# %% [markdown]
# ### Importing necessary libraries

# %%
import os
import json
import pandas as pd
import random

# %% [markdown]
# ### Function to extract EnergyPlus objects From IDF files

# %%
# Function to extract EnergyPlus objects with strict name matching
def extract_objects(idf_file_path):
    """Extracts strictly matching Zone, Space, SpaceList, BuildingSurface:Detailed, and FenestrationSurface:Detailed objects."""
    with open(idf_file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    current_obj = []
    extracted_objects = {key: [] for key in ["Zone,", "Space,", "SpaceList,", "BuildingSurface:Detailed,", "FenestrationSurface:Detailed,"]}

    inside_object = None  # Track current object type

    for line in lines:
        stripped_line = line.strip()
        if not stripped_line:
            continue  # Skip empty lines

        # Normalize spacing and remove excessive gaps
        clean_line = " ".join(stripped_line.split())  
        clean_line = clean_line.replace(" ,", ",").replace(", ", ",")  # Ensure proper comma spacing

        # Detect new object start
        for key in extracted_objects.keys():
            if clean_line.startswith(key):
                inside_object = key  # Set current object type
                current_obj = [clean_line]  # Start new object
                break
        else:
            # If already inside an object, continue collecting lines
            if inside_object:
                current_obj.append(clean_line)

        # If line ends with ';', complete the object
        if ";" in clean_line and inside_object:
            # Join the current object lines with spaces, then add a newline after the semicolon
            complete_object = " ".join(current_obj)
            extracted_objects[inside_object].append(complete_object)
            inside_object = None  # Reset tracking variable

    return [extracted_objects[key] for key in extracted_objects]

# %% [markdown]
# ### Various prompt for creating dataset with different queries

# %%
# Function to generate a user query
def generate_combined_query(description):
    """Returns a user query asking for a Zone, Space, SpaceList, BuildingSurface, and FenestrationSurface."""
    templates = [
        f"Create an EnergyPlus IDF component including a Zone, Space, and SpaceList along with a building surface and its fenestration."
        f"Building details: FA={description['FA']:.4f} m2, L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",

        f"Generate an IDF snippet defining a Zone, Space, SpaceList, a building surface, and an associated window/aperture."
        f"Building: {description['FA']:.4f} m2, {description['L']:.4f}m x {description['W']:.4f}m x {description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",

        f"Provide an EnergyPlus IDF file that includes a Zone, Space, SpaceList, a building surface, and a window/aperture."
        f"Details: L={description['L']:.4f}m, W={description['W']:.4f}m, H={description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",

        f"Give me EnergyPlus IDF file that includes a Zone, Space, SpaceList, a building surface, and a window/aperture."
        f"Details: L={description['L']:.4f}m, W={description['W']:.4f}m, H={description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",

        f"Make IDF defining a Zone, Space, SpaceList, a building surface, and an associated fenestration."
        f"Building: {description['FA']:.4f} m2, {description['L']:.4f}m x {description['W']:.4f}m x {description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
        f"Construct an EnergyPlus IDF file featuring a Zone, Space, SpaceList, a building surface, and its fenestration.\n"
        f"Specifications: Floor Area={description['FA']:.4f} sq.m, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, Aspect Ratio={description['AR']:.4f}, Window-to-Wall Ratio={description['WWR']:.2f}.",
    
        f"Dram an IDF file that includes a Zone, Space, SpaceList, a building surface, and a window or other fenestration element."
        f"Building properties: {description['FA']:.4f} sq.m total, {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Generate an EnergyPlus IDF section containing a Zone, Space, SpaceList, a building surface with fenestration, and necessary geometric details."
        f"Dimensions: {description['L']:.4f} m (L) x {description['W']:.4f} m (W) x {description['H']:.4f} m (H), Total Area={description['FA']:.4f} sq.m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Create a valid IDF file for EnergyPlus that defines a Zone, Space, SpaceList, a building envelope surface, and an opening such as a window."
        f"Given parameters: FA={description['FA']:.4f} square m, L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Write an IDF script containing a Zone, Space, SpaceList, an building surface, and its corresponding fenestration."
        f"Input specifications: Floor Area={description['FA']:.4f} square m, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
        
        f"Design an IDF file that incorporates a Zone, Space, SpaceList, a key building surface, and its fenestration for EnergyPlus simulation."
        f"Parameters: Floor Area={description['FA']:.4f} square feet, L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Prepare an EnergyPlus IDF definition that includes a Zone, Space, SpaceList, an building surface, and an associated window or aperture."
        f"Building configuration: {description['FA']:.4f} square feet, {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Write an IDF file for a building with a Zone, Space, SpaceList, a building surface, and an opening fenestration for EnergyPlus analysis."
        f"Specifications: L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, FA={description['FA']:.4f} sq. feet, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Develop an EnergyPlus IDF file that defines a Zone, Space, SpaceList, building surface and fenestration element, and other necessary details."
        f"Inputs: Floor Area={description['FA']:.4f} sq m, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Formulate an IDF snippet that includes a Zone, Space, SpaceList, building surface, and a window or glazing element."
        f"Building parameters: {description['FA']:.4f} sq m total, Dimensions: {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",

        f"How can I generate an EnergyPlus IDF file that includes a Zone, Space, SpaceList, a building surface, and a window?"
        f"My building details are: Floor Area={description['FA']:.4f} SF, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, Aspect Ratio={description['AR']:.4f}, and Window-to-Wall Ratio={description['WWR']:.2f}.",
    
        f"Can you provide an IDF file containing a Zone, Space, SpaceList, building surface, and its fenestration?"
        f"The building parameters are: {description['FA']:.4f} SF total, {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"What would an EnergyPlus IDF look like for a building with a Zone, Space, SpaceList, a building surface, and fenestration?"
        f"Here are my specifications: L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, FA={description['FA']:.4f} m2, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"Can you help me create an IDF snippet for EnergyPlus that includes a Zone, Space, SpaceList, a building surface, and a glazing element?"
        f"The building details are: {description['FA']:.4f} sq m , Dimensions: {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    
        f"What is the correct IDF structure for defining a Zone, Space, SpaceList, an building surface, and a fenestration in EnergyPlus?"
        f"My building specifications are: Floor Area={description['FA']:.4f} m2, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
    ]
    return random.choice(templates)

# %% [markdown]
# ### Choose the file path
#
# All the data related to design matrix based on which simulations are done are in Excel (csv) file. They are data about L, W, CH, FA, WWR, AR, V and EUI
# Idf file from where EnergyPlus objects will be extracted from are in idf_rectangle folder.

# %%
# Define file paths
excel_file_path = r'C:\Users\Jayedi Aman\OneDrive - University of Missouri\Desktop\LLM Eplus\idf_rectangle\data.csv'
idf_folder_path = r'C:\Users\Jayedi Aman\OneDrive - University of Missouri\Desktop\LLM Eplus\idf_rectangle'
output_json_path = 'BuildingGeometricDataset.json'

# %% [markdown]
# ### Creating dictionary
# Dictionary of ata containing key= ID or design matrix, value = set of {L, W, CH, WWR, AR, FA, V, EUI}

# %%
# Load building descriptions
if not os.path.exists(excel_file_path):
    raise FileNotFoundError(f"CSV file not found: {excel_file_path}")

df = pd.read_csv(excel_file_path)
building_data = df.set_index('ID').to_dict(orient='index')

building_data
# Out:
# {1: {'L': 28.1515,
#   'W': 15.6465,
#   'H': 2.44,
#   'WWR': 0.55,
#   'AR': 1.8,
#   'FA': 440.45,
#   'V': 1074.75,
#   'EUI': 158.68},
#  2: {'L': 43.737,
#   'W': 16.5005,
#   'H': 3.66,
#   'WWR': 0.19,
#   'AR': 2.65,
#   'FA': 721.67,
#   'V': 2641.36,
#   'EUI': 144.8},
#  3: {'L': 21.0755,
#   'W': 15.2805,
#   'H': 2.9,
#   'WWR': 0.15,
#   'AR': 1.38,
#   'FA': 322.0,
#   'V': 933.93,
#   'EUI': 144.8},
#  4: {'L': 27.7855,
#   'W': 12.81,
#   'H': 2.48,
#   'WWR': 0.21,
#   'AR': 2.17,
#   'FA': 355.91,
#   'V': 882.71,
#   'EUI': 143.85},
#  5: {'L': 38.491,
#   'W': 16.958,
#   'H': 2.89,
#   'WWR': 0.41,
#   'AR': 2.27,
#   'FA': 652.64,
#   'V': 1886.39,
#   'EUI': 150.79},
#  6: {'L': 31.4455,
#   'W': 18.605,
#   'H': 2.53,
#   'WWR': 0.16,
#   'AR': 1.69,
#   'FA': 585.01,
#   'V': 1480.16,
#   'EUI': 134.7},
#  7: {'L': 30.7135,
#   'W': 15.677,
#   'H': 3.42,
#   'WWR': 0.42,
#   'AR': 1.96,
#   'FA': 481.42,
#   'V': 1646.71,
#   'EUI': 164.35},
#  8: {'L': 26.962,
#   'W': 13.0235,
#   'H': 3.33,
#   'WWR': 0.17,
#   'AR': 2.07,
#   'FA': 351.08,
#   'V': 1169.29,
#   'EUI': 151.1},
#  9: {'L': 33.3975,
#   'W': 18.971,
#   'H': 3.23,
#   'WWR': 0.34,
#   'AR': 1.76,
#   'FA': 633.51,
#   'V': 2046.48,
#   'EUI': 149.84},
#  10: {'L': 29.9205,
#   'W': 16.8055,
#   'H': 3.61,
#   'WWR': 0.48,
#   'AR': 1.78,
#   'FA': 502.79,
#   'V': 1815.21,
#   'EUI': 170.35},
#  11: {'L': 33.672,
#   'W': 15.372,
#   'H': 3.56,
#   'WWR': 0.38,
#   'AR': 2.19,
#   'FA': 517.56,
#   'V': 1842.68,
#   'EUI': 162.46},
#  12: {'L': 25.681,
#   'W': 20.2215,
#   'H': 3.03,
#   'WWR': 0.29,
#   'AR': 1.27,
#   'FA': 519.23,
#   'V': 1573.5,
#   'EUI': 147.32},
#  13: {'L': 26.779,
#   'W': 15.128,
#   'H': 2.63,
#   'WWR': 0.41,
#   'AR': 1.77,
#   'FA': 405.06,
#   'V': 1065.45,
#   'EUI': 155.21},
#  14: {'L': 22.3565,
#   'W': 18.483,
#   'H': 3.35,
#   'WWR': 0.28,
#   'AR': 1.21,
#   'FA': 413.14,
#   'V': 1384.27,
#   'EUI': 154.57},
#  15: {'L': 30.256,
#   'W': 21.167,
#   'H': 2.59,
#   'WWR': 0.4,
#   'AR': 1.43,
#   'FA': 640.38,
#   'V': 1658.71,
#   'EUI': 144.8},
#  16: {'L': 19.0015,
#   'W': 18.8185,
#   'H': 2.96,
#   'WWR': 0.3,
#   'AR': 1.01,
#   'FA': 357.49,
#   'V': 1058.44,
#   'EUI': 153.94},
#  17: {'L': 28.426,
#   'W': 26.0775,
#   'H': 2.85,
#   'WWR': 0.42,
#   'AR': 1.09,
#   'FA': 741.27,
#   'V': 2112.65,
#   'EUI': 146.06},
#  18: {'L': 25.9555,
#   'W': 24.2475,
#   'H': 2.73,
#   'WWR': 0.48,
#   'AR': 1.07,
#   'FA': 629.32,
#   'V': 1718.14,
#   'EUI': 150.47},
#  19: {'L': 29.036,
#   'W': 21.838,
#   'H': 3.37,
#   'WWR': 0.54,
#   'AR': 1.33,
#   'FA': 634.06,
#   'V': 2136.88,
#   'EUI': 163.09},
#  20: {'L': 35.4715,
#   'W': 16.8055,
#   'H': 3.04,
#   'WWR': 0.46,
#   'AR': 2.11,
#   'FA': 596.07,
#   'V': 1812.19,
#   'EUI': 156.78},
#  21: {'L': 31.1405,
#   'W': 21.045,
#   'H': 3.49,
#   'WWR': 0.19,
#   'AR': 1.48,
#   'FA': 655.34,
#   'V': 2287.18,
#   'EUI': 142.59},
#  22: {'L': 37.515,
#   'W': 15.7685,
#   'H': 3.49,
#   'WWR': 0.21,
#   'AR': 2.38,
#   'FA': 591.51,
#   'V': 2064.53,
#   'EUI': 147.0},
#  23: {'L': 32.757,
#   'W': 14.762,
#   'H': 3.36,
#   'WWR': 0.34,
#   'AR': 2.22,
#   'FA': 483.47,
#   'V': 1624.76,
#   'EUI': 158.36},
#  24: {'L': 22.265,
#   'W': 15.4635,
#   'H': 2.57,
#   'WWR': 0.52,
#   'AR': 1.44,
#   'FA': 344.21,
#   'V': 884.84,
#   'EUI': 164.35},
#  25: {'L': 35.502,
#   'W': 19.6115,
#   'H': 3.03,
#   'WWR': 0.3,
#   'AR': 1.81,
#   'FA': 696.22,
#   'V': 2109.63,
#   'EUI': 144.16},
#  26: {'L': 21.045,
#   'W': 18.3,
#   'H': 2.75,
#   'WWR': 0.44,
#   'AR': 1.15,
#   'FA': 385.08,
#   'V': 1059.09,
#   'EUI': 158.99},
#  27: {'L': 27.4195,
#   'W': 18.91,
#   'H': 2.76,
#   'WWR': 0.37,
#   'AR': 1.45,
#   'FA': 518.49,
#   'V': 1431.07,
#   'EUI': 148.9},
#  28: {'L': 28.8225,
#   'W': 11.041,
#   'H': 2.71,
#   'WWR': 0.26,
#   'AR': 2.61,
#   'FA': 318.19,
#   'V': 862.4,
#   'EUI': 153.63},
#  29: {'L': 25.803,
#   'W': 21.8685,
#   'H': 3.53,
#   'WWR': 0.34,
#   'AR': 1.18,
#   'FA': 564.2,
#   'V': 1991.88,
#   'EUI': 154.57},
#  30: {'L': 34.465,
#   'W': 15.5245,
#   'H': 2.75,
#   'WWR': 0.46,
#   'AR': 2.22,
#   'FA': 535.03,
#   'V': 1471.39,
#   'EUI': 155.52},
#  31: {'L': 33.123,
#   'W': 16.3175,
#   'H': 3.17,
#   'WWR': 0.2,
#   'AR': 2.03,
#   'FA': 540.42,
#   'V': 1713.34,
#   'EUI': 144.16},
#  32: {'L': 35.075,
#   'W': 18.2695,
#   'H': 2.87,
#   'WWR': 0.47,
#   'AR': 1.92,
#   'FA': 640.75,
#   'V': 1839.1,
#   'EUI': 153.0},
#  33: {'L': 32.6045,
#   'W': 11.895,
#   'H': 3.23,
#   'WWR': 0.29,
#   'AR': 2.74,
#   'FA': 387.78,
#   'V': 1252.69,
#   'EUI': 159.62},
#  34: {'L': 31.476,
#   'W': 23.485,
#   'H': 2.47,
#   'WWR': 0.35,
#   'AR': 1.34,
#   'FA': 739.14,
#   'V': 1825.86,
#   'EUI': 139.43},
#  35: {'L': 29.768,
#   'W': 20.679,
#   'H': 3.15,
#   'WWR': 0.39,
#   'AR': 1.44,
#   'FA': 615.48,
#   'V': 1939.05,
#   'EUI': 151.74},
#  36: {'L': 30.9575,
#   'W': 21.655,
#   'H': 3.34,
#   'WWR': 0.2,
#   'AR': 1.43,
#   'FA': 670.3,
#   'V': 2239.08,
#   'EUI': 141.33},
#  37: {'L': 26.779,
#   'W': 9.699,
#   'H': 2.93,
#   'WWR': 0.34,
#   'AR': 2.76,
#   'FA': 259.66,
#   'V': 761.01,
#   'EUI': 169.72},
#  38: {'L': 23.2105,
#   'W': 12.4135,
#   'H': 3.61,
#   'WWR': 0.16,
#   'AR': 1.87,
#   'FA': 288.09,
#   'V': 1040.13,
#   'EUI': 157.1},
#  39: {'L': 25.6505,
#   'W': 16.8665,
#   'H': 3.13,
#   'WWR': 0.44,
#   'AR': 1.52,
#   'FA': 432.56,
#   'V': 1354.14,
#   'EUI': 162.78},
#  40: {'L': 21.899,
#   'W': 11.895,
#   'H': 3.53,
#   'WWR': 0.49,
#   'AR': 1.84,
#   'FA': 260.41,
#   'V': 919.52,
#   'EUI': 193.06},
#  41: {'L': 29.097,
#   'W': 9.7295,
#   'H': 3.63,
#   'WWR': 0.46,
#   'AR': 2.99,
#   'FA': 283.08,
#   'V': 1027.65,
#   'EUI': 195.9},
#  42: {'L': 41.175,
#   'W': 16.8055,
#   'H': 3.49,
#   'WWR': 0.49,
#   'AR': 2.45,
#   'FA': 691.94,
#   'V': 2414.96,
#   'EUI': 163.09},
#  43: {'L': 21.106,
#   'W': 12.566,
#   'H': 2.59,
#   'WWR': 0.27,
#   'AR': 1.68,
#   'FA': 265.15,
#   'V': 686.91,
#   'EUI': 153.63},
#  44: {'L': 39.772,
#   'W': 18.9405,
#   'H': 3.56,
#   'WWR': 0.35,
#   'AR': 2.1,
#   'FA': 753.26,
#   'V': 2681.75,
#   'EUI': 151.74},
#  45: {'L': 38.4605,
#   'W': 14.457,
#   'H': 2.78,
#   'WWR': 0.23,
#   'AR': 2.66,
#   'FA': 555.93,
#   'V': 1545.75,
#   'EUI': 142.9},
#  46: {'L': 39.772,
#   'W': 13.481,
#   'H': 3.45,
#   'WWR': 0.29,
#   'AR': 2.95,
#   'FA': 536.14,
#   'V': 1849.77,
#   'EUI': 156.15},
#  47: {'L': 25.01,
#   'W': 10.553,
#   'H': 2.68,
#   'WWR': 0.28,
#   'AR': 2.37,
#   'FA': 263.84,
#   'V': 707.33,
#   'EUI': 158.04},
#  48: {'L': 22.3565,
#   'W': 15.86,
#   'H': 2.9,
#   'WWR': 0.44,
#   'AR': 1.41,
#   'FA': 354.52,
#   'V': 1028.26,
#   'EUI': 164.04},
#  49: {'L': 29.829,
#   'W': 15.86,
#   'H': 3.33,
#   'WWR': 0.31,
#   'AR': 1.88,
#   'FA': 473.06,
#   'V': 1575.38,
#   'EUI': 155.21},
#  50: {'L': 29.7375,
#   'W': 10.858,
#   'H': 3.63,
#   'WWR': 0.47,
#   'AR': 2.74,
#   'FA': 322.84,
#   'V': 1172.09,
#   'EUI': 189.91},
#  51: {'L': 23.424,
#   'W': 18.3,
#   'H': 2.6,
#   'WWR': 0.19,
#   'AR': 1.28,
#   'FA': 428.65,
#   'V': 1114.51,
#   'EUI': 140.06},
#  52: {'L': 25.2235,
#   'W': 15.372,
#   'H': 3.33,
#   'WWR': 0.45,
#   'AR': 1.64,
#   'FA': 387.68,
#   'V': 1291.16,
#   'EUI': 170.35},
#  53: {'L': 23.851,
#   'W': 10.797,
#   'H': 2.88,
#   'WWR': 0.18,
#   'AR': 2.21,
#   'FA': 257.43,
#   'V': 741.66,
#   'EUI': 152.68},
#  54: {'L': 19.764,
#   'W': 14.213,
#   'H': 3.61,
#   'WWR': 0.33,
#   'AR': 1.39,
#   'FA': 280.85,
#   'V': 1014.07,
#   'EUI': 172.87},
#  55: {'L': 25.681,
#   'W': 9.5465,
#   'H': 3.44,
#   'WWR': 0.2,
#   'AR': 2.69,
#   'FA': 245.08,
#   'V': 843.36,
#   'EUI': 165.62},
#  56: {'L': 36.783,
#   'W': 13.725,
#   'H': 3.05,
#   'WWR': 0.39,
#   'AR': 2.68,
#   'FA': 504.83,
#   'V': 1539.78,
#   'EUI': 158.36},
#  57: {'L': 33.3365,
#   'W': 17.5375,
#   'H': 3.17,
#   'WWR': 0.49,
#   'AR': 1.9,
#   'FA': 584.64,
#   'V': 1853.31,
#   'EUI': 160.57},
#  58: {'L': 24.217,
#   'W': 11.8645,
#   'H': 3.54,
#   'WWR': 0.47,
#   'AR': 2.04,
#   'FA': 287.26,
#   'V': 1017.12,
#   'EUI': 188.33},
#  59: {'L': 32.2385,
#   'W': 17.7205,
#   'H': 3.03,
#   'WWR': 0.45,
#   'AR': 1.82,
#   'FA': 571.26,
#   'V': 1730.99,
#   'EUI': 156.15},
#  60: {'L': 25.01,
#   'W': 11.163,
#   'H': 3.05,
#   'WWR': 0.3,
#   'AR': 2.24,
#   'FA': 279.17,
#   'V': 851.52,
#   'EUI': 164.04},
#  61: {'L': 34.709,
#   'W': 11.8035,
#   'H': 3.6,
#   'WWR': 0.48,
#   'AR': 2.94,
#   'FA': 409.61,
#   'V': 1474.88,
#   'EUI': 182.65},
#  62: {'L': 26.23,
#   'W': 13.115,
#   'H': 2.68,
#   'WWR': 0.51,
#   'AR': 2.0,
#   'FA': 343.93,
#   'V': 921.94,
#   'EUI': 167.82},
#  63: {'L': 22.631,
#   'W': 16.043,
#   'H': 2.47,
#   'WWR': 0.29,
#   'AR': 1.41,
#   'FA': 363.06,
#   'V': 896.78,
#   'EUI': 146.69},
#  64: {'L': 24.0645,
#   'W': 15.433,
#   'H': 2.55,
#   'WWR': 0.36,
#   'AR': 1.56,
#   'FA': 371.33,
#   'V': 947.04,
#   'EUI': 152.05},
#  65: {'L': 21.472,
#   'W': 12.139,
#   'H': 3.01,
#   'WWR': 0.21,
#   'AR': 1.77,
#   'FA': 260.59,
#   'V': 784.55,
#   'EUI': 155.52},
#  66: {'L': 33.5195,
#   'W': 20.069,
#   'H': 2.63,
#   'WWR': 0.5,
#   'AR': 1.67,
#   'FA': 672.62,
#   'V': 1769.21,
#   'EUI': 149.84},
#  67: {'L': 22.1735,
#   'W': 14.213,
#   'H': 2.63,
#   'WWR': 0.38,
#   'AR': 1.56,
#   'FA': 315.13,
#   'V': 828.85,
#   'EUI': 158.04},
#  68: {'L': 29.3715,
#   'W': 24.888,
#   'H': 3.46,
#   'WWR': 0.45,
#   'AR': 1.18,
#   'FA': 730.96,
#   'V': 2529.25,
#   'EUI': 155.21},
#  69: {'L': 27.45,
#   'W': 9.3635,
#   'H': 3.44,
#   'WWR': 0.5,
#   'AR': 2.93,
#   'FA': 256.97,
#   'V': 884.18,
#   'EUI': 200.0},
#  70: {'L': 22.814,
#   'W': 10.614,
#   'H': 3.15,
#   'WWR': 0.3,
#   'AR': 2.15,
#   'FA': 242.11,
#   'V': 762.77,
#   'EUI': 169.09},
#  71: {'L': 43.6455,
#   'W': 16.287,
#   'H': 2.97,
#   'WWR': 0.31,
#   'AR': 2.68,
#   'FA': 710.8,
#   'V': 2111.24,
#   'EUI': 145.74},
#  72: {'L': 32.147,
#   'W': 12.322,
#   'H': 2.81,
#   'WWR': 0.36,
#   'AR': 2.61,
#   'FA': 396.05,
#   'V': 1113.08,
#   'EUI': 157.73},
#  73: {'L': 23.2715,
#   'W': 10.248,
#   'H': 3.24,
#   'WWR': 0.4,
#   'AR': 2.27,
#   'FA': 238.48,
#   'V': 772.7,
#   'EUI': 182.65},
#  74: {'L': 32.5435,
#   'W': 13.3895,
#   'H': 2.46,
#   'WWR': 0.16,
#   'AR': 2.43,
#   'FA': 435.72,
#   'V': 1071.92,
#   'EUI': 138.49},
#  75: {'L': 21.289,
#   'W': 12.2305,
#   'H': 2.97,
#   'WWR': 0.39,
#   'AR': 1.74,
#   'FA': 260.31,
#   'V': 773.31,
#   'EUI': 170.66},
#  76: {'L': 35.136,
#   'W': 15.3415,
#   'H': 3.24,
#   'WWR': 0.54,
#   'AR': 2.29,
#   'FA': 539.02,
#   'V': 1746.49,
#   'EUI': 168.77},
#  77: {'L': 40.7175,
#   'W': 14.701,
#   'H': 3.44,
#   'WWR': 0.47,
#   'AR': 2.77,
#   'FA': 598.57,
#   'V': 2059.14,
#   'EUI': 165.93},
#  78: {'L': 27.45,
#   'W': 10.553,
#   'H': 3.26,
#   'WWR': 0.26,
#   'AR': 2.6,
#   'FA': 289.67,
#   'V': 944.36,
#   'EUI': 164.04},
#  79: {'L': 25.193,
#   'W': 9.882,
#   'H': 3.05,
#   'WWR': 0.3,
#   'AR': 2.55,
#   'FA': 248.89,
#   'V': 759.32,
#   'EUI': 168.46},
#  80: {'L': 28.792,
#   'W': 21.167,
#   'H': 2.63,
#   'WWR': 0.23,
#   'AR': 1.36,
#   'FA': 609.35,
#   'V': 1602.83,
#   'EUI': 137.86},
#  81: {'L': 39.5585,
#   'W': 17.202,
#   'H': 2.46,
#   'WWR': 0.4,
#   'AR': 2.3,
#   'FA': 680.42,
#   'V': 1673.99,
#   'EUI': 144.16},
#  82: {'L': 34.709,
#   'W': 14.457,
#   'H': 2.91,
#   'WWR': 0.41,
#   'AR': 2.4,
#   'FA': 501.77,
#   'V': 1460.2,
#   'EUI': 156.78},
#  83: {'L': 31.7505,
#   'W': 16.714,
#   'H': 2.91,
#   'WWR': 0.27,
#   'AR': 1.9,
#   'FA': 530.66,
#   'V': 1544.27,
#   'EUI': 145.74},
#  84: {'L': 35.1055,
#   'W': 21.0145,
#   'H': 2.61,
#   'WWR': 0.21,
#   'AR': 1.67,
#   'FA': 737.65,
#   'V': 1925.46,
#   'EUI': 135.02},
#  85: {'L': 39.4975,
#   'W': 18.117,
#   'H': 2.5,
#   'WWR': 0.43,
#   'AR': 2.18,
#   'FA': 715.54,
#   'V': 1788.94,
#   'EUI': 144.8},
#  86: {'L': 20.5875,
#   'W': 15.25,
#   'H': 2.52,
#   'WWR': 0.33,
#   'AR': 1.35,
#   'FA': 313.92,
#   'V': 791.18,
#   'EUI': 152.68},
#  87: {'L': 22.4785,
#   'W': 21.0145,
#   'H': 2.62,
#   'WWR': 0.24,
#   'AR': 1.07,
#   'FA': 472.32,
#   'V': 1237.62,
#   'EUI': 141.64},
#  88: {'L': 35.7765,
#   'W': 14.4265,
#   'H': 3.44,
#   'WWR': 0.5,
#   'AR': 2.48,
#   'FA': 516.08,
#   'V': 1775.49,
#   'EUI': 171.29},
#  89: {'L': 23.607,
#   'W': 23.363,
#   'H': 2.69,
#   'WWR': 0.37,
#   'AR': 1.01,
#   'FA': 551.47,
#   'V': 1483.62,
#   'EUI': 146.69},
#  90: {'L': 35.9595,
#   'W': 12.1085,
#   'H': 3.6,
#   'WWR': 0.51,
#   'AR': 2.97,
#   'FA': 435.34,
#   'V': 1567.5,
#   'EUI': 183.28},
#  91: {'L': 38.3385,
#   'W': 15.5855,
#   'H': 2.88,
#   'WWR': 0.51,
#   'AR': 2.46,
#   'FA': 597.46,
#   'V': 1720.87,
#   'EUI': 158.68},
#  92: {'L': 21.533,
#   'W': 19.398,
#   'H': 2.63,
#   'WWR': 0.29,
#   'AR': 1.11,
#   'FA': 417.69,
#   'V': 1098.54,
#   'EUI': 146.37},
#  93: {'L': 39.1925,
#   'W': 13.7555,
#   'H': 3.08,
#   'WWR': 0.33,
#   'AR': 2.85,
#   'FA': 539.02,
#   'V': 1660.47,
#   'EUI': 153.63},
#  94: {'L': 27.023,
#   'W': 12.81,
#   'H': 2.96,
#   'WWR': 0.25,
#   'AR': 2.11,
#   'FA': 346.16,
#   'V': 1024.65,
#   'EUI': 153.0},
#  95: {'L': 28.731,
#   'W': 18.666,
#   'H': 2.94,
#   'WWR': 0.54,
#   'AR': 1.54,
#   'FA': 536.24,
#   'V': 1576.7,
#   'EUI': 161.2},
#  96: {'L': 39.406,
#   'W': 18.3305,
#   'H': 3.53,
#   'WWR': 0.25,
#   'AR': 2.15,
#   'FA': 722.32,
#   'V': 2549.83,
#   'EUI': 146.06},
#  97: {'L': 40.138,
#   'W': 13.9385,
#   'H': 2.59,
#   'WWR': 0.3,
#   'AR': 2.88,
#   'FA': 559.37,
#   'V': 1449.01,
#   'EUI': 145.11},
#  98: {'L': 25.3455,
#   'W': 14.9145,
#   'H': 3.01,
#   'WWR': 0.21,
#   'AR': 1.7,
#   'FA': 377.93,
#   'V': 1137.83,
#   'EUI': 148.27},
#  99: {'L': 31.1405,
#   'W': 12.3525,
#   'H': 3.53,
#   'WWR': 0.43,
#   'AR': 2.52,
#   'FA': 384.62,
#   'V': 1357.86,
#   'EUI': 176.34},
#  100: {'L': 27.328,
#   'W': 12.4745,
#   'H': 3.17,
#   'WWR': 0.4,
#   'AR': 2.19,
#   'FA': 340.86,
#   'V': 1080.66,
#   'EUI': 169.4},
#  101: {'L': 35.0445,
#   'W': 12.2915,
#   'H': 2.82,
#   'WWR': 0.19,
#   'AR': 2.85,
#   'FA': 430.7,
#   'V': 1214.71,
#   'EUI': 145.43},
#  102: {'L': 44.1335,
#   'W': 16.592,
#   'H': 3.57,
#   'WWR': 0.2,
#   'AR': 2.66,
#   'FA': 732.17,
#   'V': 2614.18,
#   'EUI': 144.48},
#  103: {'L': 45.5365,
#   'W': 15.982,
#   'H': 3.09,
#   'WWR': 0.33,
#   'AR': 2.85,
#   'FA': 727.71,
#   'V': 2248.79,
#   'EUI': 148.27},
#  104: {'L': 29.707,
#   'W': 13.2065,
#   'H': 2.72,
#   'WWR': 0.44,
#   'AR': 2.25,
#   'FA': 392.33,
#   'V': 1067.13,
#   'EUI': 160.88},
#  105: {'L': 31.5675,
#   'W': 17.8425,
#   'H': 3.04,
#   'WWR': 0.18,
#   'AR': 1.77,
#   'FA': 563.18,
#   'V': 1712.26,
#   'EUI': 140.69},
#  106: {'L': 26.8705,
#   'W': 12.1085,
#   'H': 3.14,
#   'WWR': 0.2,
#   'AR': 2.22,
#   'FA': 325.35,
#   'V': 1021.63,
#   'EUI': 153.31},
#  107: {'L': 38.5825,
#   'W': 16.0735,
#   'H': 3.29,
#   'WWR': 0.24,
#   'AR': 2.4,
#   'FA': 620.13,
#   'V': 2040.31,
#   'EUI': 146.37},
#  108: {'L': 41.602,
#   'W': 14.5485,
#   'H': 3.52,
#   'WWR': 0.18,
#   'AR': 2.86,
#   'FA': 605.17,
#   'V': 2130.47,
#   'EUI': 146.37},
#  109: {'L': 29.4935,
#   'W': 13.847,
#   'H': 2.49,
#   'WWR': 0.19,
#   'AR': 2.13,
#   'FA': 408.31,
#   'V': 1016.91,
#   'EUI': 140.69},
#  110: {'L': 38.552,
#   'W': 14.335,
#   'H': 3.06,
#   'WWR': 0.2,
#   'AR': 2.69,
#   'FA': 552.59,
#   'V': 1691.09,
#   'EUI': 144.16},
#  111: {'L': 30.378,
#   'W': 22.021,
#   'H': 3.52,
#   'WWR': 0.17,
#   'AR': 1.38,
#   'FA': 668.9,
#   'V': 2354.72,
#   'EUI': 141.01},
#  112: {'L': 25.559,
#   'W': 24.1255,
#   'H': 3.39,
#   'WWR': 0.23,
#   'AR': 1.06,
#   'FA': 616.6,
#   'V': 2090.35,
#   'EUI': 144.48},
#  113: {'L': 37.3015,
#   'W': 16.653,
#   'H': 2.83,
#   'WWR': 0.3,
#   'AR': 2.24,
#   'FA': 621.15,
#   'V': 1757.94,
#   'EUI': 144.8},
#  114: {'L': 26.962,
#   'W': 10.0955,
#   'H': 3.11,
#   'WWR': 0.49,
#   'AR': 2.67,
#   'FA': 272.11,
#   'V': 846.53,
#   'EUI': 186.75},
#  115: {'L': 27.3585,
#   'W': 16.287,
#   'H': 3.25,
#   'WWR': 0.16,
#   'AR': 1.68,
#   'FA': 445.56,
#   'V': 1448.16,
#   'EUI': 144.48},
#  116: {'L': 33.4585,
#   'W': 11.3765,
#   'H': 2.81,
#   'WWR': 0.44,
#   'AR': 2.94,
#   'FA': 380.62,
#   'V': 1069.6,
#   'EUI': 166.25},
#  117: {'L': 37.881,
#   'W': 14.457,
#   'H': 2.76,
#   'WWR': 0.3,
#   'AR': 2.62,
#   'FA': 547.57,
#   'V': 1511.5,
#   'EUI': 147.0},
#  118: {'L': 29.707,
#   'W': 15.311,
#   'H': 3.38,
#   'WWR': 0.54,
#   'AR': 1.94,
#   'FA': 454.76,
#   'V': 1537.37,
#   'EUI': 174.76},
#  119: {'L': 28.975,
#   'W': 12.383,
#   'H': 3.26,
#   'WWR': 0.49,
#   'AR': 2.34,
#   'FA': 358.79,
#   'V': 1169.68,
#   'EUI': 177.92},
#  120: {'L': 27.1145,
#   'W': 18.4525,
#   'H': 3.38,
#   'WWR': 0.22,
#   'AR': 1.47,
#   'FA': 500.28,
#   'V': 1691.12,
#   'EUI': 147.63},
#  121: {'L': 36.9965,
#   'W': 17.7815,
#   'H': 3.13,
#   'WWR': 0.38,
#   'AR': 2.08,
#   'FA': 657.85,
#   'V': 2059.08,
#   'EUI': 151.1},
#  122: {'L': 39.65,
#   'W': 15.677,
#   'H': 3.13,
#   'WWR': 0.27,
#   'AR': 2.53,
#   'FA': 621.52,
#   'V': 1945.59,
#   'EUI': 147.0},
#  123: {'L': 33.2755,
#   'W': 11.712,
#   'H': 2.97,
#   'WWR': 0.22,
#   'AR': 2.84,
#   'FA': 389.64,
#   'V': 1157.48,
#   'EUI': 150.79},
#  124: {'L': 35.3495,
#   'W': 20.313,
#   'H': 2.78,
#   'WWR': 0.46,
#   'AR': 1.74,
#   'FA': 718.05,
#   'V': 1996.19,
#   'EUI': 148.58},
#  125: {'L': 38.247,
#   'W': 16.0735,
#   'H': 3.01,
#   'WWR': 0.22,
#   'AR': 2.38,
#   'FA': 614.74,
#   'V': 1850.44,
#   'EUI': 142.59},
#  126: {'L': 23.2105,
#   'W': 13.5725,
#   'H': 3.0,
#   'WWR': 0.37,
#   'AR': 1.71,
#   'FA': 314.94,
#   'V': 945.07,
#   'EUI': 164.04},
#  127: {'L': 45.6585,
#   'W': 15.799,
#   'H': 2.71,
#   'WWR': 0.46,
#   'AR': 2.89,
#   'FA': 721.3,
#   'V': 1954.88,
#   'EUI': 150.79},
#  128: {'L': 27.6025,
#   'W': 24.0035,
#   'H': 3.65,
#   'WWR': 0.37,
#   'AR': 1.15,
#   'FA': 662.49,
#   'V': 2418.33,
#   'EUI': 154.57},
#  129: {'L': 27.4805,
#   'W': 26.9315,
#   'H': 2.71,
#   'WWR': 0.16,
#   'AR': 1.02,
#   'FA': 740.07,
#   'V': 2005.65,
#   'EUI': 133.44},
#  130: {'L': 30.866,
#   'W': 21.7465,
#   'H': 3.03,
#   'WWR': 0.47,
#   'AR': 1.42,
#   'FA': 671.22,
#   'V': 2033.82,
#   'EUI': 153.0},
#  131: {'L': 28.8835,
#   'W': 11.285,
#   'H': 3.11,
#   'WWR': 0.34,
#   'AR': 2.56,
#   'FA': 325.9,
#   'V': 1013.71,
#   'EUI': 165.62},
#  132: {'L': 19.825,
#   'W': 17.385,
#   'H': 2.61,
#   'WWR': 0.19,
#   'AR': 1.14,
#   'FA': 344.58,
#   'V': 899.56,
#   'EUI': 142.9},
#  133: {'L': 20.1605,
#   'W': 17.8425,
#   'H': 3.09,
#   'WWR': 0.18,
#   'AR': 1.13,
#   'FA': 359.63,
#   'V': 1111.52,
#   'EUI': 147.0},
#  134: {'L': 27.572,
#   'W': 22.6005,
#   'H': 3.38,
#   'WWR': 0.4,
#   'AR': 1.22,
#   'FA': 623.1,
#   'V': 2106.22,
#   'EUI': 154.57},
#  135: {'L': 37.637,
#   'W': 15.677,
#   'H': 2.84,
#   'WWR': 0.37,
#   'AR': 2.4,
#   'FA': 590.03,
#   'V': 1675.7,
#   'EUI': 150.16},
#  136: {'L': 30.5,
#   'W': 10.736,
#   'H': 2.65,
#   'WWR': 0.27,
#   'AR': 2.84,
#   'FA': 327.39,
#   'V': 867.74,
#   'EUI': 153.63},
#  137: {'L': 22.265,
#   'W': 16.3785,
#   'H': 2.88,
#   'WWR': 0.17,
#   'AR': 1.36,
#   'FA': 364.64,
#   'V': 1050.24,
#   'EUI': 144.16},
#  138: {'L': 21.533,
#   'W': 11.041,
#   'H': 2.67,
#   'WWR': 0.54,
#   'AR': 1.95,
#   'FA': 237.74,
#   'V': 634.78,
#   'EUI': 181.39},
#  139: {'L': 26.108,
#   'W': 13.664,
#   'H': 2.52,
#   'WWR': 0.4,
#   'AR': 1.91,
#   'FA': 356.65,
#   'V': 898.98,
#   'EUI': 155.84},
#  140: {'L': 33.0315,
#   'W': 22.021,
#   'H': 3.22,
#   'WWR': 0.46,
#   'AR': 1.5,
#   'FA': 727.34,
#   'V': 2342.19,
#   'EUI': 153.31},
#  141: {'L': 40.382,
#   'W': 18.361,
#   'H': 2.99,
#   'WWR': 0.2,
#   'AR': 2.2,
#   'FA': 741.37,
#   'V': 2216.95,
#   'EUI': 138.49},
#  142: {'L': 26.3825,
#   'W': 11.3765,
#   'H': 3.62,
#   'WWR': 0.23,
#   'AR': 2.32,
#   'FA': 300.08,
#   'V': 1086.51,
#   'EUI': 164.67},
#  143: {'L': 45.811,
#   'W': 16.1345,
#   'H': 3.61,
#   'WWR': 0.41,
#   'AR': 2.84,
#   'FA': 739.14,
#   'V': 2668.29,
#   'EUI': 158.99},
#  144: {'L': 19.093,
#   'W': 18.361,
#   'H': 3.04,
#   'WWR': 0.17,
#   'AR': 1.04,
#   'FA': 350.52,
#   'V': 1065.72,
#   'EUI': 146.37},
#  145: {'L': 35.502,
#   'W': 17.6595,
#   'H': 3.6,
#   'WWR': 0.51,
#   'AR': 2.01,
#   'FA': 626.91,
#   'V': 2257.01,
#   'EUI': 166.88},
#  146: {'L': 38.6435,
#   'W': 16.3785,
#   'H': 3.1,
#   'WWR': 0.54,
#   'AR': 2.36,
#   'FA': 632.86,
#   'V': 1962.06,
#   'EUI': 162.46},
#  147: {'L': 44.591,
#   'W': 15.921,
#   'H': 3.63,
#   'WWR': 0.17,
#   'AR': 2.8,
#   'FA': 709.87,
#   'V': 2577.06,
#   'EUI': 143.85},
#  148: {'L': 31.8725,
#   'W': 19.6725,
#   'H': 2.86,
#   'WWR': 0.33,
#   'AR': 1.62,
#   'FA': 627.0,
#   'V': 1793.25,
#   'EUI': 145.11},
#  149: {'L': 30.1645,
#   'W': 11.9255,
#   'H': 3.36,
#   'WWR': 0.23,
#   'AR': 2.53,
#   'FA': 359.72,
#   'V': 1208.68,
#   'EUI': 157.41},
#  150: {'L': 32.6655,
#   'W': 11.0715,
#   'H': 3.61,
#   'WWR': 0.31,
#   'AR': 2.95,
#   'FA': 361.58,
#   'V': 1305.58,
#   'EUI': 170.03},
#  151: {'L': 25.9555,
#   'W': 19.093,
#   'H': 3.61,
#   'WWR': 0.2,
#   'AR': 1.36,
#   'FA': 495.54,
#   'V': 1789.0,
#   'EUI': 148.58},
#  152: {'L': 29.7985,
#   'W': 13.664,
#   'H': 3.46,
#   'WWR': 0.19,
#   'AR': 2.18,
#   'FA': 407.1,
#   'V': 1408.8,
#   'EUI': 151.74},
#  153: {'L': 32.6655,
#   'W': 20.1605,
#   'H': 2.96,
#   'WWR': 0.38,
#   'AR': 1.62,
#   'FA': 658.5,
#   'V': 1949.32,
#   'EUI': 147.95},
#  154: {'L': 35.8985,
#   'W': 12.7795,
#   'H': 3.63,
#   'WWR': 0.37,
#   'AR': 2.81,
#   'FA': 458.76,
#   'V': 1665.32,
#   'EUI': 168.46},
#  155: {'L': 26.413,
#   'W': 26.413,
#   'H': 3.15,
#   'WWR': 0.48,
#   'AR': 1.0,
#   'FA': 697.61,
#   'V': 2197.59,
#   'EUI': 153.94},
#  156: {'L': 41.9375,
#   'W': 15.5855,
#   'H': 2.92,
#   'WWR': 0.49,
#   'AR': 2.69,
#   'FA': 653.57,
#   'V': 1908.56,
#   'EUI': 157.1},
#  157: {'L': 21.8685,
#   'W': 14.6705,
#   'H': 2.77,
#   'WWR': 0.38,
#   'AR': 1.49,
#   'FA': 320.79,
#   'V': 888.68,
#   'EUI': 159.94},
#  158: {'L': 39.9855,
#   'W': 14.1825,
#   'H': 2.97,
#   'WWR': 0.37,
#   'AR': 2.82,
#   'FA': 567.08,
#   'V': 1684.27,
#   'EUI': 153.63},
#  159: {'L': 24.5525,
#   'W': 11.0105,
#   'H': 3.4,
#   'WWR': 0.55,
#   'AR': 2.23,
#   'FA': 270.25,
#   'V': 919.14,
#   'EUI': 197.48},
#  160: {'L': 28.914,
#   'W': 20.496,
#   'H': 2.51,
#   'WWR': 0.55,
#   'AR': 1.41,
#   'FA': 592.54,
#   'V': 1487.48,
#   'EUI': 152.37},
#  161: {'L': 38.247,
#   'W': 19.6115,
#   'H': 2.58,
#   'WWR': 0.33,
#   'AR': 1.95,
#   'FA': 750.01,
#   'V': 1935.21,
#   'EUI': 140.38},
#  162: {'L': 33.5805,
#   'W': 17.0495,
#   'H': 2.67,
#   'WWR': 0.28,
#   'AR': 1.97,
#   'FA': 572.47,
#   'V': 1528.66,
#   'EUI': 142.59},
#  163: {'L': 32.269,
#   'W': 23.2105,
#   'H': 3.58,
#   'WWR': 0.37,
#   'AR': 1.39,
#   'FA': 748.89,
#   'V': 2681.35,
#   'EUI': 151.42},
#  164: {'L': 38.491,
#   'W': 17.4155,
#   'H': 3.26,
#   'WWR': 0.52,
#   'AR': 2.21,
#   'FA': 670.3,
#   'V': 2185.31,
#   'EUI': 161.52},
#  165: {'L': 32.818,
#   'W': 21.8685,
#   'H': 3.33,
#   'WWR': 0.33,
#   'AR': 1.5,
#   'FA': 717.68,
#   'V': 2389.88,
#   'EUI': 147.63},
#  166: {'L': 33.672,
#   'W': 13.2065,
#   'H': 3.34,
#   'WWR': 0.53,
#   'AR': 2.55,
#   'FA': 444.63,
#   'V': 1485.26,
#   'EUI': 176.97},
#  167: {'L': 37.4845,
#   'W': 17.5985,
#   'H': 3.17,
#   'WWR': 0.44,
#   'AR': 2.13,
#   'FA': 659.61,
#   'V': 2091.16,
#   'EUI': 155.21},
#  168: {'L': 38.2775,
#   'W': 16.714,
#   'H': 2.94,
#   'WWR': 0.38,
#   'AR': 2.29,
#   'FA': 639.73,
#   'V': 1880.92,
#   'EUI': 149.84},
#  169: {'L': 23.363,
#   'W': 11.346,
#   'H': 3.44,
#   'WWR': 0.33,
#   'AR': 2.06,
#   'FA': 265.05,
#   'V': 911.86,
#   'EUI': 174.45},
#  170: {'L': 29.0665,
#   'W': 17.934,
#   'H': 3.46,
#   'WWR': 0.5,
#   'AR': 1.62,
#   'FA': 521.28,
#   'V': 1803.62,
#   'EUI': 167.51},
#  171: {'L': 26.9315,
#   'W': 26.1385,
#   'H': 2.66,
#   'WWR': 0.31,
#   'AR': 1.03,
#   'FA': 703.93,
#   'V': 1872.5,
#   'EUI': 140.06},
#  172: {'L': 39.0705,
#   'W': 19.2455,
#   'H': 3.6,
#   'WWR': 0.18,
#   'AR': 2.03,
#   'FA': 751.86,
#   'V': 2706.95,
#   'EUI': 141.96},
#  173: {'L': 23.973,
#   'W': 17.629,
#   'H': 3.22,
#   'WWR': 0.27,
#   'AR': 1.36,
#   'FA': 422.62,
#   'V': 1360.84,
#   'EUI': 152.05},
#  174: {'L': 25.498,
#   'W': 18.8795,
#   'H': 3.17,
#   'WWR': 0.17,
#   'AR': 1.35,
#   'FA': 481.33,
#   'V': 1526.0,
#   'EUI': 142.59},
#  175: {'L': 31.659,
#   'W': 16.3175,
#   'H': 2.62,
#   'WWR': 0.24,
#   'AR': 1.94,
#   'FA': 516.54,
#   'V': 1353.48,
#   'EUI': 141.33},
#  176: {'L': 32.6045,
#   'W': 14.3655,
#   'H': 3.51,
#   'WWR': 0.16,
#   'AR': 2.27,
#   'FA': 468.32,
#   'V': 1644.01,
#   'EUI': 147.63},
#  177: {'L': 24.278,
#   'W': 9.272,
#   'H': 2.92,
#   'WWR': 0.51,
#   'AR': 2.62,
#   'FA': 225.1,
#   'V': 657.31,
#   'EUI': 191.17},
#  178: {'L': 38.9485,
#   'W': 16.8665,
#   'H': 2.86,
#   'WWR': 0.52,
#   'AR': 2.31,
#   'FA': 656.92,
#   'V': 1878.81,
#   'EUI': 156.47},
#  179: {'L': 26.901,
#   'W': 25.864,
#   'H': 3.5,
#   'WWR': 0.44,
#   'AR': 1.04,
#   'FA': 695.75,
#   'V': 2435.19,
#   'EUI': 156.15},
#  180: {'L': 31.354,
#   'W': 22.875,
#   'H': 2.46,
#   'WWR': 0.18,
#   'AR': 1.37,
#   'FA': 717.21,
#   'V': 1764.37,
#   'EUI': 132.81},
#  181: {'L': 32.2385,
#   'W': 16.6225,
#   'H': 3.3,
#   'WWR': 0.52,
#   'AR': 1.94,
#   'FA': 535.86,
#   'V': 1768.42,
#   'EUI': 166.88},
#  182: {'L': 32.696,
#   'W': 16.6835,
#   'H': 2.8,
#   'WWR': 0.26,
#   'AR': 1.96,
#   'FA': 545.43,
#   'V': 1527.35,
#   'EUI': 143.53},
#  183: {'L': 18.8795,
#   'W': 15.738,
#   'H': 3.33,
#   'WWR': 0.27,
#   'AR': 1.2,
#   'FA': 297.1,
#   'V': 989.43,
#   'EUI': 161.2},
#  184: {'L': 46.8175,
#   'W': 15.982,
#   'H': 2.54,
#   'WWR': 0.22,
#   'AR': 2.93,
#   'FA': 748.15,
#   'V': 1900.52,
#   'EUI': 136.91},
#  185: {'L': 34.892,
#   'W': 13.5725,
#   'H': 3.42,
#   'WWR': 0.4,
#   'AR': 2.57,
#   'FA': 473.53,
#   'V': 1619.62,
#   'EUI': 165.62},
#  186: {'L': 30.5,
#   'W': 10.309,
#   'H': 2.94,
#   'WWR': 0.46,
#   'AR': 2.96,
#   'FA': 314.38,
#   'V': 924.41,
#   'EUI': 176.34},
#  187: {'L': 21.1975,
#   'W': 12.8405,
#   'H': 2.54,
#   'WWR': 0.41,
#   'AR': 1.65,
#   'FA': 272.11,
#   'V': 691.35,
#   'EUI': 162.46},
#  188: {'L': 25.254,
#   'W': 15.5855,
#   'H': 3.43,
#   'WWR': 0.52,
#   'AR': 1.62,
#   'FA': 393.54,
#   'V': 1350.04,
#   'EUI': 177.6},
#  189: {'L': 25.1015,
#   'W': 14.8535,
#   'H': 3.09,
#   'WWR': 0.17,
#   'AR': 1.69,
#   'FA': 372.82,
#   'V': 1152.09,
#   'EUI': 146.37},
#  190: {'L': 20.3435,
#   'W': 18.666,
#   'H': 2.8,
#   'WWR': 0.45,
#   'AR': 1.09,
#   'FA': 379.69,
#   'V': 1063.25,
#   'EUI': 160.88},
#  191: {'L': 29.6765,
#   'W': 21.1975,
#   'H': 3.37,
#   'WWR': 0.48,
#   'AR': 1.4,
#   'FA': 629.05,
#   'V': 2119.96,
#   'EUI': 159.62},
#  192: {'L': 31.842,
#   'W': 14.6095,
#   'H': 3.37,
#   'WWR': 0.3,
#   'AR': 2.18,
#   'FA': 465.17,
#   'V': 1567.71,
#   'EUI': 156.15},
#  193: {'L': 25.132,
#   'W': 22.448,
#   'H': 3.62,
#   'WWR': 0.36,
#   'AR': 1.12,
#   'FA': 564.11,
#   'V': 2042.27,
#   'EUI': 157.1},
#  194: {'L': 38.43,
#   'W': 16.714,
#   'H': 2.59,
#   'WWR': 0.46,
#   'AR': 2.3,
#   'FA': 642.24,
#   'V': 1663.61,
#   'EUI': 149.84},
#  195: {'L': 27.4195,
#   'W': 22.8445,
#   'H': 2.52,
#   'WWR': 0.43,
#   'AR': 1.2,
#   'FA': 626.35,
#   'V': 1578.49,
#   'EUI': 145.74},
#  196: {'L': 31.415,
#   'W': 16.6225,
#   'H': 2.97,
#   'WWR': 0.27,
#   'AR': 1.89,
#   'FA': 522.11,
#   'V': 1550.92,
#   'EUI': 146.37},
#  197: {'L': 26.0165,
#   'W': 15.7685,
#   'H': 3.47,
#   'WWR': 0.45,
#   'AR': 1.65,
#   'FA': 410.17,
#   'V': 1423.54,
#   'EUI': 170.98},
#  198: {'L': 30.927,
#   'W': 15.1585,
#   'H': 3.14,
#   'WWR': 0.29,
#   'AR': 2.04,
#   'FA': 468.79,
#   'V': 1472.05,
#   'EUI': 152.05},
#  199: {'L': 42.1815,
#   'W': 17.507,
#   'H': 2.47,
#   'WWR': 0.38,
#   'AR': 2.41,
#   'FA': 738.39,
#   'V': 1824.02,
#   'EUI': 142.27},
#  200: {'L': 22.1125,
#   'W': 16.6225,
#   'H': 2.93,
#   'WWR': 0.21,
#   'AR': 1.33,
#   'FA': 367.52,
#   'V': 1076.97,
#   'EUI': 147.0},
#  201: {'L': 25.864,
#   'W': 11.346,
#   'H': 2.58,
#   'WWR': 0.18,
#   'AR': 2.28,
#   'FA': 293.39,
#   'V': 757.11,
#   'EUI': 146.37},
#  202: {'L': 35.319,
#   'W': 15.1585,
#   'H': 3.07,
#   'WWR': 0.31,
#   'AR': 2.33,
#   'FA': 535.31,
#   'V': 1643.63,
#   'EUI': 150.79},
#  203: {'L': 43.981,
#   'W': 15.067,
#   'H': 3.65,
#   'WWR': 0.45,
#   'AR': 2.92,
#   'FA': 662.58,
#   'V': 2418.72,
#   'EUI': 165.3},
#  204: {'L': 39.3145,
#   'W': 13.847,
#   'H': 2.9,
#   'WWR': 0.35,
#   'AR': 2.84,
#   'FA': 544.32,
#   'V': 1578.72,
#   'EUI': 152.37},
#  205: {'L': 36.3255,
#   'W': 16.4395,
#   'H': 3.49,
#   'WWR': 0.45,
#   'AR': 2.21,
#   'FA': 597.09,
#   'V': 2084.13,
#   'EUI': 163.09},
#  206: {'L': 21.3195,
#   'W': 11.285,
#   'H': 3.41,
#   'WWR': 0.25,
#   'AR': 1.89,
#   'FA': 240.53,
#   'V': 820.41,
#   'EUI': 167.82},
#  207: {'L': 24.8575,
#   'W': 15.3415,
#   'H': 2.89,
#   'WWR': 0.32,
#   'AR': 1.62,
#   'FA': 381.27,
#   'V': 1102.11,
#   'EUI': 153.94},
#  208: {'L': 31.9945,
#   'W': 23.5155,
#   'H': 2.99,
#   'WWR': 0.45,
#   'AR': 1.36,
#   'FA': 752.33,
#   'V': 2249.58,
#   'EUI': 149.21},
#  209: {'L': 38.8875,
#   'W': 16.1345,
#   'H': 2.75,
#   'WWR': 0.46,
#   'AR': 2.41,
#   'FA': 627.37,
#   'V': 1725.43,
#   'EUI': 152.68},
#  210: {'L': 28.7005,
#   'W': 20.801,
#   'H': 2.48,
#   'WWR': 0.54,
#   'AR': 1.38,
#   'FA': 596.99,
#   'V': 1480.56,
#   'EUI': 151.1},
#  211: {'L': 36.0815,
#   'W': 20.74,
#   'H': 3.38,
#   'WWR': 0.36,
#   'AR': 1.74,
#   'FA': 748.24,
#   'V': 2529.36,
#   'EUI': 149.53},
#  212: {'L': 30.8965,
#   'W': 24.339,
#   'H': 2.9,
#   'WWR': 0.5,
#   'AR': 1.27,
#   'FA': 751.96,
#   'V': 2180.77,
#   'EUI': 150.47},
#  213: {'L': 33.0315,
#   'W': 11.712,
#   'H': 3.3,
#   'WWR': 0.17,
#   'AR': 2.82,
#   'FA': 386.85,
#   'V': 1276.65,
#   'EUI': 151.1},
#  214: {'L': 22.021,
#   'W': 19.4895,
#   'H': 3.57,
#   'WWR': 0.46,
#   'AR': 1.13,
#   'FA': 429.12,
#   'V': 1532.17,
#   'EUI': 170.98},
#  215: {'L': 24.1255,
#   'W': 11.712,
#   'H': 3.41,
#   'WWR': 0.44,
#   'AR': 2.06,
#   'FA': 282.52,
#   'V': 963.52,
#   'EUI': 183.28},
#  216: {'L': 42.7,
#   'W': 16.7445,
#   'H': 2.77,
#   'WWR': 0.43,
#   'AR': 2.55,
#   'FA': 714.98,
#   'V': 1980.52,
#   'EUI': 149.53},
#  217: {'L': 29.9815,
#   'W': 10.065,
#   'H': 3.58,
#   'WWR': 0.4,
#   'AR': 2.98,
#   'FA': 301.75,
#   'V': 1080.31,
#   'EUI': 185.17},
#  218: {'L': 40.6565,
#   'W': 16.1955,
#   'H': 3.65,
#   'WWR': 0.23,
#   'AR': 2.51,
#   'FA': 658.4,
#   'V': 2403.35,
#   'EUI': 148.58},
#  219: {'L': 22.814,
#   'W': 22.3565,
#   'H': 3.49,
#   'WWR': 0.5,
#   'AR': 1.02,
#   'FA': 510.04,
#   'V': 1780.04,
#   'EUI': 167.82},
#  220: {'L': 33.7635,
#   'W': 20.2215,
#   'H': 2.8,
#   'WWR': 0.51,
#   'AR': 1.67,
#   'FA': 682.74,
#   'V': 1911.7,
#   'EUI': 152.37},
#  221: {'L': 19.9165,
#   'W': 16.592,
#   'H': 2.6,
#   'WWR': 0.2,
#   'AR': 1.2,
#   'FA': 330.36,
#   'V': 859.18,
#   'EUI': 144.16},
#  222: {'L': 36.3255,
#   'W': 16.592,
#   'H': 2.58,
#   'WWR': 0.46,
#   'AR': 2.19,
#   'FA': 602.66,
#   'V': 1555.0,
#   'EUI': 150.47},
#  223: {'L': 27.3585,
#   'W': 10.7665,
#   'H': 3.18,
#   'WWR': 0.24,
#   'AR': 2.54,
#   'FA': 294.5,
#   'V': 936.69,
#   'EUI': 160.57},
#  224: {'L': 26.718,
#   'W': 9.5465,
#   'H': 3.39,
#   'WWR': 0.27,
#   'AR': 2.8,
#   'FA': 255.02,
#   'V': 864.66,
#   'EUI': 171.93},
#  225: {'L': 29.2495,
#   'W': 11.895,
#   'H': 3.03,
#   'WWR': 0.19,
#   'AR': 2.46,
#   'FA': 347.83,
#   'V': 1054.21,
#   'EUI': 150.47},
#  226: {'L': 34.282,
#   'W': 21.167,
#   'H': 3.64,
#   'WWR': 0.3,
#   'AR': 1.62,
#   'FA': 725.57,
#   'V': 2641.36,
#   'EUI': 148.9},
#  227: {'L': 36.417,
#   'W': 18.3,
#   'H': 2.78,
#   'WWR': 0.24,
#   'AR': 1.99,
#   'FA': 666.39,
#   'V': 1852.68,
#   'EUI': 139.75},
#  228: {'L': 26.596,
#   'W': 11.3155,
#   'H': 3.04,
#   'WWR': 0.54,
#   'AR': 2.35,
#   'FA': 300.91,
#   'V': 914.88,
#   'EUI': 184.23},
#  229: {'L': 23.9425,
#   'W': 23.241,
#   'H': 3.5,
#   'WWR': 0.45,
#   'AR': 1.03,
#   'FA': 556.4,
#   'V': 1947.57,
#   'EUI': 162.15},
#  230: {'L': 28.975,
#   'W': 16.7445,
#   'H': 2.9,
#   'WWR': 0.42,
#   'AR': 1.73,
#   'FA': 485.14,
#   'V': 1407.0,
#   'EUI': 155.84},
#  231: {'L': 17.69,
#   'W': 12.7185,
#   'H': 2.76,
#   'WWR': 0.47,
#   'AR': 1.39,
#   'FA': 224.92,
#   'V': 620.97,
#   'EUI': 176.97},
#  232: {'L': 18.849,
#   'W': 13.2675,
#   'H': 2.54,
#   'WWR': 0.26,
#   'AR': 1.42,
#   'FA': 250.0,
#   'V': 635.2,
#   'EUI': 152.68},
#  233: {'L': 35.38,
#   'W': 13.054,
#   'H': 2.98,
#   'WWR': 0.3,
#   'AR': 2.71,
#   'FA': 461.82,
#   'V': 1376.31,
#   'EUI': 153.0},
#  234: {'L': 31.0185,
#   'W': 16.409,
#   'H': 3.43,
#   'WWR': 0.42,
#   'AR': 1.89,
#   'FA': 508.92,
#   'V': 1745.81,
#   'EUI': 162.78},
#  235: {'L': 33.0925,
#   'W': 12.3525,
#   'H': 2.62,
#   'WWR': 0.25,
#   'AR': 2.68,
#   'FA': 408.77,
#   'V': 1070.99,
#   'EUI': 147.0},
#  236: {'L': 36.295,
#   'W': 18.3305,
#   'H': 2.89,
#   'WWR': 0.32,
#   'AR': 1.98,
#   'FA': 665.28,
#   'V': 1922.73,
#   'EUI': 144.8},
#  237: {'L': 25.132,
#   'W': 15.799,
#   'H': 3.43,
#   'WWR': 0.2,
#   'AR': 1.59,
#   'FA': 396.97,
#   'V': 1361.92,
#   'EUI': 151.1},
#  238: {'L': 22.1735,
#   'W': 12.383,
#   'H': 2.69,
#   'WWR': 0.3,
#   'AR': 1.79,
#   'FA': 274.53,
#   'V': 738.61,
#   'EUI': 156.78},
#  239: {'L': 23.485,
#   'W': 14.0605,
#   'H': 2.94,
#   'WWR': 0.54,
#   'AR': 1.67,
#   'FA': 330.18,
#   'V': 970.82,
#   'EUI': 175.4},
#  240: {'L': 26.718,
#   'W': 13.6335,
#   'H': 2.84,
#   'WWR': 0.39,
#   'AR': 1.96,
#   'FA': 364.18,
#   'V': 1034.5,
#   'EUI': 160.25},
#  241: {'L': 28.182,
#   'W': 25.1625,
#   'H': 2.56,
#   'WWR': 0.48,
#   'AR': 1.12,
#   'FA': 709.13,
#   'V': 1815.37,
#   'EUI': 146.37},
#  242: {'L': 27.572,
#   'W': 13.786,
#   'H': 3.43,
#   'WWR': 0.25,
#   'AR': 2.0,
#   'FA': 380.07,
#   'V': 1303.77,
#   'EUI': 157.1},
#  243: {'L': 24.4305,
#   'W': 12.7185,
#   'H': 3.6,
#   'WWR': 0.2,
#   'AR': 1.92,
#   'FA': 310.67,
#   'V': 1118.59,
#   'EUI': 158.99},
#  244: {'L': 29.6155,
#   'W': 11.529,
#   'H': 2.74,
#   'WWR': 0.21,
#   'AR': 2.57,
#   'FA': 341.42,
#   'V': 935.54,
#   'EUI': 148.9},
#  245: {'L': 34.16,
#   'W': 14.7925,
#   'H': 3.38,
#   'WWR': 0.37,
#   'AR': 2.31,
#   'FA': 505.3,
#   'V': 1707.95,
#   'EUI': 160.25},
#  246: {'L': 41.602,
#   'W': 14.2435,
#   'H': 2.65,
#   'WWR': 0.41,
#   'AR': 2.92,
#   'FA': 592.54,
#   'V': 1570.28,
#   'EUI': 151.42},
#  247: {'L': 40.809,
#   'W': 16.653,
#   'H': 3.08,
#   'WWR': 0.31,
#   'AR': 2.45,
#   'FA': 679.59,
#   'V': 2093.14,
#   'EUI': 147.0},
#  248: {'L': 26.108,
#   'W': 15.006,
#   'H': 2.78,
#   'WWR': 0.3,
#   'AR': 1.74,
#   'FA': 391.77,
#   'V': 1089.14,
#   'EUI': 150.79},
#  249: {'L': 41.5715,
#   'W': 14.091,
#   'H': 3.04,
#   'WWR': 0.35,
#   'AR': 2.95,
#   'FA': 585.75,
#   'V': 1780.78,
#   'EUI': 153.0},
#  250: {'L': 30.5915,
#   'W': 15.7685,
#   'H': 3.5,
#   'WWR': 0.21,
#   'AR': 1.94,
#   'FA': 482.35,
#   'V': 1688.34,
#   'EUI': 149.84},
#  251: {'L': 37.149,
#   'W': 13.0845,
#   'H': 3.11,
#   'WWR': 0.41,
#   'AR': 2.84,
#   'FA': 486.07,
#   'V': 1511.7,
#   'EUI': 162.15},
#  252: {'L': 25.742,
#   'W': 10.4615,
#   'H': 3.02,
#   'WWR': 0.19,
#   'AR': 2.46,
#   'FA': 269.23,
#   'V': 813.29,
#   'EUI': 155.52},
#  253: {'L': 27.6025,
#   'W': 10.614,
#   'H': 2.65,
#   'WWR': 0.54,
#   'AR': 2.6,
#   'FA': 292.92,
#   'V': 776.38,
#   'EUI': 177.29},
#  254: {'L': 30.683,
#   'W': 11.6205,
#   'H': 3.21,
#   'WWR': 0.39,
#   'AR': 2.64,
#   'FA': 356.47,
#   'V': 1144.53,
#   'EUI': 169.72},
#  255: {'L': 17.2935,
#   'W': 14.1825,
#   'H': 3.14,
#   'WWR': 0.49,
#   'AR': 1.22,
#   'FA': 245.26,
#   'V': 770.13,
#   'EUI': 184.23},
#  256: {'L': 40.2905,
#   'W': 17.5985,
#   'H': 3.05,
#   'WWR': 0.37,
#   'AR': 2.29,
#   'FA': 709.04,
#   'V': 2162.61,
#   'EUI': 148.9},
#  257: {'L': 26.4435,
#   'W': 13.0235,
#   'H': 2.62,
#   'WWR': 0.41,
#   'AR': 2.03,
#   'FA': 344.3,
#   'V': 902.29,
#   'EUI': 159.31},
#  258: {'L': 40.3515,
#   'W': 15.5245,
#   'H': 2.63,
#   'WWR': 0.3,
#   'AR': 2.6,
#   'FA': 626.35,
#   'V': 1647.53,
#   'EUI': 143.22},
#  259: {'L': 40.687,
#   'W': 15.8905,
#   'H': 2.89,
#   'WWR': 0.22,
#   'AR': 2.56,
#   'FA': 646.51,
#   'V': 1868.49,
#   'EUI': 141.01},
#  260: {'L': 21.411,
#   'W': 10.492,
#   'H': 2.59,
#   'WWR': 0.48,
#   'AR': 2.04,
#   'FA': 224.64,
#   'V': 581.83,
#   'EUI': 176.66},
#  261: {'L': 23.1495,
#   'W': 16.653,
#   'H': 3.45,
#   'WWR': 0.53,
#   'AR': 1.39,
#   'FA': 385.45,
#   'V': 1330.0,
#   'EUI': 178.55},
#  262: {'L': 23.2105,
#   'W': 13.725,
#   'H': 3.47,
#   'WWR': 0.22,
#   'AR': 1.69,
#   'FA': 318.47,
#   'V': 1105.42,
#   'EUI': 158.04},
#  263: {'L': 24.1255,
#   'W': 18.422,
#   'H': 2.77,
#   'WWR': 0.44,
#   'AR': 1.31,
#   'FA': 444.36,
#   'V': 1231.1,
#   'EUI': 156.15},
#  264: {'L': 18.6355,
#   'W': 18.4525,
#   'H': 3.12,
#   'WWR': 0.29,
#   'AR': 1.01,
#   'FA': 343.83,
#   'V': 1072.88,
#   'EUI': 156.47},
#  265: {'L': 23.363,
#   'W': 20.862,
#   'H': 2.8,
#   'WWR': 0.4,
#   'AR': 1.12,
#   'FA': 487.37,
#   'V': 1364.72,
#   'EUI': 152.05},
#  266: {'L': 42.517,
#   'W': 16.8665,
#   'H': 3.03,
#   'WWR': 0.34,
#   'AR': 2.52,
#   'FA': 717.03,
#   'V': 2172.85,
#   'EUI': 147.32},
#  267: {'L': 37.088,
#   'W': 18.727,
#   'H': 3.56,
#   'WWR': 0.3,
#   'AR': 1.98,
#   'FA': 694.54,
#   'V': 2472.59,
#   'EUI': 149.84},
#  268: {'L': 37.21,
#   'W': 15.8295,
#   'H': 3.21,
#   'WWR': 0.51,
#   'AR': 2.35,
#   'FA': 589.01,
#   'V': 1890.74,
#   'EUI': 164.04},
#  269: {'L': 21.594,
#   'W': 16.348,
#   'H': 2.55,
#   'WWR': 0.18,
#   'AR': 1.32,
#   'FA': 352.94,
#   'V': 900.2,
#   'EUI': 141.64},
#  270: {'L': 22.631,
#   'W': 16.043,
#   'H': 3.24,
#   'WWR': 0.36,
#   'AR': 1.41,
#   'FA': 363.06,
#   'V': 1176.34,
#   'EUI': 162.78},
#  271: {'L': 22.3565,
#   'W': 16.1955,
#   'H': 2.91,
#   'WWR': 0.48,
#   'AR': 1.38,
#   'FA': 362.04,
#   'V': 1053.64,
#   'EUI': 166.25},
#  272: {'L': 36.6915,
#   'W': 16.9885,
#   'H': 3.59,
#   'WWR': 0.47,
#   'AR': 2.16,
#   'FA': 623.29,
#   'V': 2237.77,
#   'EUI': 164.67},
#  273: {'L': 32.6045,
#   'W': 20.252,
#   'H': 3.04,
#   'WWR': 0.33,
#   'AR': 1.61,
#   'FA': 660.26,
#   'V': 2007.33,
#   'EUI': 146.06},
#  274: {'L': 39.894,
#   'W': 18.727,
#   'H': 2.48,
#   'WWR': 0.34,
#   'AR': 2.13,
#   'FA': 747.03,
#   'V': 1852.8,
#   'EUI': 140.06},
#  275: {'L': 29.5545,
#   'W': 15.006,
#   'H': 3.46,
#   'WWR': 0.5,
#   'AR': 1.97,
#   'FA': 443.43,
#   'V': 1534.49,
#   'EUI': 173.82},
#  276: {'L': 20.557,
#   'W': 17.4155,
#   'H': 3.36,
#   'WWR': 0.16,
#   'AR': 1.18,
#   'FA': 357.96,
#   'V': 1202.92,
#   'EUI': 148.58},
#  277: {'L': 37.393,
#   'W': 16.6225,
#   'H': 2.65,
#   'WWR': 0.49,
#   'AR': 2.25,
#   'FA': 621.52,
#   'V': 1647.15,
#   'EUI': 152.68},
#  278: {'L': 30.5305,
#   'W': 17.446,
#   'H': 2.94,
#   'WWR': 0.41,
#   'AR': 1.75,
#   'FA': 532.61,
#   'V': 1565.95,
#   'EUI': 153.94},
#  279: {'L': 27.389,
#   'W': 19.703,
#   'H': 3.38,
#   'WWR': 0.34,
#   'AR': 1.39,
#   'FA': 539.58,
#   'V': 1824.0,
#   'EUI': 153.94},
#  280: {'L': 39.8635,
#   'W': 17.873,
#   'H': 2.76,
#   'WWR': 0.45,
#   'AR': 2.23,
#   'FA': 712.47,
#   'V': 1966.45,
#   'EUI': 149.21},
#  281: {'L': 37.088,
#   'W': 19.947,
#   'H': 2.76,
#   'WWR': 0.28,
#   'AR': 1.86,
#   'FA': 739.79,
#   'V': 2041.83,
#   'EUI': 139.75},
#  282: {'L': 21.228,
#   'W': 21.228,
#   'H': 2.93,
#   'WWR': 0.31,
#   'AR': 1.0,
#   'FA': 450.58,
#   'V': 1320.34,
#   'EUI': 149.84},
#  283: {'L': 40.9615,
#   'W': 15.2805,
#   'H': 2.99,
#   'WWR': 0.52,
#   'AR': 2.68,
#   'FA': 625.89,
#   'V': 1871.48,
#   'EUI': 160.88},
#  284: {'L': 34.16,
#   'W': 20.7095,
#   'H': 3.15,
#   'WWR': 0.36,
#   'AR': 1.65,
#   'FA': 707.36,
#   'V': 2228.43,
#   'EUI': 147.95},
#  285: {'L': 30.4085,
#   'W': 12.4135,
#   'H': 2.73,
#   'WWR': 0.44,
#   'AR': 2.45,
#   'FA': 377.46,
#   'V': 1030.51,
#   'EUI': 163.09},
#  286: {'L': 34.2515,
#   'W': 14.579,
#   'H': 3.53,
#   'WWR': 0.46,
#   'AR': 2.35,
#   'FA': 499.26,
#   'V': 1762.71,
#   'EUI': 169.72},
#  287: {'L': 36.478,
#   'W': 12.2,
#   'H': 3.12,
#   'WWR': 0.38,
#   'AR': 2.99,
#   'FA': 445.01,
#   'V': 1388.5,
#   'EUI': 162.78},
#  288: {'L': 30.1645,
#   'W': 20.252,
#   'H': 2.83,
#   'WWR': 0.34,
#   'AR': 1.49,
#   'FA': 610.84,
#   'V': 1728.82,
#   'EUI': 145.43},
#  289: {'L': 30.5305,
#   'W': 21.655,
#   'H': 3.47,
#   'WWR': 0.51,
#   'AR': 1.41,
#   'FA': 661.1,
#   'V': 2294.15,
#   'EUI': 161.83},
#  290: {'L': 37.6675,
#   'W': 17.934,
#   'H': 3.12,
#   'WWR': 0.28,
#   'AR': 2.1,
#   'FA': 675.5,
#   'V': 2107.65,
#   'EUI': 145.11},
#  291: {'L': 33.3365,
#   'W': 15.9515,
#   'H': 2.58,
#   'WWR': 0.54,
#   'AR': 2.09,
#   'FA': 531.68,
#   'V': 1371.96,
#   'EUI': 157.1},
#  292: {'L': 26.0165,
#   'W': 24.095,
#   'H': 2.81,
#   'WWR': 0.42,
#   'AR': 1.08,
#   'FA': 626.82,
#   'V': 1761.5,
#   'EUI': 148.58},
#  293: {'L': 21.96,
#   'W': 11.2545,
#   'H': 3.32,
#   'WWR': 0.18,
#   'AR': 1.95,
#   'FA': 247.12,
#   'V': 820.53,
#   'EUI': 158.99},
#  294: {'L': 23.8815,
#   'W': 13.054,
#   'H': 3.08,
#   'WWR': 0.42,
#   'AR': 1.83,
#   'FA': 311.69,
#   'V': 960.19,
#   'EUI': 170.35},
#  295: {'L': 39.04,
#   'W': 13.237,
#   'H': 3.61,
#   'WWR': 0.41,
#   'AR': 2.95,
#   'FA': 516.73,
#   'V': 1865.55,
#   'EUI': 168.77},
#  296: {'L': 34.099,
#   'W': 12.871,
#   'H': 2.88,
#   'WWR': 0.32,
#   'AR': 2.65,
#   'FA': 438.87,
#   'V': 1264.0,
#   'EUI': 153.94},
#  297: {'L': 32.4825,
#   'W': 20.435,
#   'H': 3.36,
#   'WWR': 0.49,
#   'AR': 1.59,
#   'FA': 663.7,
#   'V': 2230.3,
#   'EUI': 158.99},
#  298: {'L': 35.5935,
#   'W': 12.627,
#   'H': 2.76,
#   'WWR': 0.23,
#   'AR': 2.82,
#   'FA': 449.37,
#   'V': 1240.45,
#   'EUI': 146.37},
#  299: {'L': 21.167,
#   'W': 14.396,
#   'H': 2.52,
#   'WWR': 0.25,
#   'AR': 1.47,
#   'FA': 304.63,
#   'V': 767.89,
#   'EUI': 147.95},
#  300: {'L': 26.962,
#   'W': 20.74,
#   'H': 3.09,
#   'WWR': 0.48,
#   'AR': 1.3,
#   'FA': 559.18,
#   'V': 1727.9,
#   'EUI': 158.04},
#  301: {'L': 40.992,
#   'W': 15.5855,
#   'H': 2.88,
#   'WWR': 0.27,
#   'AR': 2.63,
#   'FA': 638.8,
#   'V': 1839.98,
#   'EUI': 144.16},
#  302: {'L': 28.5175,
#   'W': 15.25,
#   'H': 3.02,
#   'WWR': 0.33,
#   'AR': 1.87,
#   'FA': 434.88,
#   'V': 1313.37,
#   'EUI': 154.26},
#  303: {'L': 29.0665,
#   'W': 10.492,
#   'H': 3.17,
#   'WWR': 0.19,
#   'AR': 2.77,
#   'FA': 304.91,
#   'V': 966.74,
#   'EUI': 155.84},
#  304: {'L': 21.9295,
#   'W': 13.054,
#   'H': 2.85,
#   'WWR': 0.28,
#   'AR': 1.68,
#   'FA': 286.23,
#   'V': 815.86,
#   'EUI': 156.47},
#  305: {'L': 38.2775,
#   'W': 14.335,
#   'H': 2.44,
#   'WWR': 0.34,
#   'AR': 2.67,
#   'FA': 548.69,
#   'V': 1338.85,
#   'EUI': 145.43},
#  306: {'L': 26.8095,
#   'W': 8.9975,
#   'H': 3.61,
#   'WWR': 0.48,
#   'AR': 2.98,
#   'FA': 241.18,
#   'V': 870.8,
#   'EUI': 205.05},
#  307: {'L': 28.121,
#   'W': 21.1365,
#   'H': 2.88,
#   'WWR': 0.25,
#   'AR': 1.33,
#   'FA': 594.3,
#   'V': 1711.81,
#   'EUI': 141.64},
#  308: {'L': 34.4345,
#   'W': 19.2455,
#   'H': 2.48,
#   'WWR': 0.22,
#   'AR': 1.79,
#   'FA': 662.68,
#   'V': 1643.52,
#   'EUI': 135.96},
#  309: {'L': 20.4655,
#   'W': 11.834,
#   'H': 3.47,
#   'WWR': 0.2,
#   'AR': 1.73,
#   'FA': 242.11,
#   'V': 840.39,
#   'EUI': 162.78},
#  310: {'L': 24.0035,
#   'W': 11.3765,
#   'H': 2.73,
#   'WWR': 0.35,
#   'AR': 2.11,
#   'FA': 273.04,
#   'V': 745.5,
#   'EUI': 162.78},
#  311: {'L': 36.844,
#   'W': 12.322,
#   'H': 3.1,
#   'WWR': 0.53,
#   'AR': 2.99,
#   'FA': 453.92,
#   'V': 1407.37,
#   'EUI': 173.82},
#  312: {'L': 30.256,
#   'W': 14.274,
#   'H': 3.49,
#   'WWR': 0.54,
#   'AR': 2.12,
#   'FA': 431.81,
#   'V': 1507.24,
#   'EUI': 179.5},
#  313: {'L': 22.6615,
#   'W': 21.3805,
#   'H': 2.79,
#   'WWR': 0.2,
#   'AR': 1.06,
#   'FA': 484.49,
#   'V': 1351.79,
#   'EUI': 140.69},
#  314: {'L': 24.217,
#   'W': 15.128,
#   'H': 3.04,
#   'WWR': 0.34,
#   'AR': 1.6,
#   'FA': 366.32,
#   'V': 1113.72,
#   'EUI': 158.36},
#  315: {'L': 29.036,
#   'W': 9.9125,
#   'H': 3.23,
#   'WWR': 0.36,
#   'AR': 2.93,
#   'FA': 287.81,
#   'V': 929.66,
#   'EUI': 175.4},
#  316: {'L': 25.559,
#   'W': 17.507,
#   'H': 2.53,
#   'WWR': 0.42,
#   'AR': 1.46,
#   'FA': 447.42,
#   'V': 1132.08,
#   'EUI': 151.42},
#  317: {'L': 34.3735,
#   'W': 13.3285,
#   'H': 3.23,
#   'WWR': 0.36,
#   'AR': 2.58,
#   'FA': 458.1,
#   'V': 1479.82,
#   'EUI': 160.57},
#  318: {'L': 34.099,
#   'W': 11.9255,
#   'H': 3.1,
#   'WWR': 0.41,
#   'AR': 2.86,
#   'FA': 406.64,
#   'V': 1260.61,
#   'EUI': 166.88},
#  319: {'L': 27.572,
#   'W': 17.9035,
#   'H': 2.69,
#   'WWR': 0.43,
#   'AR': 1.54,
#   'FA': 493.59,
#   'V': 1327.88,
#   'EUI': 152.68},
#  320: {'L': 23.119,
#   'W': 13.359,
#   'H': 2.75,
#   'WWR': 0.37,
#   'AR': 1.73,
#   'FA': 308.81,
#   'V': 849.33,
#   'EUI': 160.57},
#  321: {'L': 23.2105,
#   'W': 13.115,
#   'H': 2.55,
#   'WWR': 0.2,
#   'AR': 1.77,
#   'FA': 304.35,
#   'V': 776.23,
#   'EUI': 145.74},
#  322: {'L': 38.5825,
#   'W': 15.25,
#   'H': 2.96,
#   'WWR': 0.23,
#   'AR': 2.53,
#   'FA': 588.35,
#   'V': 1741.61,
#   'EUI': 143.53},
#  323: {'L': 28.0295,
#   'W': 21.228,
#   'H': 3.37,
#   'WWR': 0.4,
#   'AR': 1.32,
#   'FA': 594.95,
#   'V': 2005.18,
#   'EUI': 155.52},
#  324: {'L': 34.9835,
#   'W': 20.0995,
#   'H': 3.1,
#   'WWR': 0.16,
#   'AR': 1.74,
#   'FA': 703.09,
#   'V': 2179.77,
#   'EUI': 137.22},
#  325: {'L': 24.1865,
#   'W': 14.152,
#   'H': 3.61,
#   'WWR': 0.55,
#   'AR': 1.71,
#   'FA': 342.25,
#   'V': 1235.66,
#   'EUI': 189.28},
#  326: {'L': 32.513,
#   'W': 22.4175,
#   'H': 2.5,
#   'WWR': 0.51,
#   'AR': 1.45,
#   'FA': 728.82,
#   'V': 1822.15,
#   'EUI': 146.69},
#  327: {'L': 25.7725,
#   'W': 11.163,
#   'H': 2.82,
#   'WWR': 0.52,
#   'AR': 2.31,
#   'FA': 287.63,
#   'V': 811.31,
#   'EUI': 178.55},
#  328: {'L': 20.0995,
#   'W': 15.5855,
#   'H': 3.5,
#   'WWR': 0.26,
#   'AR': 1.29,
#   'FA': 313.18,
#   'V': 1096.41,
#   'EUI': 161.52},
#  329: {'L': 41.0225,
#   'W': 16.47,
#   'H': 2.47,
#   'WWR': 0.24,
#   'AR': 2.49,
#   'FA': 675.59,
#   'V': 1668.83,
#   'EUI': 137.54},
#  330: {'L': 27.816,
#   'W': 23.363,
#   'H': 2.77,
#   'WWR': 0.29,
#   'AR': 1.19,
#   'FA': 649.86,
#   'V': 1800.13,
#   'EUI': 141.01},
#  331: {'L': 21.716,
#   'W': 20.679,
#   'H': 3.49,
#   'WWR': 0.31,
#   'AR': 1.05,
#   'FA': 449.0,
#   'V': 1567.24,
#   'EUI': 156.78},
#  332: {'L': 29.951,
#   'W': 21.8685,
#   'H': 3.65,
#   'WWR': 0.33,
#   'AR': 1.37,
#   'FA': 654.97,
#   'V': 2390.69,
#   'EUI': 152.37},
#  333: {'L': 35.0445,
#   'W': 20.374,
#   'H': 3.09,
#   'WWR': 0.4,
#   'AR': 1.72,
#   'FA': 713.96,
#   'V': 2206.25,
#   'EUI': 149.53},
#  334: {'L': 24.461,
#   'W': 15.5855,
#   'H': 3.07,
#   'WWR': 0.51,
#   'AR': 1.57,
#   'FA': 381.18,
#   'V': 1170.4,
#   'EUI': 170.66},
#  335: {'L': 21.716,
#   'W': 12.4135,
#   'H': 3.17,
#   'WWR': 0.46,
#   'AR': 1.75,
#   'FA': 269.51,
#   'V': 854.54,
#   'EUI': 180.13},
#  336: {'L': 36.4475,
#   'W': 15.067,
#   'H': 3.06,
#   'WWR': 0.39,
#   'AR': 2.42,
#   'FA': 549.06,
#   'V': 1680.41,
#   'EUI': 155.52},
#  337: {'L': 27.2975,
#   'W': 18.5745,
#   'H': 2.79,
#   'WWR': 0.41,
#   'AR': 1.47,
#   'FA': 506.97,
#   'V': 1414.63,
#   'EUI': 152.05},
#  338: {'L': 26.84,
#   'W': 12.8405,
#   'H': 2.69,
#   'WWR': 0.36,
#   'AR': 2.09,
#   'FA': 344.58,
#   'V': 927.08,
#   'EUI': 157.41},
#  339: {'L': 33.672,
#   'W': 13.054,
#   'H': 3.01,
#   'WWR': 0.32,
#   'AR': 2.58,
#   'FA': 439.52,
#   'V': 1323.06,
#   'EUI': 155.52},
#  340: {'L': 33.001,
#   'W': 18.544,
#   'H': 3.15,
#   'WWR': 0.26,
#   'AR': 1.78,
#   'FA': 611.95,
#   'V': 1927.71,
#   'EUI': 145.11},
#  341: {'L': 26.23,
#   'W': 9.6075,
#   'H': 3.6,
#   'WWR': 0.46,
#   'AR': 2.73,
#   'FA': 251.95,
#   'V': 907.22,
#   'EUI': 198.74},
#  342: {'L': 33.7635,
#   'W': 19.398,
#   'H': 2.57,
#   'WWR': 0.32,
#   'AR': 1.74,
#   'FA': 654.87,
#   'V': 1683.21,
#   'EUI': 141.01},
#  343: {'L': 39.406,
#   'W': 16.0125,
#   'H': 3.63,
#   'WWR': 0.27,
#   'AR': 2.46,
#   'FA': 630.9,
#   'V': 2290.49,
#   'EUI': 151.74},
#  344: {'L': 45.4145,
#   'W': 15.189,
#   'H': 2.71,
#   'WWR': 0.2,
#   'AR': 2.99,
#   'FA': 689.71,
#   'V': 1869.36,
#   'EUI': 138.49},
#  345: {'L': 28.1515,
#   'W': 20.557,
#   'H': 3.51,
#   'WWR': 0.37,
#   'AR': 1.37,
#   'FA': 578.69,
#   'V': 2031.27,
#   'EUI': 156.15},
#  346: {'L': 39.345,
#   'W': 14.152,
#   'H': 2.8,
#   'WWR': 0.32,
#   'AR': 2.78,
#   'FA': 556.77,
#   'V': 1559.07,
#   'EUI': 148.58},
#  347: {'L': 33.6415,
#   'W': 16.409,
#   'H': 3.66,
#   'WWR': 0.4,
#   'AR': 2.05,
#   'FA': 551.94,
#   'V': 2020.41,
#   'EUI': 163.09},
#  348: {'L': 25.681,
#   'W': 16.5615,
#   'H': 3.44,
#   'WWR': 0.49,
#   'AR': 1.55,
#   'FA': 425.31,
#   'V': 1463.09,
#   'EUI': 172.24},
#  349: {'L': 32.1775,
#   'W': 13.237,
#   'H': 3.65,
#   'WWR': 0.36,
#   'AR': 2.43,
#   'FA': 425.87,
#   'V': 1554.66,
#   'EUI': 168.14},
#  350: {'L': 37.4845,
#   'W': 14.3045,
#   'H': 3.32,
#   'WWR': 0.51,
#   'AR': 2.62,
#   'FA': 536.14,
#   'V': 1780.17,
#   'EUI': 169.4},
#  351: {'L': 40.1075,
#   'W': 17.2935,
#   'H': 3.29,
#   'WWR': 0.47,
#   'AR': 2.32,
#   'FA': 693.52,
#   'V': 2281.94,
#   'EUI': 158.36},
#  352: {'L': 33.7025,
#   'W': 15.5245,
#   'H': 3.61,
#   'WWR': 0.55,
#   'AR': 2.17,
#   'FA': 523.14,
#   'V': 1888.8,
#   'EUI': 176.34},
#  353: {'L': 22.8445,
#   'W': 18.8795,
#   'H': 2.81,
#   'WWR': 0.24,
#   'AR': 1.21,
#   'FA': 431.26,
#   'V': 1211.93,
#   'EUI': 144.8},
#  354: {'L': 33.794,
#   'W': 18.361,
#   'H': 3.62,
#   'WWR': 0.38,
#   'AR': 1.84,
#   'FA': 620.41,
#   'V': 2246.18,
#   'EUI': 157.73},
#  355: {'L': 24.4305,
#   'W': 13.725,
#   'H': 2.9,
#   'WWR': 0.26,
#   'AR': 1.78,
#   'FA': 335.29,
#   'V': 972.39,
#   'EUI': 152.68},
#  356: {'L': 38.186,
#   'W': 15.5855,
#   'H': 3.46,
#   'WWR': 0.45,
#   'AR': 2.45,
#   'FA': 595.14,
#   'V': 2059.21,
#   'EUI': 163.72},
#  357: {'L': 28.3955,
#   'W': 19.1845,
#   'H': 2.57,
#   'WWR': 0.39,
#   'AR': 1.48,
#   'FA': 544.69,
#   'V': 1400.02,
#   'EUI': 147.0},
#  358: {'L': 33.245,
#   'W': 15.4635,
#   'H': 2.87,
#   'WWR': 0.54,
#   'AR': 2.15,
#   'FA': 514.03,
#   'V': 1475.42,
#   'EUI': 163.09},
#  359: {'L': 26.8705,
#   'W': 13.237,
#   'H': 3.36,
#   'WWR': 0.28,
#   'AR': 2.03,
#   'FA': 355.63,
#   'V': 1195.1,
#   'EUI': 160.25},
#  360: {'L': 27.267,
#   'W': 9.15,
#   'H': 3.03,
#   'WWR': 0.19,
#   'AR': 2.98,
#   'FA': 249.44,
#   'V': 755.96,
#   'EUI': 158.99},
#  361: {'L': 21.1365,
#   'W': 10.675,
#   'H': 3.36,
#   'WWR': 0.44,
#   'AR': 1.98,
#   'FA': 225.57,
#   'V': 758.12,
#   'EUI': 190.22},
#  362: {'L': 33.611,
#   'W': 18.8795,
#   'H': 3.28,
#   'WWR': 0.22,
#   'AR': 1.78,
#   'FA': 634.53,
#   'V': 2081.35,
#   'EUI': 143.22},
#  363: {'L': 27.267,
#   'W': 20.0385,
#   'H': 3.02,
#   'WWR': 0.19,
#   'AR': 1.36,
#   'FA': 546.36,
#   'V': 1650.1,
#   'EUI': 140.69},
#  364: {'L': 26.6875,
#   'W': 15.433,
#   'H': 2.91,
#   'WWR': 0.48,
#   'AR': 1.73,
#   'FA': 411.84,
#   'V': 1198.54,
#   'EUI': 164.04},
#  365: {'L': 36.2645,
#   'W': 12.1695,
#   'H': 3.3,
#   'WWR': 0.3,
#   'AR': 2.98,
#   'FA': 441.29,
#   'V': 1456.36,
#   'EUI': 159.31},
#  366: {'L': 38.7045,
#   'W': 17.0495,
#   'H': 2.54,
#   'WWR': 0.17,
#   'AR': 2.27,
#   'FA': 659.8,
#   'V': 1676.13,
#   'EUI': 135.02},
#  367: {'L': 41.846,
#   'W': 14.7315,
#   'H': 2.92,
#   'WWR': 0.16,
#   'AR': 2.84,
#   'FA': 616.41,
#   'V': 1800.05,
#   'EUI': 139.43},
#  368: {'L': 24.522,
#   'W': 16.1345,
#   'H': 2.87,
#   'WWR': 0.27,
#   'AR': 1.52,
#   'FA': 395.58,
#   'V': 1135.52,
#   'EUI': 149.21},
#  369: {'L': 40.9005,
#   'W': 14.6095,
#   'H': 2.56,
#   'WWR': 0.54,
#   'AR': 2.8,
#   'FA': 597.46,
#   'V': 1529.69,
#   'EUI': 156.47},
#  370: {'L': 26.962,
#   'W': 9.3635,
#   'H': 3.03,
#   'WWR': 0.22,
#   'AR': 2.88,
#   'FA': 252.42,
#   'V': 764.95,
#   'EUI': 161.2},
#  371: {'L': 24.7965,
#   'W': 21.7465,
#   'H': 3.08,
#   'WWR': 0.4,
#   'AR': 1.14,
#   'FA': 539.21,
#   'V': 1660.85,
#   'EUI': 153.94},
#  372: {'L': 31.171,
#   'W': 12.078,
#   'H': 3.5,
#   'WWR': 0.2,
#   'AR': 2.58,
#   'FA': 376.44,
#   'V': 1317.69,
#   'EUI': 155.84},
#  373: {'L': 33.2755,
#   'W': 12.4135,
#   'H': 2.49,
#   'WWR': 0.38,
#   'AR': 2.68,
#   'FA': 413.05,
#   'V': 1028.53,
#   'EUI': 153.31},
#  374: {'L': 21.228,
#   'W': 14.945,
#   'H': 3.29,
#   'WWR': 0.22,
#   'AR': 1.42,
#   'FA': 317.17,
#   'V': 1043.76,
#   'EUI': 155.21},
#  375: {'L': 23.6985,
#   'W': 14.3655,
#   'H': 2.79,
#   'WWR': 0.29,
#   'AR': 1.65,
#   'FA': 340.4,
#   'V': 949.83,
#   'EUI': 152.68},
#  376: {'L': 43.7065,
#   'W': 14.6705,
#   'H': 3.38,
#   'WWR': 0.55,
#   'AR': 2.98,
#   'FA': 641.12,
#   'V': 2167.24,
#   'EUI': 170.03},
#  377: {'L': 35.807,
#   'W': 17.2935,
#   'H': 2.93,
#   'WWR': 0.31,
#   'AR': 2.07,
#   'FA': 619.2,
#   'V': 1814.34,
#   'EUI': 146.06},
#  378: {'L': 32.2385,
#   'W': 15.494,
#   'H': 2.91,
#   'WWR': 0.29,
#   'AR': 2.08,
#   'FA': 499.45,
#   'V': 1453.55,
#   'EUI': 148.27},
#  379: {'L': 27.2365,
#   'W': 26.962,
#   'H': 2.55,
#   'WWR': 0.16,
#   'AR': 1.01,
# ...
#   'W': 26.6265,
#   'H': 2.8,
#   'WWR': 0.42,
#   'AR': 1.04,
#   'FA': 737.37,
#   'V': 2064.7,
#   'EUI': 145.74},
#  386: {'L': 22.814,
#   'W': 12.81,
#   'H': 2.5,
#   'WWR': 0.48,
#   'AR': 1.78,
#   'FA': 292.18,
#   'V': 730.62,
#   'EUI': 165.3},
#  387: {'L': 37.7895,
#   'W': 19.093,
#   'H': 3.61,
#   'WWR': 0.26,
#   'AR': 1.98,
#   'FA': 721.48,
#   'V': 2604.67,
#   'EUI': 147.0},
#  388: {'L': 42.334,
#   'W': 16.8665,
#   'H': 2.57,
#   'WWR': 0.27,
#   'AR': 2.51,
#   'FA': 713.96,
#   'V': 1835.05,
#   'EUI': 139.12},
#  389: {'L': 25.5895,
#   'W': 15.7075,
#   'H': 2.75,
#   'WWR': 0.4,
#   'AR': 1.63,
#   'FA': 401.9,
#   'V': 1105.35,
#   'EUI': 156.15},
#  390: {'L': 27.328,
#   'W': 18.849,
#   'H': 3.51,
#   'WWR': 0.34,
#   'AR': 1.45,
#   'FA': 515.05,
#   'V': 1808.02,
#   'EUI': 156.47},
#  391: {'L': 38.8265,
#   'W': 13.2065,
#   'H': 2.82,
#   'WWR': 0.39,
#   'AR': 2.94,
#   'FA': 512.73,
#   'V': 1445.99,
#   'EUI': 155.52},
#  392: {'L': 29.158,
#   'W': 13.0235,
#   'H': 2.69,
#   'WWR': 0.36,
#   'AR': 2.24,
#   'FA': 379.69,
#   'V': 1021.5,
#   'EUI': 155.52},
#  393: {'L': 21.96,
#   'W': 11.6205,
#   'H': 2.94,
#   'WWR': 0.53,
#   'AR': 1.89,
#   'FA': 255.11,
#   'V': 750.25,
#   'EUI': 184.54},
#  394: {'L': 34.8005,
#   'W': 18.8185,
#   'H': 2.48,
#   'WWR': 0.43,
#   'AR': 1.85,
#   'FA': 654.87,
#   'V': 1624.14,
#   'EUI': 145.43},
#  395: {'L': 27.1755,
#   'W': 15.982,
#   'H': 3.08,
#   'WWR': 0.43,
#   'AR': 1.7,
#   'FA': 434.23,
#   'V': 1337.7,
#   'EUI': 161.83},
#  396: {'L': 35.7765,
#   'W': 15.0975,
#   'H': 2.84,
#   'WWR': 0.31,
#   'AR': 2.37,
#   'FA': 540.14,
#   'V': 1533.99,
#   'EUI': 147.95},
#  397: {'L': 29.2495,
#   'W': 13.054,
#   'H': 2.75,
#   'WWR': 0.48,
#   'AR': 2.24,
#   'FA': 381.74,
#   'V': 1050.01,
#   'EUI': 164.99},
#  398: {'L': 21.3805,
#   'W': 14.8535,
#   'H': 3.2,
#   'WWR': 0.43,
#   'AR': 1.44,
#   'FA': 317.54,
#   'V': 1016.24,
#   'EUI': 171.61},
#  399: {'L': 29.4935,
#   'W': 22.1735,
#   'H': 3.29,
#   'WWR': 0.44,
#   'AR': 1.33,
#   'FA': 653.94,
#   'V': 2151.57,
#   'EUI': 154.89},
#  400: {'L': 24.6135,
#   'W': 17.8425,
#   'H': 3.04,
#   'WWR': 0.51,
#   'AR': 1.38,
#   'FA': 439.15,
#   'V': 1335.07,
#   'EUI': 165.62},
#  401: {'L': 27.999,
#   'W': 12.1695,
#   'H': 2.47,
#   'WWR': 0.24,
#   'AR': 2.3,
#   'FA': 340.68,
#   'V': 841.61,
#   'EUI': 146.69},
#  402: {'L': 27.2975,
#   'W': 22.753,
#   'H': 2.59,
#   'WWR': 0.19,
#   'AR': 1.2,
#   'FA': 621.06,
#   'V': 1608.65,
#   'EUI': 135.65},
#  403: {'L': 28.304,
#   'W': 12.688,
#   'H': 2.83,
#   'WWR': 0.27,
#   'AR': 2.23,
#   'FA': 359.07,
#   'V': 1016.31,
#   'EUI': 152.37},
#  404: {'L': 24.3085,
#   'W': 13.8165,
#   'H': 2.92,
#   'WWR': 0.42,
#   'AR': 1.76,
#   'FA': 335.84,
#   'V': 980.71,
#   'EUI': 164.99},
#  405: {'L': 23.0885,
#   'W': 21.9905,
#   'H': 2.61,
#   'WWR': 0.32,
#   'AR': 1.05,
#   'FA': 507.71,
#   'V': 1325.17,
#   'EUI': 144.48},
#  406: {'L': 44.713,
#   'W': 16.6225,
#   'H': 2.97,
#   'WWR': 0.5,
#   'AR': 2.69,
#   'FA': 743.22,
#   'V': 2207.43,
#   'EUI': 155.52},
#  407: {'L': 24.0035,
#   'W': 13.481,
#   'H': 2.99,
#   'WWR': 0.19,
#   'AR': 1.78,
#   'FA': 323.58,
#   'V': 967.54,
#   'EUI': 149.53},
#  408: {'L': 26.108,
#   'W': 22.326,
#   'H': 2.77,
#   'WWR': 0.39,
#   'AR': 1.17,
#   'FA': 582.87,
#   'V': 1614.6,
#   'EUI': 147.95},
#  409: {'L': 19.6725,
#   'W': 12.5355,
#   'H': 2.97,
#   'WWR': 0.49,
#   'AR': 1.57,
#   'FA': 246.56,
#   'V': 732.42,
#   'EUI': 181.07},
#  410: {'L': 26.901,
#   'W': 19.215,
#   'H': 3.31,
#   'WWR': 0.41,
#   'AR': 1.4,
#   'FA': 516.82,
#   'V': 1710.95,
#   'EUI': 158.68},
#  411: {'L': 30.8965,
#   'W': 18.727,
#   'H': 3.1,
#   'WWR': 0.34,
#   'AR': 1.65,
#   'FA': 578.51,
#   'V': 1793.66,
#   'EUI': 149.84},
#  412: {'L': 25.376,
#   'W': 24.888,
#   'H': 3.54,
#   'WWR': 0.41,
#   'AR': 1.02,
#   'FA': 631.55,
#   'V': 2235.71,
#   'EUI': 157.1},
#  413: {'L': 19.2455,
#   'W': 12.749,
#   'H': 3.25,
#   'WWR': 0.36,
#   'AR': 1.51,
#   'FA': 245.36,
#   'V': 797.42,
#   'EUI': 174.13},
#  414: {'L': 17.629,
#   'W': 15.4635,
#   'H': 3.46,
#   'WWR': 0.44,
#   'AR': 1.14,
#   'FA': 272.58,
#   'V': 943.22,
#   'EUI': 182.02},
#  415: {'L': 34.3735,
#   'W': 12.2305,
#   'H': 3.56,
#   'WWR': 0.39,
#   'AR': 2.81,
#   'FA': 420.39,
#   'V': 1496.64,
#   'EUI': 171.61},
#  416: {'L': 29.89,
#   'W': 15.982,
#   'H': 2.47,
#   'WWR': 0.51,
#   'AR': 1.87,
#   'FA': 477.61,
#   'V': 1179.92,
#   'EUI': 155.21},
#  417: {'L': 32.513,
#   'W': 21.106,
#   'H': 2.93,
#   'WWR': 0.51,
#   'AR': 1.54,
#   'FA': 686.18,
#   'V': 2010.62,
#   'EUI': 153.63},
#  418: {'L': 30.744,
#   'W': 22.6005,
#   'H': 3.08,
#   'WWR': 0.41,
#   'AR': 1.36,
#   'FA': 694.82,
#   'V': 2140.08,
#   'EUI': 149.53},
#  419: {'L': 37.454,
#   'W': 15.2195,
#   'H': 2.49,
#   'WWR': 0.3,
#   'AR': 2.46,
#   'FA': 569.96,
#   'V': 1419.38,
#   'EUI': 142.9},
#  420: {'L': 40.321,
#   'W': 15.1585,
#   'H': 3.46,
#   'WWR': 0.44,
#   'AR': 2.66,
#   'FA': 611.21,
#   'V': 2114.77,
#   'EUI': 163.09},
#  421: {'L': 40.687,
#   'W': 14.8535,
#   'H': 2.73,
#   'WWR': 0.21,
#   'AR': 2.74,
#   'FA': 604.33,
#   'V': 1649.86,
#   'EUI': 140.38},
#  422: {'L': 25.315,
#   'W': 19.1845,
#   'H': 2.7,
#   'WWR': 0.29,
#   'AR': 1.32,
#   'FA': 485.6,
#   'V': 1311.27,
#   'EUI': 144.8},
#  423: {'L': 21.5635,
#   'W': 14.274,
#   'H': 3.5,
#   'WWR': 0.44,
#   'AR': 1.51,
#   'FA': 307.79,
#   'V': 1077.29,
#   'EUI': 179.5},
#  424: {'L': 35.563,
#   'W': 20.557,
#   'H': 3.51,
#   'WWR': 0.19,
#   'AR': 1.73,
#   'FA': 731.05,
#   'V': 2566.05,
#   'EUI': 141.33},
#  425: {'L': 22.631,
#   'W': 12.2305,
#   'H': 2.66,
#   'WWR': 0.2,
#   'AR': 1.85,
#   'FA': 276.76,
#   'V': 736.26,
#   'EUI': 148.9},
#  426: {'L': 30.195,
#   'W': 13.786,
#   'H': 3.04,
#   'WWR': 0.27,
#   'AR': 2.19,
#   'FA': 416.21,
#   'V': 1265.46,
#   'EUI': 152.05},
#  427: {'L': 25.8945,
#   'W': 24.888,
#   'H': 3.44,
#   'WWR': 0.32,
#   'AR': 1.04,
#   'FA': 644.38,
#   'V': 2216.95,
#   'EUI': 149.53},
#  428: {'L': 29.7375,
#   'W': 15.0975,
#   'H': 2.73,
#   'WWR': 0.38,
#   'AR': 1.97,
#   'FA': 448.91,
#   'V': 1225.67,
#   'EUI': 153.0},
#  429: {'L': 25.193,
#   'W': 11.1935,
#   'H': 2.88,
#   'WWR': 0.36,
#   'AR': 2.25,
#   'FA': 281.96,
#   'V': 812.15,
#   'EUI': 165.93},
#  430: {'L': 26.9315,
#   'W': 9.4855,
#   'H': 3.54,
#   'WWR': 0.24,
#   'AR': 2.84,
#   'FA': 255.39,
#   'V': 904.32,
#   'EUI': 171.29},
#  431: {'L': 30.5305,
#   'W': 23.119,
#   'H': 3.46,
#   'WWR': 0.17,
#   'AR': 1.32,
#   'FA': 705.78,
#   'V': 2442.19,
#   'EUI': 139.75},
#  432: {'L': 39.6195,
#   'W': 13.664,
#   'H': 3.51,
#   'WWR': 0.5,
#   'AR': 2.9,
#   'FA': 541.35,
#   'V': 1900.18,
#   'EUI': 172.87},
#  433: {'L': 38.43,
#   'W': 14.6705,
#   'H': 3.19,
#   'WWR': 0.34,
#   'AR': 2.62,
#   'FA': 563.74,
#   'V': 1798.48,
#   'EUI': 153.94},
#  434: {'L': 24.1255,
#   'W': 18.1475,
#   'H': 2.99,
#   'WWR': 0.54,
#   'AR': 1.33,
#   'FA': 437.76,
#   'V': 1309.07,
#   'EUI': 166.88},
#  435: {'L': 33.3975,
#   'W': 14.9145,
#   'H': 2.96,
#   'WWR': 0.5,
#   'AR': 2.24,
#   'FA': 498.05,
#   'V': 1474.4,
#   'EUI': 163.09},
#  436: {'L': 25.8945,
#   'W': 25.132,
#   'H': 3.07,
#   'WWR': 0.15,
#   'AR': 1.03,
#   'FA': 650.69,
#   'V': 1997.9,
#   'EUI': 136.91},
#  437: {'L': 36.6,
#   'W': 15.128,
#   'H': 3.02,
#   'WWR': 0.44,
#   'AR': 2.42,
#   'FA': 553.61,
#   'V': 1672.13,
#   'EUI': 158.04},
#  438: {'L': 26.535,
#   'W': 16.287,
#   'H': 3.19,
#   'WWR': 0.43,
#   'AR': 1.63,
#   'FA': 432.09,
#   'V': 1378.64,
#   'EUI': 163.41},
#  439: {'L': 26.9925,
#   'W': 10.3395,
#   'H': 2.56,
#   'WWR': 0.44,
#   'AR': 2.61,
#   'FA': 279.08,
#   'V': 714.47,
#   'EUI': 168.46},
#  440: {'L': 43.676,
#   'W': 15.7075,
#   'H': 3.16,
#   'WWR': 0.38,
#   'AR': 2.78,
#   'FA': 686.0,
#   'V': 2167.89,
#   'EUI': 152.68},
#  441: {'L': 33.55,
#   'W': 17.4765,
#   'H': 2.58,
#   'WWR': 0.34,
#   'AR': 1.92,
#   'FA': 586.31,
#   'V': 1512.75,
#   'EUI': 144.16},
#  442: {'L': 30.317,
#   'W': 13.42,
#   'H': 3.33,
#   'WWR': 0.17,
#   'AR': 2.26,
#   'FA': 406.82,
#   'V': 1354.82,
#   'EUI': 148.9},
#  443: {'L': 38.0335,
#   'W': 17.69,
#   'H': 2.81,
#   'WWR': 0.42,
#   'AR': 2.15,
#   'FA': 672.8,
#   'V': 1890.6,
#   'EUI': 149.21},
#  444: {'L': 30.5,
#   'W': 11.468,
#   'H': 3.2,
#   'WWR': 0.4,
#   'AR': 2.66,
#   'FA': 349.69,
#   'V': 1119.28,
#   'EUI': 171.29},
#  445: {'L': 27.633,
#   'W': 11.3765,
#   'H': 2.51,
#   'WWR': 0.28,
#   'AR': 2.43,
#   'FA': 314.29,
#   'V': 789.06,
#   'EUI': 151.74},
#  446: {'L': 43.615,
#   'W': 15.0365,
#   'H': 2.45,
#   'WWR': 0.19,
#   'AR': 2.9,
#   'FA': 655.8,
#   'V': 1606.75,
#   'EUI': 136.28},
#  447: {'L': 28.3345,
#   'W': 15.921,
#   'H': 3.05,
#   'WWR': 0.52,
#   'AR': 1.78,
#   'FA': 451.04,
#   'V': 1375.9,
#   'EUI': 166.88},
#  448: {'L': 33.3365,
#   'W': 13.3895,
#   'H': 2.96,
#   'WWR': 0.54,
#   'AR': 2.49,
#   'FA': 446.31,
#   'V': 1321.22,
#   'EUI': 170.03},
#  449: {'L': 22.753,
#   'W': 14.396,
#   'H': 3.23,
#   'WWR': 0.32,
#   'AR': 1.58,
#   'FA': 327.48,
#   'V': 1057.99,
#   'EUI': 162.15},
#  450: {'L': 29.2495,
#   'W': 13.542,
#   'H': 2.75,
#   'WWR': 0.22,
#   'AR': 2.16,
#   'FA': 396.05,
#   'V': 1089.27,
#   'EUI': 146.06},
#  451: {'L': 36.3865,
#   'W': 13.9995,
#   'H': 2.64,
#   'WWR': 0.53,
#   'AR': 2.6,
#   'FA': 509.39,
#   'V': 1344.8,
#   'EUI': 160.57},
#  452: {'L': 26.1385,
#   'W': 11.0715,
#   'H': 3.61,
#   'WWR': 0.2,
#   'AR': 2.36,
#   'FA': 289.3,
#   'V': 1044.71,
#   'EUI': 162.46},
#  453: {'L': 28.3955,
#   'W': 14.0605,
#   'H': 2.97,
#   'WWR': 0.16,
#   'AR': 2.02,
#   'FA': 399.2,
#   'V': 1185.79,
#   'EUI': 144.16},
#  454: {'L': 35.38,
#   'W': 14.152,
#   'H': 2.52,
#   'WWR': 0.45,
#   'AR': 2.5,
#   'FA': 500.65,
#   'V': 1261.76,
#   'EUI': 153.63},
#  455: {'L': 41.1445,
#   'W': 16.1955,
#   'H': 3.51,
#   'WWR': 0.28,
#   'AR': 2.54,
#   'FA': 666.3,
#   'V': 2338.91,
#   'EUI': 150.16},
#  456: {'L': 36.0815,
#   'W': 12.6575,
#   'H': 3.02,
#   'WWR': 0.34,
#   'AR': 2.85,
#   'FA': 456.62,
#   'V': 1379.24,
#   'EUI': 157.1},
#  457: {'L': 25.62,
#   'W': 11.1935,
#   'H': 2.81,
#   'WWR': 0.39,
#   'AR': 2.29,
#   'FA': 286.7,
#   'V': 805.84,
#   'EUI': 167.19},
#  458: {'L': 25.8945,
#   'W': 13.847,
#   'H': 2.99,
#   'WWR': 0.3,
#   'AR': 1.87,
#   'FA': 358.51,
#   'V': 1072.1,
#   'EUI': 155.84},
#  459: {'L': 27.7855,
#   'W': 16.836,
#   'H': 2.97,
#   'WWR': 0.54,
#   'AR': 1.65,
#   'FA': 467.77,
#   'V': 1389.36,
#   'EUI': 165.3},
#  460: {'L': 40.7175,
#   'W': 17.324,
#   'H': 3.28,
#   'WWR': 0.47,
#   'AR': 2.35,
#   'FA': 705.32,
#   'V': 2313.68,
#   'EUI': 157.73},
#  461: {'L': 30.805,
#   'W': 16.1345,
#   'H': 3.51,
#   'WWR': 0.22,
#   'AR': 1.91,
#   'FA': 496.94,
#   'V': 1744.55,
#   'EUI': 149.84},
#  462: {'L': 19.215,
#   'W': 18.3,
#   'H': 3.08,
#   'WWR': 0.51,
#   'AR': 1.05,
#   'FA': 351.54,
#   'V': 1083.03,
#   'EUI': 172.56},
#  463: {'L': 23.3935,
#   'W': 10.309,
#   'H': 2.57,
#   'WWR': 0.39,
#   'AR': 2.27,
#   'FA': 241.08,
#   'V': 619.79,
#   'EUI': 166.88},
#  464: {'L': 24.1255,
#   'W': 14.274,
#   'H': 2.9,
#   'WWR': 0.36,
#   'AR': 1.69,
#   'FA': 344.3,
#   'V': 998.67,
#   'EUI': 159.31},
#  465: {'L': 28.975,
#   'W': 15.006,
#   'H': 2.47,
#   'WWR': 0.25,
#   'AR': 1.93,
#   'FA': 434.79,
#   'V': 1073.95,
#   'EUI': 142.59},
#  466: {'L': 42.883,
#   'W': 14.945,
#   'H': 2.81,
#   'WWR': 0.27,
#   'AR': 2.87,
#   'FA': 640.84,
#   'V': 1800.89,
#   'EUI': 143.85},
#  467: {'L': 22.509,
#   'W': 14.152,
#   'H': 3.63,
#   'WWR': 0.24,
#   'AR': 1.59,
#   'FA': 318.47,
#   'V': 1156.33,
#   'EUI': 161.52},
#  468: {'L': 23.241,
#   'W': 16.958,
#   'H': 3.57,
#   'WWR': 0.24,
#   'AR': 1.37,
#   'FA': 394.09,
#   'V': 1407.01,
#   'EUI': 155.52},
#  469: {'L': 19.825,
#   'W': 18.0255,
#   'H': 3.5,
#   'WWR': 0.49,
#   'AR': 1.1,
#   'FA': 357.3,
#   'V': 1250.74,
#   'EUI': 178.23},
#  470: {'L': 38.613,
#   'W': 14.2435,
#   'H': 3.51,
#   'WWR': 0.39,
#   'AR': 2.71,
#   'FA': 549.89,
#   'V': 1930.44,
#   'EUI': 163.09},
#  471: {'L': 40.443,
#   'W': 15.494,
#   'H': 2.71,
#   'WWR': 0.33,
#   'AR': 2.61,
#   'FA': 626.54,
#   'V': 1698.15,
#   'EUI': 145.74},
#  472: {'L': 40.5345,
#   'W': 15.6465,
#   'H': 3.31,
#   'WWR': 0.5,
#   'AR': 2.59,
#   'FA': 634.16,
#   'V': 2099.28,
#   'EUI': 163.72},
#  473: {'L': 29.8595,
#   'W': 21.472,
#   'H': 2.44,
#   'WWR': 0.2,
#   'AR': 1.39,
#   'FA': 641.12,
#   'V': 1564.39,
#   'EUI': 134.39},
#  474: {'L': 25.8335,
#   'W': 11.59,
#   'H': 2.44,
#   'WWR': 0.22,
#   'AR': 2.23,
#   'FA': 299.33,
#   'V': 730.56,
#   'EUI': 147.0},
#  475: {'L': 21.5025,
#   'W': 12.871,
#   'H': 3.03,
#   'WWR': 0.37,
#   'AR': 1.67,
#   'FA': 276.76,
#   'V': 838.58,
#   'EUI': 168.14},
#  476: {'L': 44.3775,
#   'W': 16.6225,
#   'H': 3.62,
#   'WWR': 0.45,
#   'AR': 2.67,
#   'FA': 737.65,
#   'V': 2670.35,
#   'EUI': 161.2},
#  477: {'L': 28.548,
#   'W': 16.409,
#   'H': 3.63,
#   'WWR': 0.41,
#   'AR': 1.74,
#   'FA': 468.42,
#   'V': 1700.45,
#   'EUI': 166.88},
#  478: {'L': 40.7175,
#   'W': 18.422,
#   'H': 2.56,
#   'WWR': 0.47,
#   'AR': 2.21,
#   'FA': 750.1,
#   'V': 1920.25,
#   'EUI': 147.0},
#  479: {'L': 24.3085,
#   'W': 10.431,
#   'H': 3.15,
#   'WWR': 0.25,
#   'AR': 2.33,
#   'FA': 253.53,
#   'V': 798.72,
#   'EUI': 163.72},
#  480: {'L': 17.9645,
#   'W': 14.03,
#   'H': 3.14,
#   'WWR': 0.19,
#   'AR': 1.28,
#   'FA': 251.95,
#   'V': 791.41,
#   'EUI': 155.21},
#  481: {'L': 35.319,
#   'W': 18.3,
#   'H': 3.28,
#   'WWR': 0.3,
#   'AR': 1.93,
#   'FA': 646.33,
#   'V': 2119.99,
#   'EUI': 147.95},
#  482: {'L': 26.108,
#   'W': 24.4,
#   'H': 3.08,
#   'WWR': 0.23,
#   'AR': 1.07,
#   'FA': 637.04,
#   'V': 1962.07,
#   'EUI': 141.33},
#  483: {'L': 25.3455,
#   'W': 14.823,
#   'H': 3.51,
#   'WWR': 0.52,
#   'AR': 1.71,
#   'FA': 375.61,
#   'V': 1318.69,
#   'EUI': 181.07},
#  484: {'L': 20.4045,
#   'W': 13.5115,
#   'H': 3.18,
#   'WWR': 0.42,
#   'AR': 1.51,
#   'FA': 275.64,
#   'V': 876.71,
#   'EUI': 175.08},
#  485: {'L': 31.0185,
#   'W': 21.533,
#   'H': 2.66,
#   'WWR': 0.32,
#   'AR': 1.44,
#   'FA': 667.88,
#   'V': 1776.67,
#   'EUI': 141.33},
#  486: {'L': 29.7375,
#   'W': 13.5725,
#   'H': 3.36,
#   'WWR': 0.28,
#   'AR': 2.19,
#   'FA': 403.57,
#   'V': 1356.14,
#   'EUI': 157.73},
#  487: {'L': 26.5655,
#   'W': 10.4615,
#   'H': 3.57,
#   'WWR': 0.15,
#   'AR': 2.54,
#   'FA': 277.87,
#   'V': 992.16,
#   'EUI': 158.68},
#  488: {'L': 27.511,
#   'W': 15.4635,
#   'H': 2.99,
#   'WWR': 0.45,
#   'AR': 1.78,
#   'FA': 425.4,
#   'V': 1271.99,
#   'EUI': 162.46},
#  489: {'L': 38.186,
#   'W': 18.361,
#   'H': 3.12,
#   'WWR': 0.47,
#   'AR': 2.08,
#   'FA': 701.05,
#   'V': 2187.54,
#   'EUI': 154.89},
#  490: {'L': 32.025,
#   'W': 15.25,
#   'H': 3.39,
#   'WWR': 0.35,
#   'AR': 2.1,
#   'FA': 488.3,
#   'V': 1655.61,
#   'EUI': 158.68},
#  491: {'L': 33.0925,
#   'W': 11.0715,
#   'H': 3.24,
#   'WWR': 0.25,
#   'AR': 2.99,
#   'FA': 366.32,
#   'V': 1187.08,
#   'EUI': 158.68},
#  492: {'L': 45.628,
#   'W': 16.0125,
#   'H': 3.04,
#   'WWR': 0.33,
#   'AR': 2.85,
#   'FA': 730.59,
#   'V': 2221.08,
#   'EUI': 147.63},
#  493: {'L': 18.6965,
#   'W': 17.9645,
#   'H': 3.51,
#   'WWR': 0.36,
#   'AR': 1.04,
#   'FA': 335.84,
#   'V': 1178.92,
#   'EUI': 168.46},
#  494: {'L': 31.7505,
#   'W': 22.3565,
#   'H': 2.47,
#   'WWR': 0.26,
#   'AR': 1.42,
#   'FA': 709.78,
#   'V': 1753.28,
#   'EUI': 136.28},
#  495: {'L': 33.855,
#   'W': 11.712,
#   'H': 3.0,
#   'WWR': 0.44,
#   'AR': 2.89,
#   'FA': 396.42,
#   'V': 1189.53,
#   'EUI': 168.46},
#  496: {'L': 22.1735,
#   'W': 16.0735,
#   'H': 3.36,
#   'WWR': 0.41,
#   'AR': 1.38,
#   'FA': 356.38,
#   'V': 1197.52,
#   'EUI': 169.09},
#  497: {'L': 20.374,
#   'W': 14.5485,
#   'H': 3.26,
#   'WWR': 0.15,
#   'AR': 1.4,
#   'FA': 296.36,
#   'V': 966.3,
#   'EUI': 150.16},
#  498: {'L': 24.6745,
#   'W': 18.1475,
#   'H': 2.47,
#   'WWR': 0.4,
#   'AR': 1.36,
#   'FA': 447.7,
#   'V': 1106.02,
#   'EUI': 149.21},
#  499: {'L': 20.313,
#   'W': 11.346,
#   'H': 3.19,
#   'WWR': 0.53,
#   'AR': 1.79,
#   'FA': 230.4,
#   'V': 735.2,
#   'EUI': 194.32},
#  500: {'L': 25.193,
#   'W': 16.2565,
#   'H': 2.75,
#   'WWR': 0.22,
#   'AR': 1.55,
#   'FA': 409.52,
#   'V': 1126.26,
#   'EUI': 144.16},
#  501: {'L': 35.258,
#   'W': 13.9385,
#   'H': 2.48,
#   'WWR': 0.54,
#   'AR': 2.53,
#   'FA': 491.36,
#   'V': 1218.78,
#   'EUI': 158.68},
#  502: {'L': 17.019,
#   'W': 16.1955,
#   'H': 3.61,
#   'WWR': 0.18,
#   'AR': 1.05,
#   'FA': 275.55,
#   'V': 995.03,
#   'EUI': 158.68},
#  503: {'L': 42.6695,
#   'W': 17.202,
#   'H': 3.0,
#   'WWR': 0.23,
#   'AR': 2.48,
#   'FA': 733.93,
#   'V': 2202.0,
#   'EUI': 140.69},
#  504: {'L': 31.354,
#   'W': 14.1825,
#   'H': 3.28,
#   'WWR': 0.19,
#   'AR': 2.21,
#   'FA': 444.63,
#   'V': 1458.54,
#   'EUI': 147.95},
#  505: {'L': 33.5805,
#   'W': 15.128,
#   'H': 3.62,
#   'WWR': 0.48,
#   'AR': 2.22,
#   'FA': 507.99,
#   'V': 1838.98,
#   'EUI': 171.93},
#  506: {'L': 19.4895,
#   'W': 14.884,
#   'H': 3.41,
#   'WWR': 0.52,
#   'AR': 1.31,
#   'FA': 290.04,
#   'V': 989.18,
#   'EUI': 187.07},
#  507: {'L': 30.378,
#   'W': 17.873,
#   'H': 3.47,
#   'WWR': 0.55,
#   'AR': 1.7,
#   'FA': 542.93,
#   'V': 1884.02,
#   'EUI': 170.66},
#  508: {'L': 38.7655,
#   'W': 16.714,
#   'H': 2.83,
#   'WWR': 0.16,
#   'AR': 2.32,
#   'FA': 647.91,
#   'V': 1833.63,
#   'EUI': 136.91},
#  509: {'L': 33.3975,
#   'W': 21.838,
#   'H': 3.04,
#   'WWR': 0.21,
#   'AR': 1.53,
#   'FA': 729.29,
#   'V': 2217.18,
#   'EUI': 138.49},
#  510: {'L': 25.2845,
#   'W': 21.9905,
#   'H': 2.7,
#   'WWR': 0.34,
#   'AR': 1.15,
#   'FA': 555.93,
#   'V': 1501.25,
#   'EUI': 145.11}}

# %% [markdown]
# ### Creating the dataset with Query and Answer

# %% [markdown]
# ###

# %%
# Initialize JSON pairs list
json_pairs = []

# Process each IDF file
for idf_file in os.listdir(idf_folder_path):
    if idf_file.endswith('.idf') and idf_file.startswith("in"):
        idf_file_path = os.path.join(idf_folder_path, idf_file)

        try:
            building_id = int(idf_file.replace("in", "").replace(".idf", ""))
            description = building_data.get(building_id)
            if not description:
                print(f"Warning: No description found for {idf_file}")
                continue
        except ValueError:
            print(f"Skipping {idf_file} - Invalid filename format.")
            continue

        # Extract EnergyPlus objects
        zones, spaces, space_lists, building_surfaces, fenestration_surfaces = extract_objects(idf_file_path)

        # Debugging: Print number of extracted components
        print(f"Processing {idf_file}: Zones({len(zones)}), Spaces({len(spaces)}), "
              f"SpaceLists({len(space_lists)}), Surfaces({len(building_surfaces)}), Windows({len(fenestration_surfaces)})")

        # Ensure at least some components exist
        if any([zones, spaces, space_lists, building_surfaces, fenestration_surfaces]):
            json_pairs.append({
                "user": generate_combined_query(description),
                "assistant": "\n".join(zones + spaces + space_lists + building_surfaces + fenestration_surfaces)
            })
        else:
            print(f"Skipping {idf_file} - No relevant objects found.")
# Out:
# Processing in1.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in10.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in100.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in101.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in102.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in103.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in104.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in105.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in106.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in107.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in108.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in109.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in11.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in110.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in111.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in112.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in113.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in114.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in115.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in116.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in117.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in118.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in119.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in12.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in120.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in121.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in122.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in123.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in124.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in125.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in126.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in127.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in128.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in129.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in13.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in130.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in131.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in132.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in133.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in134.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in135.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in136.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in137.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in138.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in139.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in14.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in140.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in141.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in142.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in143.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in144.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in145.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in146.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in147.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in148.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in149.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in15.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in150.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in151.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in152.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in153.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in154.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in155.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in156.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in157.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in158.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in159.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in16.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in160.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in161.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in162.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in163.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in164.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in165.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in166.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in167.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in168.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in169.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in17.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in170.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in171.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in172.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in173.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in174.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in175.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in176.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in177.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in178.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in179.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in18.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in180.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in181.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in182.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in183.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in184.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in185.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in186.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in187.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in188.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in189.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in19.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in190.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in191.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in192.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in193.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in194.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in195.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in196.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in197.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in198.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in199.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in2.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in20.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in200.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in201.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in202.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in203.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in204.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in205.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in206.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in207.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in208.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in209.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in21.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in210.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in211.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in212.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in213.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in214.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in215.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in216.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in217.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in218.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in219.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in22.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in220.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in221.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in222.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in223.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in224.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in225.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in226.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in227.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in228.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in229.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in23.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in230.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in231.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in232.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in233.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in234.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in235.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in236.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in237.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in238.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in239.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in24.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in240.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in241.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in242.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in243.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in244.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in245.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in246.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in247.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in248.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in249.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in25.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in250.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in251.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in252.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in253.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in254.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in255.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in256.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in257.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in258.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in259.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in26.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in260.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in261.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in262.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in263.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in264.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in265.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in266.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in267.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in268.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in269.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in27.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in270.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in271.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in272.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in273.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in274.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in275.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in276.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in277.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in278.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in279.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in28.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in280.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in281.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in282.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in283.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in284.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in285.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in286.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in287.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in288.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in289.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in29.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in290.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in291.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in292.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in293.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in294.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in295.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in296.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in297.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in298.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in299.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in3.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in30.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in300.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in301.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in302.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in303.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in304.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in305.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in306.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in307.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in308.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in309.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in31.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in310.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in311.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in312.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in313.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in314.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in315.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in316.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in317.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in318.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in319.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in32.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in320.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in321.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in322.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in323.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in324.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in325.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in326.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in327.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in328.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in329.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in33.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in330.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in331.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in332.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in333.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in334.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in335.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in336.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in337.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in338.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in339.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in34.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in340.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in341.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in342.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in343.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in344.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in345.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in346.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in347.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in348.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in349.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in35.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in350.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in351.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in352.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in353.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in354.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in355.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in356.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in357.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in358.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in359.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in36.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in360.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in361.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in362.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in363.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in364.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in365.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in366.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in367.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in368.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in369.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in37.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in370.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in371.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in372.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in373.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in374.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in375.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in376.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in377.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in378.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in379.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in38.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in380.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in381.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in382.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in383.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in384.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in385.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in386.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in387.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in388.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in389.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in39.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in390.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in391.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in392.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in393.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in394.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in395.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in396.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in397.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in398.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in399.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in4.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in40.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in400.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in401.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in402.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in403.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in404.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in405.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in406.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in407.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in408.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in409.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in41.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in410.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in411.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in412.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in413.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in414.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in415.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in416.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in417.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in418.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in419.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in42.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in420.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in421.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in422.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in423.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in424.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in425.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in426.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in427.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in428.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in429.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in43.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in430.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in431.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in432.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in433.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in434.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in435.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in436.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in437.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in438.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in439.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in44.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in440.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in441.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in442.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in443.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in444.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in445.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in446.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in447.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in448.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in449.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in45.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in450.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in451.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in452.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in453.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in454.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in455.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in456.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in457.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in458.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in459.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in46.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in460.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in461.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in462.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in463.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in464.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in465.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in466.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in467.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in468.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in469.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in47.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in470.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in471.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in472.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in473.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in474.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in475.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in476.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in477.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in478.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in479.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in48.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in480.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in481.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in482.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in483.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in484.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in485.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in486.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in487.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in488.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in489.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in49.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in490.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in491.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in492.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in493.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in494.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in495.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in496.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in497.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in498.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in499.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in5.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in50.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in500.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in501.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in502.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in503.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in504.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in505.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in506.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in507.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in508.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in509.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in51.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in510.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in52.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in53.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in54.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in55.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in56.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in57.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in58.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in59.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in6.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in60.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in61.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in62.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in63.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in64.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in65.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in66.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in67.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in68.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in69.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in7.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in70.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in71.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in72.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in73.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in74.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in75.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in76.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in77.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in78.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in79.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in8.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in80.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in81.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in82.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in83.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in84.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in85.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in86.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in87.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in88.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in89.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in9.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in90.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in91.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in92.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in93.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in94.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in95.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in96.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in97.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in98.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in99.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)

# %%
# Save dataset to JSON
with open(output_json_path, 'w', encoding='utf-8') as json_file:
    json.dump(json_pairs, json_file, indent=2)

print(f"Fine-tuning dataset saved to {output_json_path}")
# Out:
# Fine-tuning dataset saved to BuildingGeometricDataset.json

# %% [markdown]
# ### Cleaning the json file

# %%
## Making 0.2 or two significant digitsimport json
import re
file_path = r'C:\Users\Jayedi Aman\OneDrive - University of Missouri\Desktop\LLM Eplus\BuildingGeometricDataset.json'

def round_numbers_in_text(text, precision=2):
    # Match float or int numbers in string, including negatives
    number_pattern = re.compile(r'-?\d+\.\d+|-?\d+')

    def round_match(match):
        num = float(match.group())
        return f"{num:.{precision}f}"

    return number_pattern.sub(round_match, text)

def round_json_numbers(json_data, precision=2):
    for item in json_data:
        for key in item:
            if isinstance(item[key], str):
                item[key] = round_numbers_in_text(item[key], precision)
    return json_data

# %%
# === Usage ===
# Load your JSON file
with open(file_path, "r") as f:
    data = json.load(f)

# Round numbers in the JSON
rounded_data = round_json_numbers(data, precision=2)

# %%
# Save the modified JSON
with open(file_path, "w") as f:
    json.dump(rounded_data, f, indent=2)
