# %% [markdown]
# ### Importing necessary libraries

# %%
import os
import json
import pandas as pd
import random

# %% [markdown]
# ### Function to extract EnergyPlus objects From IDF files

# %%
import re

def extract_objects(idf_file_path):
    """Extracts strictly matching Zone, Space, SpaceList, BuildingSurface:Detailed, and FenestrationSurface:Detailed objects."""
    with open(idf_file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    current_obj = []
    extracted_objects = {key: [] for key in [
        "Zone,", "Space,", "SpaceList,", 
        "BuildingSurface:Detailed,", "FenestrationSurface:Detailed,"
    ]}

    inside_object = None  # Track current object type

    for line in lines:

        # Remove comments (everything after '!')
        # line = line.strip() # including comments
        line = line.split('!')[0].strip()
        if not line:
            continue  # Skip empty or comment-only lines

        # Normalize spacing
        clean_line = " ".join(line.split())  
        clean_line = clean_line.replace(" ,", ",").replace(", ", ",")

        # Detect start of a new object
        for key in extracted_objects.keys():
            if clean_line.startswith(key):
                inside_object = key
                current_obj = [clean_line]
                break
        else:
            if inside_object:
                current_obj.append(clean_line)

        # If line ends with ';', finalize the object
        if ";" in clean_line and inside_object:
            # Join, remove extra spaces/newlines
            complete_object = " ".join(current_obj).replace("\n", "").strip()
            extracted_objects[inside_object].append(complete_object)
            inside_object = None

    return [extracted_objects[key] for key in extracted_objects]

# %% [markdown]
# ### Various prompt for creating dataset with different queries

# %%
# Function to generate a user query
def generate_combined_query(description):
    """Returns a user query asking for a Zone, Space, SpaceList, BuildingSurface, and FenestrationSurface."""
    L = float(description['L'])
    W = float(description['W'])
    H = float(description['H'])
    FA = float(description['FA'])
    AR = float(description['AR'])
    WWR = float(description['WWR'])
    templates = [
        f"""
        Generate an EnergyPlus IDF for the geometric parameters with
        Length: {description['L']:.2f} m  
        Width: {description['W']:.2f} m  
        Height: {description['H']:.2f} m  
        Floor Area: Length*Width={description['FA']:.2f} m²  
        Aspect Ratio: Length/Width={description['AR']:.2f}  
        WWR: {description['WWR']:.2f}
        Define one Zone, one Space, and one SpaceList.\
        Create six BuildingSurface:Detailed surfaces: four walls, one roof, one floor.\
        Walls must be named 'zone1.00_Space - Wall angle:a' where angle is in degrees (0, 90, 180, 270).\
        Add one rectangular window (FenestrationSurface:Detailed) centered on each wall.\
        Window names must be 'zone1.00_Space - Wall angle:a - Sub:a', linked to walls.\
        Window area equals corresponding to wall area times WWR\
        Vertices start at (0,0,0), defined clockwise for all surfaces and windows.\
        Use meters as units.\
        Ensure windows fit fully inside walls and do not overlap edges.\
        Output only the IDF code snippet with no comments or extra text.
        """

    #     f"""
    #     Create an EnergyPlus IDF snippet with the following requirements:

    #     - One Zone, one Space, and one SpaceList named consistently.
    #     - Six BuildingSurface:Detailed objects representing four walls, one floor, and one roof.
    #     - Four FenestrationSurface:Detailed windows, each centered on one of the four walls.
    #     - Walls named as 'zone1.00_Space - Wall angle:.4f:a' with angles 0, 90, 180, 270 degrees.
    #     - Windows named as 'zone1.00_Space - Wall angle:.4f:a - Sub:a', linked to the corresponding wall.
    #     - Window area = wall area * WWR
    #     - Vertices for all surfaces start at (0.0, 0.0, 0.0) and are ordered clockwise.
    #     - Windows must be rectangular, centered, and fully inside wall boundaries.
    #     - Use metric units (meters) for all coordinates.
    #     - Only output the correctly formatted IDF objects, no additional explanation.

    #     Building Parameters:
    #     - Length = {description['L']:.2f} m
    #     - Width = {description['W']:.2f} m
    #     - Height = {description['H']:.2f} m
    #     - Floor Area = {description['FA']:.2f} m²
    #     - Aspect Ratio = {description['AR']:.2f}
    #     - Window-to-Wall Ratio (WWR) = {description['WWR']:.2f}
    #    """
    #    f"""
    #     Create an EnergyPlus IDF snippet with:
    #     - One Zone, Space, and SpaceList
    #     - Six BuildingSurface:Detailed surfaces (4 walls, roof, floor)
    #     - Four FenestrationSurface:Detailed windows centered on walls

    #     Step 1: Define wall vertices clockwise from (0,0,0) using length (L), width (W), and height (H).
    #     Step 2: Calculate wall centroids.
    #     Step 3: Calculate window area = WWR * wall area.
    #     Step 4: Calculate window width and height = wall width/height * sqrt(WWR).
    #     Step 5: Center windows on wall centroids and define vertices accordingly.
    #     Step 6: Ensure windows fit inside walls, coplanar and clockwise.

    #     Building Parameters:
    #     - Length = {description['L']:.2f} m
    #     - Width = {description['W']:.2f} m
    #     - Height = {description['H']:.2f} m
    #     - Floor Area = {description['FA']:.2f} m²
    #     - Aspect Ratio = {description['AR']:.2f}
    #     - Window-to-Wall Ratio (WWR) = {description['WWR']:.2f}
    #    Include only geometry-related IDF objects.
    #    """
    # f"""
    # Create an EnergyPlus IDF snippet for a rectangular building with these requirements.
    # Building Parameters:
    # - Length = {description['L']:.2f} m
    # - Width = {description['W']:.2f} m
    # - Height = {description['H']:.2f} m
    # - Floor Area = {description['FA']:.2f} m²
    # - Aspect Ratio = {description['AR']:.2f}
    # - Window-to-Wall Ratio (WWR) = {description['WWR']:.2f}

    # Requirements:
    # 1. Define exactly 1 Zone, 1 Space, and 1 SpaceList.
    # 2. Create 6 BuildingSurface:Detailed objects:
    # - 4 walls,
    # - 1 roof,
    # - 1 floor.
    # 3. Add one rectangular FenestrationSurface:Detailed window centered on each wall.
    # - Window size based on WWR and wall geometry.
    # 4. Geometry Rules:
    # - Vertices start at (0.00, 0.00, 0.00) and proceed clockwise.
    # - Units are meters (SI).
    # - Roof elevation Z = building Height.
    # - Floor elevation Z = 0.00.
    # 5. Calculate for each wall:
    # - Wall area = Wall Width * Wall Height.
    # - Window area = WWR * Wall Area.
    # - Window Width = Wall Width * sqrt(WWR).
    # - Window Height = Wall Height * sqrt(WWR).
    # - Center the window on wall centroid.
    # - Ensure windows fully fit inside wall and are coplanar, clockwise vertex order.
    # 6. Use consistent naming conventions for walls and windows.
    # 7. Output only the IDF geometry snippet with Zone, Space, SpaceList, BuildingSurface:Detailed, and FenestrationSurface:Detailed objects.

    # Include only geometry-related IDF objects.
    # """
    ]
    return random.choice(templates)

# %% [markdown]
# ### Choose the file path
#
# All the data related to design matrix based on which simulations are done are in Excel (csv) file. They are data about L, W, CH, FA, WWR, AR, V and EUI
# Idf file from where EnergyPlus objects will be extracted from are in idf_rectangle folder.

# %%
# Define file paths
excel_file_path = r"C:\Users\Desktop\LLM\idf_rectangle\data.csv"
idf_folder_path = r'C:\Users\Desktop\LLM\idf_rectangle'
output_json_path = 'BuildingGeometricDataset2.json'

# %% [markdown]
# ### Creating dictionary
# Dictionary of ata containing key= ID or design matrix, value = set of {L, W, CH, WWR, AR, FA, V, EUI}

# %%
# Load building descriptions
if not os.path.exists(excel_file_path):
    raise FileNotFoundError(f"CSV file not found: {excel_file_path}")

df = pd.read_csv(excel_file_path)
# Convert all necessary columns to float explicitly
float_columns = ['L', 'W', 'H', 'WWR', 'AR', 'EUI', 'FA']
df[float_columns] = df[float_columns].astype(float)

building_data = df.set_index('ID').to_dict(orient='index')

building_data
# Out:
# {1: {'L': 22.08,
#   'W': 15.77,
#   'H': 4.0,
#   'WWR': 0.22,
#   'AR': 1.4,
#   'EUI': 185.0,
#   'FA': 348.2},
#  2: {'L': 26.52,
#   'W': 14.18,
#   'H': 3.69,
#   'WWR': 0.24,
#   'AR': 1.87,
#   'EUI': 182.4,
#   'FA': 376.1},
#  3: {'L': 23.53,
#   'W': 20.11,
#   'H': 3.96,
#   'WWR': 0.19,
#   'AR': 1.17,
#   'EUI': 174.9,
#   'FA': 473.2},
#  4: {'L': 32.65,
#   'W': 28.39,
#   'H': 2.9,
#   'WWR': 0.25,
#   'AR': 1.15,
#   'EUI': 158.8,
#   'FA': 926.9},
#  5: {'L': 33.9,
#   'W': 17.12,
#   'H': 2.88,
#   'WWR': 0.24,
#   'AR': 1.98,
#   'EUI': 165.3,
#   'FA': 580.4},
#  6: {'L': 15.61,
#   'W': 8.39,
#   'H': 2.69,
#   'WWR': 0.18,
#   'AR': 1.86,
#   'EUI': 187.3,
#   'FA': 131.0},
#  7: {'L': 36.87,
#   'W': 19.93,
#   'H': 2.84,
#   'WWR': 0.18,
#   'AR': 1.85,
#   'EUI': 158.7,
#   'FA': 734.8},
#  8: {'L': 18.91,
#   'W': 12.12,
#   'H': 3.17,
#   'WWR': 0.34,
#   'AR': 1.56,
#   'EUI': 196.1,
#   'FA': 229.2},
#  9: {'L': 37.84,
#   'W': 21.14,
#   'H': 2.93,
#   'WWR': 0.3,
#   'AR': 1.79,
#   'EUI': 163.8,
#   'FA': 799.9},
#  10: {'L': 32.75,
#   'W': 23.23,
#   'H': 3.82,
#   'WWR': 0.2,
#   'AR': 1.41,
#   'EUI': 166.3,
#   'FA': 760.8},
#  11: {'L': 25.13,
#   'W': 20.77,
#   'H': 2.61,
#   'WWR': 0.24,
#   'AR': 1.21,
#   'EUI': 162.9,
#   'FA': 522.0},
#  12: {'L': 18.91,
#   'W': 13.8,
#   'H': 3.42,
#   'WWR': 0.28,
#   'AR': 1.37,
#   'EUI': 190.2,
#   'FA': 261.0},
#  13: {'L': 35.94,
#   'W': 19.64,
#   'H': 2.56,
#   'WWR': 0.27,
#   'AR': 1.83,
#   'EUI': 160.7,
#   'FA': 705.9},
#  14: {'L': 13.9,
#   'W': 12.09,
#   'H': 3.61,
#   'WWR': 0.25,
#   'AR': 1.15,
#   'EUI': 203.8,
#   'FA': 168.1},
#  15: {'L': 32.12,
#   'W': 30.3,
#   'H': 3.31,
#   'WWR': 0.33,
#   'AR': 1.06,
#   'EUI': 165.1,
#   'FA': 973.2},
#  16: {'L': 35.86,
#   'W': 20.97,
#   'H': 3.78,
#   'WWR': 0.35,
#   'AR': 1.71,
#   'EUI': 175.8,
#   'FA': 752.0},
#  17: {'L': 29.23,
#   'W': 24.77,
#   'H': 3.14,
#   'WWR': 0.35,
#   'AR': 1.18,
#   'EUI': 169.0,
#   'FA': 724.0},
#  18: {'L': 20.68,
#   'W': 15.32,
#   'H': 3.88,
#   'WWR': 0.21,
#   'AR': 1.35,
#   'EUI': 184.9,
#   'FA': 316.8},
#  19: {'L': 27.2,
#   'W': 15.37,
#   'H': 2.68,
#   'WWR': 0.2,
#   'AR': 1.77,
#   'EUI': 165.3,
#   'FA': 418.1},
#  20: {'L': 20.83,
#   'W': 12.86,
#   'H': 2.99,
#   'WWR': 0.19,
#   'AR': 1.62,
#   'EUI': 175.8,
#   'FA': 267.9},
#  21: {'L': 30.18,
#   'W': 17.86,
#   'H': 2.61,
#   'WWR': 0.29,
#   'AR': 1.69,
#   'EUI': 165.5,
#   'FA': 539.0},
#  22: {'L': 29.84,
#   'W': 20.58,
#   'H': 2.79,
#   'WWR': 0.18,
#   'AR': 1.45,
#   'EUI': 159.8,
#   'FA': 614.1},
#  23: {'L': 31.98,
#   'W': 30.17,
#   'H': 3.22,
#   'WWR': 0.22,
#   'AR': 1.06,
#   'EUI': 159.5,
#   'FA': 964.8},
#  24: {'L': 37.41,
#   'W': 24.94,
#   'H': 3.5,
#   'WWR': 0.19,
#   'AR': 1.5,
#   'EUI': 160.7,
#   'FA': 933.0},
#  25: {'L': 22.45,
#   'W': 16.75,
#   'H': 2.81,
#   'WWR': 0.17,
#   'AR': 1.34,
#   'EUI': 165.8,
#   'FA': 376.0},
#  26: {'L': 18.89,
#   'W': 13.3,
#   'H': 3.92,
#   'WWR': 0.28,
#   'AR': 1.42,
#   'EUI': 199.7,
#   'FA': 251.2},
#  27: {'L': 38.58,
#   'W': 23.96,
#   'H': 2.82,
#   'WWR': 0.15,
#   'AR': 1.61,
#   'EUI': 154.7,
#   'FA': 924.4},
#  28: {'L': 26.65,
#   'W': 19.74,
#   'H': 2.93,
#   'WWR': 0.33,
#   'AR': 1.35,
#   'EUI': 171.2,
#   'FA': 526.1},
#  29: {'L': 12.64,
#   'W': 9.5,
#   'H': 2.96,
#   'WWR': 0.27,
#   'AR': 1.33,
#   'EUI': 204.7,
#   'FA': 120.1},
#  30: {'L': 24.68,
#   'W': 18.15,
#   'H': 3.15,
#   'WWR': 0.22,
#   'AR': 1.36,
#   'EUI': 169.9,
#   'FA': 447.9},
#  31: {'L': 36.37,
#   'W': 24.74,
#   'H': 2.87,
#   'WWR': 0.23,
#   'AR': 1.47,
#   'EUI': 158.4,
#   'FA': 899.8},
#  32: {'L': 35.67,
#   'W': 26.42,
#   'H': 3.73,
#   'WWR': 0.29,
#   'AR': 1.35,
#   'EUI': 167.1,
#   'FA': 942.4},
#  33: {'L': 26.84,
#   'W': 14.83,
#   'H': 3.36,
#   'WWR': 0.25,
#   'AR': 1.81,
#   'EUI': 177.6,
#   'FA': 398.0},
#  34: {'L': 27.94,
#   'W': 14.4,
#   'H': 3.98,
#   'WWR': 0.32,
#   'AR': 1.94,
#   'EUI': 192.0,
#   'FA': 402.3},
#  35: {'L': 37.89,
#   'W': 21.53,
#   'H': 3.73,
#   'WWR': 0.22,
#   'AR': 1.76,
#   'EUI': 166.3,
#   'FA': 815.8},
#  36: {'L': 23.58,
#   'W': 20.15,
#   'H': 2.55,
#   'WWR': 0.32,
#   'AR': 1.17,
#   'EUI': 167.7,
#   'FA': 475.1},
#  37: {'L': 28.25,
#   'W': 22.97,
#   'H': 2.86,
#   'WWR': 0.19,
#   'AR': 1.23,
#   'EUI': 160.0,
#   'FA': 648.9},
#  38: {'L': 33.65,
#   'W': 20.9,
#   'H': 3.01,
#   'WWR': 0.15,
#   'AR': 1.61,
#   'EUI': 158.7,
#   'FA': 703.3},
#  39: {'L': 34.88,
#   'W': 24.22,
#   'H': 2.68,
#   'WWR': 0.23,
#   'AR': 1.44,
#   'EUI': 157.5,
#   'FA': 844.8},
#  40: {'L': 15.32,
#   'W': 10.64,
#   'H': 2.56,
#   'WWR': 0.24,
#   'AR': 1.44,
#   'EUI': 184.0,
#   'FA': 163.0},
#  41: {'L': 36.16,
#   'W': 24.27,
#   'H': 3.63,
#   'WWR': 0.23,
#   'AR': 1.49,
#   'EUI': 164.5,
#   'FA': 877.6},
#  42: {'L': 24.23,
#   'W': 16.15,
#   'H': 2.92,
#   'WWR': 0.33,
#   'AR': 1.5,
#   'EUI': 177.1,
#   'FA': 391.3},
#  43: {'L': 38.54,
#   'W': 25.19,
#   'H': 2.92,
#   'WWR': 0.18,
#   'AR': 1.53,
#   'EUI': 155.9,
#   'FA': 970.8},
#  44: {'L': 37.79,
#   'W': 18.99,
#   'H': 3.72,
#   'WWR': 0.2,
#   'AR': 1.99,
#   'EUI': 167.5,
#   'FA': 717.6},
#  45: {'L': 30.25,
#   'W': 16.62,
#   'H': 3.96,
#   'WWR': 0.21,
#   'AR': 1.82,
#   'EUI': 176.4,
#   'FA': 502.8},
#  46: {'L': 18.02,
#   'W': 12.6,
#   'H': 4.0,
#   'WWR': 0.28,
#   'AR': 1.43,
#   'EUI': 204.6,
#   'FA': 227.1},
#  47: {'L': 39.55,
#   'W': 23.54,
#   'H': 3.84,
#   'WWR': 0.19,
#   'AR': 1.68,
#   'EUI': 163.4,
#   'FA': 931.0},
#  48: {'L': 35.43,
#   'W': 23.94,
#   'H': 3.62,
#   'WWR': 0.21,
#   'AR': 1.48,
#   'EUI': 163.8,
#   'FA': 848.2},
#  49: {'L': 25.36,
#   'W': 17.86,
#   'H': 3.42,
#   'WWR': 0.34,
#   'AR': 1.42,
#   'EUI': 181.3,
#   'FA': 452.9},
#  50: {'L': 31.1,
#   'W': 20.87,
#   'H': 2.87,
#   'WWR': 0.18,
#   'AR': 1.49,
#   'EUI': 159.9,
#   'FA': 649.1},
#  51: {'L': 28.43,
#   'W': 23.89,
#   'H': 3.54,
#   'WWR': 0.34,
#   'AR': 1.19,
#   'EUI': 173.8,
#   'FA': 679.2},
#  52: {'L': 26.43,
#   'W': 20.81,
#   'H': 3.1,
#   'WWR': 0.35,
#   'AR': 1.27,
#   'EUI': 173.6,
#   'FA': 550.0},
#  53: {'L': 37.69,
#   'W': 23.12,
#   'H': 2.87,
#   'WWR': 0.24,
#   'AR': 1.63,
#   'EUI': 159.3,
#   'FA': 871.4},
#  54: {'L': 25.72,
#   'W': 20.41,
#   'H': 2.54,
#   'WWR': 0.2,
#   'AR': 1.26,
#   'EUI': 160.2,
#   'FA': 525.0},
#  55: {'L': 24.91,
#   'W': 23.72,
#   'H': 3.03,
#   'WWR': 0.22,
#   'AR': 1.05,
#   'EUI': 164.3,
#   'FA': 590.9},
#  56: {'L': 34.46,
#   'W': 19.47,
#   'H': 3.98,
#   'WWR': 0.24,
#   'AR': 1.77,
#   'EUI': 173.0,
#   'FA': 670.9},
#  57: {'L': 41.9,
#   'W': 22.65,
#   'H': 3.64,
#   'WWR': 0.3,
#   'AR': 1.85,
#   'EUI': 167.7,
#   'FA': 949.0},
#  58: {'L': 18.37,
#   'W': 14.58,
#   'H': 3.11,
#   'WWR': 0.31,
#   'AR': 1.26,
#   'EUI': 187.0,
#   'FA': 267.8},
#  59: {'L': 31.22,
#   'W': 15.85,
#   'H': 3.37,
#   'WWR': 0.25,
#   'AR': 1.97,
#   'EUI': 173.8,
#   'FA': 494.8},
#  60: {'L': 27.75,
#   'W': 21.02,
#   'H': 3.0,
#   'WWR': 0.23,
#   'AR': 1.32,
#   'EUI': 164.8,
#   'FA': 583.3},
#  61: {'L': 28.48,
#   'W': 15.07,
#   'H': 3.68,
#   'WWR': 0.15,
#   'AR': 1.89,
#   'EUI': 172.3,
#   'FA': 429.2},
#  62: {'L': 31.75,
#   'W': 21.45,
#   'H': 3.73,
#   'WWR': 0.29,
#   'AR': 1.48,
#   'EUI': 172.9,
#   'FA': 681.0},
#  63: {'L': 13.7,
#   'W': 12.34,
#   'H': 2.68,
#   'WWR': 0.21,
#   'AR': 1.11,
#   'EUI': 182.1,
#   'FA': 169.1},
#  64: {'L': 41.49,
#   'W': 21.95,
#   'H': 2.85,
#   'WWR': 0.2,
#   'AR': 1.89,
#   'EUI': 157.4,
#   'FA': 910.7},
#  65: {'L': 34.76,
#   'W': 24.31,
#   'H': 2.8,
#   'WWR': 0.17,
#   'AR': 1.43,
#   'EUI': 156.0,
#   'FA': 845.0},
#  66: {'L': 19.38,
#   'W': 14.91,
#   'H': 3.92,
#   'WWR': 0.24,
#   'AR': 1.3,
#   'EUI': 190.8,
#   'FA': 289.0},
#  67: {'L': 14.85,
#   'W': 11.25,
#   'H': 2.7,
#   'WWR': 0.17,
#   'AR': 1.32,
#   'EUI': 179.2,
#   'FA': 167.1},
#  68: {'L': 24.8,
#   'W': 12.46,
#   'H': 2.97,
#   'WWR': 0.28,
#   'AR': 1.99,
#   'EUI': 180.7,
#   'FA': 309.0},
#  69: {'L': 20.67,
#   'W': 13.6,
#   'H': 3.7,
#   'WWR': 0.34,
#   'AR': 1.52,
#   'EUI': 199.1,
#   'FA': 281.1},
#  70: {'L': 23.02,
#   'W': 19.51,
#   'H': 3.53,
#   'WWR': 0.22,
#   'AR': 1.18,
#   'EUI': 173.7,
#   'FA': 449.1},
#  71: {'L': 32.31,
#   'W': 20.58,
#   'H': 2.93,
#   'WWR': 0.27,
#   'AR': 1.57,
#   'EUI': 164.6,
#   'FA': 664.9},
#  72: {'L': 22.25,
#   'W': 12.5,
#   'H': 2.99,
#   'WWR': 0.35,
#   'AR': 1.78,
#   'EUI': 188.8,
#   'FA': 278.1},
#  73: {'L': 25.75,
#   'W': 15.06,
#   'H': 2.92,
#   'WWR': 0.22,
#   'AR': 1.71,
#   'EUI': 170.3,
#   'FA': 387.8},
#  74: {'L': 43.68,
#   'W': 22.63,
#   'H': 3.5,
#   'WWR': 0.17,
#   'AR': 1.93,
#   'EUI': 159.7,
#   'FA': 988.5},
#  75: {'L': 22.78,
#   'W': 11.68,
#   'H': 3.28,
#   'WWR': 0.16,
#   'AR': 1.95,
#   'EUI': 178.1,
#   'FA': 266.1},
#  76: {'L': 28.43,
#   'W': 18.11,
#   'H': 2.66,
#   'WWR': 0.2,
#   'AR': 1.57,
#   'EUI': 161.9,
#   'FA': 514.9},
#  77: {'L': 42.18,
#   'W': 21.74,
#   'H': 3.85,
#   'WWR': 0.22,
#   'AR': 1.94,
#   'EUI': 165.8,
#   'FA': 917.0},
#  78: {'L': 21.82,
#   'W': 18.65,
#   'H': 3.23,
#   'WWR': 0.24,
#   'AR': 1.17,
#   'EUI': 173.7,
#   'FA': 406.9},
#  79: {'L': 37.15,
#   'W': 25.27,
#   'H': 2.9,
#   'WWR': 0.18,
#   'AR': 1.47,
#   'EUI': 156.1,
#   'FA': 938.8},
#  80: {'L': 14.06,
#   'W': 13.52,
#   'H': 3.95,
#   'WWR': 0.32,
#   'AR': 1.04,
#   'EUI': 215.2,
#   'FA': 190.1},
#  81: {'L': 18.85,
#   'W': 10.71,
#   'H': 3.74,
#   'WWR': 0.17,
#   'AR': 1.76,
#   'EUI': 192.0,
#   'FA': 201.9},
#  82: {'L': 38.27,
#   'W': 23.77,
#   'H': 3.92,
#   'WWR': 0.33,
#   'AR': 1.61,
#   'EUI': 172.0,
#   'FA': 909.7},
#  83: {'L': 24.78,
#   'W': 12.71,
#   'H': 3.63,
#   'WWR': 0.25,
#   'AR': 1.95,
#   'EUI': 187.2,
#   'FA': 315.0},
#  84: {'L': 23.3,
#   'W': 13.87,
#   'H': 3.77,
#   'WWR': 0.28,
#   'AR': 1.68,
#   'EUI': 190.4,
#   'FA': 323.2},
#  85: {'L': 40.8,
#   'W': 21.03,
#   'H': 2.84,
#   'WWR': 0.24,
#   'AR': 1.94,
#   'EUI': 159.7,
#   'FA': 858.0},
#  86: {'L': 23.07,
#   'W': 13.65,
#   'H': 3.58,
#   'WWR': 0.31,
#   'AR': 1.69,
#   'EUI': 191.2,
#   'FA': 314.9},
#  87: {'L': 25.33,
#   'W': 24.12,
#   'H': 3.75,
#   'WWR': 0.34,
#   'AR': 1.05,
#   'EUI': 178.3,
#   'FA': 611.0},
#  88: {'L': 32.71,
#   'W': 18.07,
#   'H': 3.45,
#   'WWR': 0.29,
#   'AR': 1.81,
#   'EUI': 173.5,
#   'FA': 591.1},
#  89: {'L': 24.93,
#   'W': 18.33,
#   'H': 3.8,
#   'WWR': 0.28,
#   'AR': 1.36,
#   'EUI': 181.1,
#   'FA': 457.0},
#  90: {'L': 26.21,
#   'W': 15.6,
#   'H': 2.86,
#   'WWR': 0.24,
#   'AR': 1.68,
#   'EUI': 170.0,
#   'FA': 408.9},
#  91: {'L': 35.22,
#   'W': 22.15,
#   'H': 3.81,
#   'WWR': 0.23,
#   'AR': 1.59,
#   'EUI': 167.9,
#   'FA': 780.1},
#  92: {'L': 29.65,
#   'W': 16.2,
#   'H': 2.58,
#   'WWR': 0.27,
#   'AR': 1.83,
#   'EUI': 166.1,
#   'FA': 480.3},
#  93: {'L': 41.77,
#   'W': 21.53,
#   'H': 3.33,
#   'WWR': 0.29,
#   'AR': 1.94,
#   'EUI': 165.6,
#   'FA': 899.3},
#  94: {'L': 41.62,
#   'W': 23.78,
#   'H': 3.33,
#   'WWR': 0.21,
#   'AR': 1.75,
#   'EUI': 160.1,
#   'FA': 989.7},
#  95: {'L': 32.57,
#   'W': 27.6,
#   'H': 2.63,
#   'WWR': 0.34,
#   'AR': 1.18,
#   'EUI': 160.5,
#   'FA': 898.9},
#  96: {'L': 21.95,
#   'W': 11.2,
#   'H': 2.66,
#   'WWR': 0.21,
#   'AR': 1.96,
#   'EUI': 175.3,
#   'FA': 245.8},
#  97: {'L': 23.97,
#   'W': 15.98,
#   'H': 3.35,
#   'WWR': 0.28,
#   'AR': 1.5,
#   'EUI': 179.8,
#   'FA': 383.0},
#  98: {'L': 20.45,
#   'W': 20.05,
#   'H': 2.78,
#   'WWR': 0.19,
#   'AR': 1.02,
#   'EUI': 165.4,
#   'FA': 410.0},
#  99: {'L': 25.64,
#   'W': 24.65,
#   'H': 2.94,
#   'WWR': 0.32,
#   'AR': 1.04,
#   'EUI': 167.6,
#   'FA': 632.0},
#  100: {'L': 27.28,
#   'W': 14.99,
#   'H': 3.5,
#   'WWR': 0.24,
#   'AR': 1.82,
#   'EUI': 178.0,
#   'FA': 408.9},
#  101: {'L': 24.36,
#   'W': 12.24,
#   'H': 3.33,
#   'WWR': 0.18,
#   'AR': 1.99,
#   'EUI': 178.2,
#   'FA': 298.2},
#  102: {'L': 20.46,
#   'W': 17.64,
#   'H': 2.71,
#   'WWR': 0.29,
#   'AR': 1.16,
#   'EUI': 172.8,
#   'FA': 360.9},
#  103: {'L': 27.44,
#   'W': 14.29,
#   'H': 3.16,
#   'WWR': 0.23,
#   'AR': 1.92,
#   'EUI': 174.2,
#   'FA': 392.1},
#  104: {'L': 39.22,
#   'W': 23.77,
#   'H': 3.91,
#   'WWR': 0.29,
#   'AR': 1.65,
#   'EUI': 169.3,
#   'FA': 932.3},
#  105: {'L': 17.85,
#   'W': 14.17,
#   'H': 3.22,
#   'WWR': 0.2,
#   'AR': 1.26,
#   'EUI': 180.3,
#   'FA': 252.9},
#  106: {'L': 15.7,
#   'W': 10.9,
#   'H': 2.75,
#   'WWR': 0.17,
#   'AR': 1.44,
#   'EUI': 179.7,
#   'FA': 171.1},
#  107: {'L': 17.26,
#   'W': 15.01,
#   'H': 3.82,
#   'WWR': 0.23,
#   'AR': 1.15,
#   'EUI': 191.2,
#   'FA': 259.1},
#  108: {'L': 42.6,
#   'W': 22.42,
#   'H': 3.13,
#   'WWR': 0.16,
#   'AR': 1.9,
#   'EUI': 157.2,
#   'FA': 955.1},
#  109: {'L': 34.19,
#   'W': 18.89,
#   'H': 3.98,
#   'WWR': 0.22,
#   'AR': 1.81,
#   'EUI': 172.4,
#   'FA': 645.9},
#  110: {'L': 27.95,
#   'W': 15.7,
#   'H': 2.59,
#   'WWR': 0.25,
#   'AR': 1.78,
#   'EUI': 166.4,
#   'FA': 438.8},
#  111: {'L': 27.37,
#   'W': 16.59,
#   'H': 3.41,
#   'WWR': 0.34,
#   'AR': 1.65,
#   'EUI': 181.6,
#   'FA': 454.1},
#  112: {'L': 28.75,
#   'W': 17.32,
#   'H': 3.39,
#   'WWR': 0.21,
#   'AR': 1.66,
#   'EUI': 170.4,
#   'FA': 498.0},
#  113: {'L': 16.44,
#   'W': 8.39,
#   'H': 3.75,
#   'WWR': 0.31,
#   'AR': 1.96,
#   'EUI': 226.8,
#   'FA': 137.9},
#  114: {'L': 35.35,
#   'W': 20.2,
#   'H': 2.98,
#   'WWR': 0.16,
#   'AR': 1.75,
#   'EUI': 159.0,
#   'FA': 714.1},
#  115: {'L': 15.16,
#   'W': 11.75,
#   'H': 3.95,
#   'WWR': 0.2,
#   'AR': 1.29,
#   'EUI': 201.6,
#   'FA': 178.1},
#  116: {'L': 23.23,
#   'W': 15.8,
#   'H': 2.87,
#   'WWR': 0.15,
#   'AR': 1.47,
#   'EUI': 165.7,
#   'FA': 367.0},
#  117: {'L': 25.67,
#   'W': 14.42,
#   'H': 3.37,
#   'WWR': 0.16,
#   'AR': 1.78,
#   'EUI': 172.2,
#   'FA': 370.2},
#  118: {'L': 35.05,
#   'W': 19.58,
#   'H': 3.18,
#   'WWR': 0.17,
#   'AR': 1.79,
#   'EUI': 161.6,
#   'FA': 686.3},
#  119: {'L': 39.1,
#   'W': 24.44,
#   'H': 3.76,
#   'WWR': 0.2,
#   'AR': 1.6,
#   'EUI': 162.8,
#   'FA': 955.6},
#  120: {'L': 38.22,
#   'W': 26.0,
#   'H': 3.04,
#   'WWR': 0.33,
#   'AR': 1.47,
#   'EUI': 162.7,
#   'FA': 993.7},
#  121: {'L': 38.91,
#   'W': 19.85,
#   'H': 3.97,
#   'WWR': 0.32,
#   'AR': 1.96,
#   'EUI': 175.9,
#   'FA': 772.4},
#  122: {'L': 27.59,
#   'W': 19.57,
#   'H': 2.63,
#   'WWR': 0.2,
#   'AR': 1.41,
#   'EUI': 160.9,
#   'FA': 539.9},
#  123: {'L': 19.21,
#   'W': 16.14,
#   'H': 3.86,
#   'WWR': 0.22,
#   'AR': 1.19,
#   'EUI': 185.9,
#   'FA': 310.1},
#  124: {'L': 30.86,
#   'W': 27.8,
#   'H': 2.94,
#   'WWR': 0.27,
#   'AR': 1.11,
#   'EUI': 160.9,
#   'FA': 857.9},
#  125: {'L': 27.0,
#   'W': 19.71,
#   'H': 3.97,
#   'WWR': 0.26,
#   'AR': 1.37,
#   'EUI': 178.1,
#   'FA': 532.2},
#  126: {'L': 34.43,
#   'W': 28.93,
#   'H': 2.98,
#   'WWR': 0.32,
#   'AR': 1.19,
#   'EUI': 161.5,
#   'FA': 996.1},
#  127: {'L': 16.1,
#   'W': 11.67,
#   'H': 2.82,
#   'WWR': 0.29,
#   'AR': 1.38,
#   'EUI': 189.8,
#   'FA': 187.9},
#  128: {'L': 25.37,
#   'W': 16.8,
#   'H': 3.45,
#   'WWR': 0.17,
#   'AR': 1.51,
#   'EUI': 170.7,
#   'FA': 426.2},
#  129: {'L': 14.55,
#   'W': 9.15,
#   'H': 3.28,
#   'WWR': 0.31,
#   'AR': 1.59,
#   'EUI': 214.7,
#   'FA': 133.1},
#  130: {'L': 36.6,
#   'W': 24.73,
#   'H': 2.92,
#   'WWR': 0.17,
#   'AR': 1.48,
#   'EUI': 156.2,
#   'FA': 905.1},
#  131: {'L': 24.72,
#   'W': 16.59,
#   'H': 2.91,
#   'WWR': 0.3,
#   'AR': 1.49,
#   'EUI': 174.0,
#   'FA': 410.1},
#  132: {'L': 30.25,
#   'W': 15.2,
#   'H': 3.82,
#   'WWR': 0.19,
#   'AR': 1.99,
#   'EUI': 175.8,
#   'FA': 459.8},
#  133: {'L': 18.31,
#   'W': 16.06,
#   'H': 2.52,
#   'WWR': 0.15,
#   'AR': 1.14,
#   'EUI': 164.9,
#   'FA': 294.1},
#  134: {'L': 36.17,
#   'W': 23.49,
#   'H': 3.58,
#   'WWR': 0.27,
#   'AR': 1.54,
#   'EUI': 166.8,
#   'FA': 849.6},
#  135: {'L': 19.34,
#   'W': 11.94,
#   'H': 3.75,
#   'WWR': 0.33,
#   'AR': 1.62,
#   'EUI': 206.2,
#   'FA': 230.9},
#  136: {'L': 20.48,
#   'W': 19.14,
#   'H': 3.98,
#   'WWR': 0.22,
#   'AR': 1.07,
#   'EUI': 181.6,
#   'FA': 392.0},
#  137: {'L': 33.22,
#   'W': 24.98,
#   'H': 3.03,
#   'WWR': 0.28,
#   'AR': 1.33,
#   'EUI': 162.6,
#   'FA': 829.8},
#  138: {'L': 41.47,
#   'W': 23.97,
#   'H': 2.95,
#   'WWR': 0.17,
#   'AR': 1.73,
#   'EUI': 155.7,
#   'FA': 994.0},
#  139: {'L': 17.71,
#   'W': 9.27,
#   'H': 3.69,
#   'WWR': 0.27,
#   'AR': 1.91,
#   'EUI': 211.6,
#   'FA': 164.2},
#  140: {'L': 29.32,
#   'W': 23.84,
#   'H': 2.69,
#   'WWR': 0.28,
#   'AR': 1.23,
#   'EUI': 161.7,
#   'FA': 699.0},
#  141: {'L': 11.49,
#   'W': 10.26,
#   'H': 3.93,
#   'WWR': 0.28,
#   'AR': 1.12,
#   'EUI': 230.2,
#   'FA': 117.9},
#  142: {'L': 18.27,
#   'W': 12.26,
#   'H': 3.79,
#   'WWR': 0.24,
#   'AR': 1.49,
#   'EUI': 196.8,
#   'FA': 224.0},
#  143: {'L': 22.62,
#   'W': 12.03,
#   'H': 3.0,
#   'WWR': 0.19,
#   'AR': 1.88,
#   'EUI': 176.3,
#   'FA': 272.1},
#  144: {'L': 30.93,
#   'W': 28.91,
#   'H': 3.75,
#   'WWR': 0.31,
#   'AR': 1.07,
#   'EUI': 169.1,
#   'FA': 894.2},
#  145: {'L': 20.89,
#   'W': 14.31,
#   'H': 2.83,
#   'WWR': 0.31,
#   'AR': 1.46,
#   'EUI': 180.1,
#   'FA': 298.9},
#  146: {'L': 23.58,
#   'W': 13.1,
#   'H': 3.32,
#   'WWR': 0.3,
#   'AR': 1.8,
#   'EUI': 187.1,
#   'FA': 308.9},
#  147: {'L': 30.45,
#   'W': 19.27,
#   'H': 2.86,
#   'WWR': 0.32,
#   'AR': 1.58,
#   'EUI': 168.4,
#   'FA': 586.8},
#  148: {'L': 31.31,
#   'W': 18.31,
#   'H': 3.11,
#   'WWR': 0.23,
#   'AR': 1.71,
#   'EUI': 166.7,
#   'FA': 573.3},
#  149: {'L': 38.54,
#   'W': 24.24,
#   'H': 2.52,
#   'WWR': 0.33,
#   'AR': 1.59,
#   'EUI': 159.1,
#   'FA': 934.2},
#  150: {'L': 26.46,
#   'W': 14.7,
#   'H': 3.04,
#   'WWR': 0.17,
#   'AR': 1.8,
#   'EUI': 168.5,
#   'FA': 389.0},
#  151: {'L': 41.72,
#   'W': 21.96,
#   'H': 3.87,
#   'WWR': 0.22,
#   'AR': 1.9,
#   'EUI': 165.9,
#   'FA': 916.2},
#  152: {'L': 30.9,
#   'W': 25.33,
#   'H': 3.4,
#   'WWR': 0.19,
#   'AR': 1.22,
#   'EUI': 162.0,
#   'FA': 782.7},
#  153: {'L': 39.86,
#   'W': 25.07,
#   'H': 2.75,
#   'WWR': 0.33,
#   'AR': 1.59,
#   'EUI': 160.3,
#   'FA': 999.3},
#  154: {'L': 24.56,
#   'W': 15.07,
#   'H': 3.33,
#   'WWR': 0.33,
#   'AR': 1.63,
#   'EUI': 184.6,
#   'FA': 370.1},
#  155: {'L': 41.69,
#   'W': 23.29,
#   'H': 3.1,
#   'WWR': 0.23,
#   'AR': 1.79,
#   'EUI': 159.7,
#   'FA': 971.0},
#  156: {'L': 24.35,
#   'W': 20.46,
#   'H': 2.64,
#   'WWR': 0.28,
#   'AR': 1.19,
#   'EUI': 165.9,
#   'FA': 498.2},
#  157: {'L': 32.44,
#   'W': 18.33,
#   'H': 3.08,
#   'WWR': 0.24,
#   'AR': 1.77,
#   'EUI': 166.5,
#   'FA': 594.6},
#  158: {'L': 21.02,
#   'W': 16.17,
#   'H': 3.72,
#   'WWR': 0.21,
#   'AR': 1.3,
#   'EUI': 181.1,
#   'FA': 339.9},
#  159: {'L': 32.81,
#   'W': 17.93,
#   'H': 3.12,
#   'WWR': 0.31,
#   'AR': 1.83,
#   'EUI': 171.2,
#   'FA': 588.3},
#  160: {'L': 37.91,
#   'W': 25.79,
#   'H': 2.93,
#   'WWR': 0.19,
#   'AR': 1.47,
#   'EUI': 156.3,
#   'FA': 977.7},
#  161: {'L': 27.27,
#   'W': 20.5,
#   'H': 3.4,
#   'WWR': 0.16,
#   'AR': 1.33,
#   'EUI': 165.0,
#   'FA': 559.0},
#  162: {'L': 35.19,
#   'W': 20.58,
#   'H': 3.68,
#   'WWR': 0.25,
#   'AR': 1.71,
#   'EUI': 169.4,
#   'FA': 724.2},
#  163: {'L': 36.71,
#   'W': 19.12,
#   'H': 2.52,
#   'WWR': 0.25,
#   'AR': 1.92,
#   'EUI': 159.7,
#   'FA': 701.9},
#  164: {'L': 13.79,
#   'W': 8.41,
#   'H': 2.66,
#   'WWR': 0.35,
#   'AR': 1.64,
#   'EUI': 209.5,
#   'FA': 116.0},
#  165: {'L': 26.55,
#   'W': 15.71,
#   'H': 3.12,
#   'WWR': 0.29,
#   'AR': 1.69,
#   'EUI': 176.2,
#   'FA': 417.1},
#  166: {'L': 35.54,
#   'W': 18.04,
#   'H': 3.04,
#   'WWR': 0.32,
#   'AR': 1.97,
#   'EUI': 169.7,
#   'FA': 641.1},
#  167: {'L': 26.71,
#   'W': 21.37,
#   'H': 2.58,
#   'WWR': 0.23,
#   'AR': 1.25,
#   'EUI': 161.0,
#   'FA': 570.8},
#  168: {'L': 18.17,
#   'W': 15.02,
#   'H': 2.76,
#   'WWR': 0.3,
#   'AR': 1.21,
#   'EUI': 179.9,
#   'FA': 272.9},
#  169: {'L': 16.39,
#   'W': 8.67,
#   'H': 2.89,
#   'WWR': 0.25,
#   'AR': 1.89,
#   'EUI': 197.0,
#   'FA': 142.1},
#  170: {'L': 42.02,
#   'W': 21.44,
#   'H': 2.75,
#   'WWR': 0.21,
#   'AR': 1.96,
#   'EUI': 157.3,
#   'FA': 900.9},
#  171: {'L': 38.61,
#   'W': 22.98,
#   'H': 3.24,
#   'WWR': 0.18,
#   'AR': 1.68,
#   'EUI': 159.3,
#   'FA': 887.3},
#  172: {'L': 21.24,
#   'W': 14.96,
#   'H': 2.67,
#   'WWR': 0.26,
#   'AR': 1.42,
#   'EUI': 172.9,
#   'FA': 317.8},
#  173: {'L': 17.3,
#   'W': 10.06,
#   'H': 3.33,
#   'WWR': 0.3,
#   'AR': 1.72,
#   'EUI': 204.8,
#   'FA': 174.0},
#  174: {'L': 26.84,
#   'W': 14.83,
#   'H': 3.91,
#   'WWR': 0.31,
#   'AR': 1.81,
#   'EUI': 189.9,
#   'FA': 398.0},
#  175: {'L': 39.39,
#   'W': 20.95,
#   'H': 3.35,
#   'WWR': 0.35,
#   'AR': 1.88,
#   'EUI': 170.1,
#   'FA': 825.2},
#  176: {'L': 23.76,
#   'W': 21.8,
#   'H': 3.56,
#   'WWR': 0.18,
#   'AR': 1.09,
#   'EUI': 168.8,
#   'FA': 518.0},
#  177: {'L': 27.24,
#   'W': 25.22,
#   'H': 3.0,
#   'WWR': 0.35,
#   'AR': 1.08,
#   'EUI': 168.4,
#   'FA': 687.0},
#  178: {'L': 36.1,
#   'W': 18.14,
#   'H': 3.93,
#   'WWR': 0.24,
#   'AR': 1.99,
#   'EUI': 173.5,
#   'FA': 654.9},
#  179: {'L': 13.45,
#   'W': 8.1,
#   'H': 3.29,
#   'WWR': 0.35,
#   'AR': 1.66,
#   'EUI': 230.4,
#   'FA': 108.9},
#  180: {'L': 20.06,
#   'W': 16.31,
#   'H': 3.83,
#   'WWR': 0.22,
#   'AR': 1.23,
#   'EUI': 184.2,
#   'FA': 327.2},
#  181: {'L': 39.58,
#   'W': 21.28,
#   'H': 2.75,
#   'WWR': 0.16,
#   'AR': 1.86,
#   'EUI': 155.8,
#   'FA': 842.3},
#  182: {'L': 11.98,
#   'W': 9.43,
#   'H': 2.77,
#   'WWR': 0.31,
#   'AR': 1.27,
#   'EUI': 207.2,
#   'FA': 113.0},
#  183: {'L': 37.27,
#   'W': 20.59,
#   'H': 2.73,
#   'WWR': 0.28,
#   'AR': 1.81,
#   'EUI': 161.6,
#   'FA': 767.4},
#  184: {'L': 36.75,
#   'W': 25.88,
#   'H': 3.23,
#   'WWR': 0.34,
#   'AR': 1.42,
#   'EUI': 165.4,
#   'FA': 951.1},
#  185: {'L': 37.72,
#   'W': 23.14,
#   'H': 2.97,
#   'WWR': 0.31,
#   'AR': 1.63,
#   'EUI': 163.2,
#   'FA': 872.8},
#  186: {'L': 17.11,
#   'W': 11.33,
#   'H': 3.63,
#   'WWR': 0.24,
#   'AR': 1.51,
#   'EUI': 198.8,
#   'FA': 193.9},
#  187: {'L': 19.39,
#   'W': 10.26,
#   'H': 3.4,
#   'WWR': 0.26,
#   'AR': 1.89,
#   'EUI': 197.6,
#   'FA': 198.9},
#  188: {'L': 28.67,
#   'W': 23.5,
#   'H': 3.91,
#   'WWR': 0.2,
#   'AR': 1.22,
#   'EUI': 168.7,
#   'FA': 673.8},
#  189: {'L': 31.39,
#   'W': 26.83,
#   'H': 3.51,
#   'WWR': 0.23,
#   'AR': 1.17,
#   'EUI': 163.8,
#   'FA': 842.2},
#  190: {'L': 31.42,
#   'W': 20.14,
#   'H': 3.25,
#   'WWR': 0.32,
#   'AR': 1.56,
#   'EUI': 171.3,
#   'FA': 632.8},
#  191: {'L': 15.45,
#   'W': 11.53,
#   'H': 3.6,
#   'WWR': 0.25,
#   'AR': 1.34,
#   'EUI': 201.8,
#   'FA': 178.1},
#  192: {'L': 31.86,
#   'W': 21.1,
#   'H': 3.19,
#   'WWR': 0.29,
#   'AR': 1.51,
#   'EUI': 167.9,
#   'FA': 672.3},
#  193: {'L': 29.82,
#   'W': 23.3,
#   'H': 3.44,
#   'WWR': 0.22,
#   'AR': 1.28,
#   'EUI': 165.6,
#   'FA': 694.8},
#  194: {'L': 42.3,
#   'W': 22.74,
#   'H': 2.6,
#   'WWR': 0.3,
#   'AR': 1.86,
#   'EUI': 158.7,
#   'FA': 961.9},
#  195: {'L': 26.83,
#   'W': 13.76,
#   'H': 3.13,
#   'WWR': 0.17,
#   'AR': 1.95,
#   'EUI': 170.8,
#   'FA': 369.2},
#  196: {'L': 28.71,
#   'W': 15.11,
#   'H': 2.95,
#   'WWR': 0.27,
#   'AR': 1.9,
#   'EUI': 172.4,
#   'FA': 433.8},
#  197: {'L': 30.64,
#   'W': 18.57,
#   'H': 2.84,
#   'WWR': 0.21,
#   'AR': 1.65,
#   'EUI': 163.0,
#   'FA': 569.0},
#  198: {'L': 27.92,
#   'W': 18.01,
#   'H': 3.68,
#   'WWR': 0.16,
#   'AR': 1.55,
#   'EUI': 169.5,
#   'FA': 502.8},
#  199: {'L': 20.77,
#   'W': 15.27,
#   'H': 3.94,
#   'WWR': 0.35,
#   'AR': 1.36,
#   'EUI': 199.8,
#   'FA': 317.2},
#  200: {'L': 28.95,
#   'W': 22.27,
#   'H': 2.73,
#   'WWR': 0.32,
#   'AR': 1.3,
#   'EUI': 165.1,
#   'FA': 644.7},
#  201: {'L': 29.1,
#   'W': 17.22,
#   'H': 3.45,
#   'WWR': 0.31,
#   'AR': 1.69,
#   'EUI': 177.9,
#   'FA': 501.1},
#  202: {'L': 39.05,
#   'W': 24.87,
#   'H': 3.86,
#   'WWR': 0.19,
#   'AR': 1.57,
#   'EUI': 162.8,
#   'FA': 971.2},
#  203: {'L': 29.01,
#   'W': 27.37,
#   'H': 3.59,
#   'WWR': 0.23,
#   'AR': 1.06,
#   'EUI': 165.3,
#   'FA': 794.0},
#  204: {'L': 21.49,
#   'W': 14.52,
#   'H': 2.77,
#   'WWR': 0.33,
#   'AR': 1.48,
#   'EUI': 179.8,
#   'FA': 312.0},
#  205: {'L': 43.49,
#   'W': 22.19,
#   'H': 3.31,
#   'WWR': 0.29,
#   'AR': 1.96,
#   'EUI': 164.5,
#   'FA': 965.0},
#  206: {'L': 27.45,
#   'W': 27.18,
#   'H': 2.72,
#   'WWR': 0.26,
#   'AR': 1.01,
#   'EUI': 160.3,
#   'FA': 746.1},
#  207: {'L': 20.36,
#   'W': 11.84,
#   'H': 3.84,
#   'WWR': 0.26,
#   'AR': 1.72,
#   'EUI': 198.5,
#   'FA': 241.1},
#  208: {'L': 38.1,
#   'W': 22.28,
#   'H': 3.4,
#   'WWR': 0.27,
#   'AR': 1.71,
#   'EUI': 165.6,
#   'FA': 848.9},
#  209: {'L': 20.77,
#   'W': 10.49,
#   'H': 3.05,
#   'WWR': 0.23,
#   'AR': 1.98,
#   'EUI': 186.0,
#   'FA': 217.9},
#  210: {'L': 30.01,
#   'W': 19.36,
#   'H': 3.76,
#   'WWR': 0.27,
#   'AR': 1.55,
#   'EUI': 175.2,
#   'FA': 581.0},
#  211: {'L': 21.96,
#   'W': 18.45,
#   'H': 3.02,
#   'WWR': 0.19,
#   'AR': 1.19,
#   'EUI': 168.1,
#   'FA': 405.2},
#  212: {'L': 34.86,
#   'W': 27.02,
#   'H': 3.25,
#   'WWR': 0.16,
#   'AR': 1.29,
#   'EUI': 157.4,
#   'FA': 941.9},
#  213: {'L': 33.74,
#   'W': 19.06,
#   'H': 3.33,
#   'WWR': 0.25,
#   'AR': 1.77,
#   'EUI': 168.3,
#   'FA': 643.1},
#  214: {'L': 25.7,
#   'W': 24.48,
#   'H': 3.15,
#   'WWR': 0.32,
#   'AR': 1.05,
#   'EUI': 169.9,
#   'FA': 629.1},
#  215: {'L': 32.42,
#   'W': 21.47,
#   'H': 3.22,
#   'WWR': 0.3,
#   'AR': 1.51,
#   'EUI': 168.2,
#   'FA': 696.1},
#  216: {'L': 15.2,
#   'W': 12.56,
#   'H': 2.88,
#   'WWR': 0.2,
#   'AR': 1.21,
#   'EUI': 181.7,
#   'FA': 190.9},
#  217: {'L': 36.45,
#   'W': 20.25,
#   'H': 3.99,
#   'WWR': 0.19,
#   'AR': 1.8,
#   'EUI': 168.2,
#   'FA': 738.1},
#  218: {'L': 32.81,
#   'W': 29.83,
#   'H': 3.46,
#   'WWR': 0.28,
#   'AR': 1.1,
#   'EUI': 163.8,
#   'FA': 978.7},
#  219: {'L': 13.3,
#   'W': 7.6,
#   'H': 2.83,
#   'WWR': 0.18,
#   'AR': 1.75,
#   'EUI': 197.4,
#   'FA': 101.1},
#  220: {'L': 18.47,
#   'W': 9.52,
#   'H': 3.59,
#   'WWR': 0.28,
#   'AR': 1.94,
#   'EUI': 208.4,
#   'FA': 175.8},
#  221: {'L': 35.71,
#   'W': 24.29,
#   'H': 2.91,
#   'WWR': 0.24,
#   'AR': 1.47,
#   'EUI': 159.5,
#   'FA': 867.4},
#  222: {'L': 22.65,
#   'W': 15.62,
#   'H': 3.15,
#   'WWR': 0.23,
#   'AR': 1.45,
#   'EUI': 175.0,
#   'FA': 353.8},
#  223: {'L': 34.28,
#   'W': 17.67,
#   'H': 3.97,
#   'WWR': 0.17,
#   'AR': 1.94,
#   'EUI': 170.4,
#   'FA': 605.7},
#  224: {'L': 28.6,
#   'W': 23.64,
#   'H': 2.89,
#   'WWR': 0.23,
#   'AR': 1.21,
#   'EUI': 161.7,
#   'FA': 676.1},
#  225: {'L': 30.93,
#   'W': 27.13,
#   'H': 3.75,
#   'WWR': 0.16,
#   'AR': 1.14,
#   'EUI': 162.0,
#   'FA': 839.1},
#  226: {'L': 37.08,
#   'W': 21.07,
#   'H': 3.62,
#   'WWR': 0.29,
#   'AR': 1.76,
#   'EUI': 170.0,
#   'FA': 781.3},
#  227: {'L': 24.59,
#   'W': 18.63,
#   'H': 3.87,
#   'WWR': 0.17,
#   'AR': 1.32,
#   'EUI': 173.3,
#   'FA': 458.1},
#  228: {'L': 26.3,
#   'W': 13.35,
#   'H': 2.52,
#   'WWR': 0.16,
#   'AR': 1.97,
#   'EUI': 164.1,
#   'FA': 351.1},
#  229: {'L': 42.82,
#   'W': 23.02,
#   'H': 3.42,
#   'WWR': 0.29,
#   'AR': 1.86,
#   'EUI': 164.8,
#   'FA': 985.7},
#  230: {'L': 30.89,
#   'W': 15.76,
#   'H': 2.52,
#   'WWR': 0.15,
#   'AR': 1.96,
#   'EUI': 159.4,
#   'FA': 486.8},
#  231: {'L': 31.98,
#   'W': 21.61,
#   'H': 3.89,
#   'WWR': 0.27,
#   'AR': 1.48,
#   'EUI': 172.9,
#   'FA': 691.1},
#  232: {'L': 35.75,
#   'W': 19.75,
#   'H': 3.5,
#   'WWR': 0.28,
#   'AR': 1.81,
#   'EUI': 170.2,
#   'FA': 706.1},
#  233: {'L': 10.96,
#   'W': 9.13,
#   'H': 3.81,
#   'WWR': 0.27,
#   'AR': 1.2,
#   'EUI': 233.7,
#   'FA': 100.1},
#  234: {'L': 20.89,
#   'W': 14.02,
#   'H': 2.87,
#   'WWR': 0.19,
#   'AR': 1.49,
#   'EUI': 172.2,
#   'FA': 292.9},
#  235: {'L': 13.95,
#   'W': 8.02,
#   'H': 3.58,
#   'WWR': 0.34,
#   'AR': 1.74,
#   'EUI': 236.2,
#   'FA': 111.9},
#  236: {'L': 29.48,
#   'W': 24.16,
#   'H': 2.82,
#   'WWR': 0.23,
#   'AR': 1.22,
#   'EUI': 160.4,
#   'FA': 712.2},
#  237: {'L': 22.94,
#   'W': 11.95,
#   'H': 3.83,
#   'WWR': 0.24,
#   'AR': 1.92,
#   'EUI': 192.9,
#   'FA': 274.1},
#  238: {'L': 32.21,
#   'W': 16.52,
#   'H': 3.41,
#   'WWR': 0.18,
#   'AR': 1.95,
#   'EUI': 168.2,
#   'FA': 532.1},
#  239: {'L': 13.23,
#   'W': 7.78,
#   'H': 3.43,
#   'WWR': 0.29,
#   'AR': 1.7,
#   'EUI': 227.6,
#   'FA': 102.9},
#  240: {'L': 36.94,
#   'W': 20.52,
#   'H': 2.85,
#   'WWR': 0.29,
#   'AR': 1.8,
#   'EUI': 163.4,
#   'FA': 758.0},
#  241: {'L': 32.99,
#   'W': 16.92,
#   'H': 3.23,
#   'WWR': 0.25,
#   'AR': 1.95,
#   'EUI': 170.0,
#   'FA': 558.2},
#  242: {'L': 24.48,
#   'W': 16.21,
#   'H': 3.55,
#   'WWR': 0.35,
#   'AR': 1.51,
#   'EUI': 187.4,
#   'FA': 396.8},
#  243: {'L': 22.9,
#   'W': 14.68,
#   'H': 2.62,
#   'WWR': 0.35,
#   'AR': 1.56,
#   'EUI': 177.3,
#   'FA': 336.2},
#  244: {'L': 23.69,
#   'W': 17.55,
#   'H': 3.82,
#   'WWR': 0.16,
#   'AR': 1.35,
#   'EUI': 173.9,
#   'FA': 415.8},
#  245: {'L': 22.22,
#   'W': 18.36,
#   'H': 3.7,
#   'WWR': 0.28,
#   'AR': 1.21,
#   'EUI': 182.4,
#   'FA': 408.0},
#  246: {'L': 22.8,
#   'W': 12.81,
#   'H': 3.57,
#   'WWR': 0.21,
#   'AR': 1.78,
#   'EUI': 183.9,
#   'FA': 292.1},
#  247: {'L': 18.04,
#   'W': 12.03,
#   'H': 3.37,
#   'WWR': 0.27,
#   'AR': 1.5,
#   'EUI': 194.0,
#   'FA': 217.0},
#  248: {'L': 11.4,
#   'W': 9.66,
#   'H': 2.96,
#   'WWR': 0.28,
#   'AR': 1.18,
#   'EUI': 209.0,
#   'FA': 110.1},
#  249: {'L': 17.76,
#   'W': 9.92,
#   'H': 3.29,
#   'WWR': 0.24,
#   'AR': 1.79,
#   'EUI': 196.7,
#   'FA': 176.2},
#  250: {'L': 37.78,
#   'W': 22.76,
#   'H': 3.54,
#   'WWR': 0.27,
#   'AR': 1.66,
#   'EUI': 166.4,
#   'FA': 859.9},
#  251: {'L': 33.82,
#   'W': 22.7,
#   'H': 3.43,
#   'WWR': 0.32,
#   'AR': 1.49,
#   'EUI': 169.7,
#   'FA': 767.7},
#  252: {'L': 27.36,
#   'W': 13.82,
#   'H': 3.81,
#   'WWR': 0.17,
#   'AR': 1.98,
#   'EUI': 178.0,
#   'FA': 378.1},
#  253: {'L': 35.57,
#   'W': 19.65,
#   'H': 2.8,
#   'WWR': 0.35,
#   'AR': 1.81,
#   'EUI': 166.9,
#   'FA': 699.0},
#  254: {'L': 16.66,
#   'W': 9.36,
#   'H': 2.58,
#   'WWR': 0.25,
#   'AR': 1.78,
#   'EUI': 187.4,
#   'FA': 155.9},
#  255: {'L': 28.15,
#   'W': 17.93,
#   'H': 2.84,
#   'WWR': 0.15,
#   'AR': 1.57,
#   'EUI': 161.2,
#   'FA': 504.7},
#  256: {'L': 34.71,
#   'W': 25.15,
#   'H': 3.39,
#   'WWR': 0.28,
#   'AR': 1.38,
#   'EUI': 165.1,
#   'FA': 873.0},
#  257: {'L': 26.73,
#   'W': 23.24,
#   'H': 3.51,
#   'WWR': 0.3,
#   'AR': 1.15,
#   'EUI': 172.7,
#   'FA': 621.2},
#  258: {'L': 31.82,
#   'W': 27.43,
#   'H': 2.58,
#   'WWR': 0.32,
#   'AR': 1.16,
#   'EUI': 159.6,
#   'FA': 872.8},
#  259: {'L': 17.22,
#   'W': 14.0,
#   'H': 3.13,
#   'WWR': 0.15,
#   'AR': 1.23,
#   'EUI': 175.8,
#   'FA': 241.1},
#  260: {'L': 31.52,
#   'W': 17.71,
#   'H': 3.2,
#   'WWR': 0.26,
#   'AR': 1.78,
#   'EUI': 169.9,
#   'FA': 558.2},
#  261: {'L': 30.65,
#   'W': 19.52,
#   'H': 3.64,
#   'WWR': 0.34,
#   'AR': 1.57,
#   'EUI': 178.1,
#   'FA': 598.3},
#  262: {'L': 41.18,
#   'W': 21.56,
#   'H': 3.04,
#   'WWR': 0.24,
#   'AR': 1.91,
#   'EUI': 160.9,
#   'FA': 887.8},
#  263: {'L': 41.79,
#   'W': 21.88,
#   'H': 3.21,
#   'WWR': 0.15,
#   'AR': 1.91,
#   'EUI': 157.7,
#   'FA': 914.4},
#  264: {'L': 21.98,
#   'W': 15.7,
#   'H': 2.62,
#   'WWR': 0.16,
#   'AR': 1.4,
#   'EUI': 164.5,
#   'FA': 345.1},
#  265: {'L': 18.0,
#   'W': 12.16,
#   'H': 2.91,
#   'WWR': 0.17,
#   'AR': 1.48,
#   'EUI': 176.9,
#   'FA': 218.9},
#  266: {'L': 19.28,
#   'W': 15.93,
#   'H': 3.54,
#   'WWR': 0.22,
#   'AR': 1.21,
#   'EUI': 181.9,
#   'FA': 307.1},
#  267: {'L': 13.85,
#   'W': 12.48,
#   'H': 3.33,
#   'WWR': 0.27,
#   'AR': 1.11,
#   'EUI': 199.9,
#   'FA': 172.9},
#  268: {'L': 40.63,
#   'W': 21.61,
#   'H': 2.63,
#   'WWR': 0.27,
#   'AR': 1.88,
#   'EUI': 158.9,
#   'FA': 878.0},
#  269: {'L': 41.56,
#   'W': 20.99,
#   'H': 3.86,
#   'WWR': 0.23,
#   'AR': 1.98,
#   'EUI': 167.3,
#   'FA': 872.3},
#  270: {'L': 39.01,
#   'W': 19.8,
#   'H': 3.93,
#   'WWR': 0.24,
#   'AR': 1.97,
#   'EUI': 170.4,
#   'FA': 772.4},
#  271: {'L': 19.95,
#   'W': 14.78,
#   'H': 3.61,
#   'WWR': 0.3,
#   'AR': 1.35,
#   'EUI': 191.7,
#   'FA': 294.9},
#  272: {'L': 37.85,
#   'W': 25.23,
#   'H': 3.45,
#   'WWR': 0.31,
#   'AR': 1.5,
#   'EUI': 165.9,
#   'FA': 955.0},
#  273: {'L': 13.72,
#   'W': 9.4,
#   'H': 3.9,
#   'WWR': 0.21,
#   'AR': 1.46,
#   'EUI': 214.6,
#   'FA': 129.0},
#  274: {'L': 23.13,
#   'W': 12.24,
#   'H': 2.96,
#   'WWR': 0.22,
#   'AR': 1.89,
#   'EUI': 177.3,
#   'FA': 283.1},
#  275: {'L': 37.52,
#   'W': 23.02,
#   'H': 3.84,
#   'WWR': 0.16,
#   'AR': 1.63,
#   'EUI': 162.7,
#   'FA': 863.7},
#  276: {'L': 37.57,
#   'W': 26.09,
#   'H': 3.28,
#   'WWR': 0.15,
#   'AR': 1.44,
#   'EUI': 156.8,
#   'FA': 980.2},
#  277: {'L': 30.26,
#   'W': 22.58,
#   'H': 3.32,
#   'WWR': 0.3,
#   'AR': 1.34,
#   'EUI': 169.2,
#   'FA': 683.3},
#  278: {'L': 26.95,
#   'W': 18.21,
#   'H': 3.2,
#   'WWR': 0.26,
#   'AR': 1.48,
#   'EUI': 171.6,
#   'FA': 490.8},
#  279: {'L': 14.76,
#   'W': 11.18,
#   'H': 2.98,
#   'WWR': 0.17,
#   'AR': 1.32,
#   'EUI': 184.1,
#   'FA': 165.0},
#  280: {'L': 41.38,
#   'W': 22.86,
#   'H': 3.61,
#   'WWR': 0.18,
#   'AR': 1.81,
#   'EUI': 161.3,
#   'FA': 946.0},
#  281: {'L': 21.18,
#   'W': 19.79,
#   'H': 2.72,
#   'WWR': 0.19,
#   'AR': 1.07,
#   'EUI': 164.4,
#   'FA': 419.2},
#  282: {'L': 19.73,
#   'W': 12.41,
#   'H': 3.54,
#   'WWR': 0.3,
#   'AR': 1.59,
#   'EUI': 196.8,
#   'FA': 244.9},
#  283: {'L': 39.23,
#   'W': 25.31,
#   'H': 3.39,
#   'WWR': 0.28,
#   'AR': 1.55,
#   'EUI': 163.5,
#   'FA': 992.9},
#  284: {'L': 19.48,
#   'W': 18.38,
#   'H': 3.77,
#   'WWR': 0.23,
#   'AR': 1.06,
#   'EUI': 182.1,
#   'FA': 358.0},
#  285: {'L': 25.14,
#   'W': 16.87,
#   'H': 3.43,
#   'WWR': 0.32,
#   'AR': 1.49,
#   'EUI': 181.6,
#   'FA': 424.1},
#  286: {'L': 39.78,
#   'W': 20.61,
#   'H': 3.96,
#   'WWR': 0.19,
#   'AR': 1.93,
#   'EUI': 166.6,
#   'FA': 819.9},
#  287: {'L': 31.38,
#   'W': 19.61,
#   'H': 3.05,
#   'WWR': 0.33,
#   'AR': 1.6,
#   'EUI': 170.3,
#   'FA': 615.4},
#  288: {'L': 16.98,
#   'W': 12.67,
#   'H': 3.99,
#   'WWR': 0.24,
#   'AR': 1.34,
#   'EUI': 201.1,
#   'FA': 215.1},
#  289: {'L': 32.31,
#   'W': 17.37,
#   'H': 2.94,
#   'WWR': 0.28,
#   'AR': 1.86,
#   'EUI': 168.4,
#   'FA': 561.2},
#  290: {'L': 26.69,
#   'W': 17.91,
#   'H': 2.75,
#   'WWR': 0.27,
#   'AR': 1.49,
#   'EUI': 167.5,
#   'FA': 478.0},
#  291: {'L': 16.4,
#   'W': 13.55,
#   'H': 2.99,
#   'WWR': 0.24,
#   'AR': 1.21,
#   'EUI': 183.5,
#   'FA': 222.2},
#  292: {'L': 28.94,
#   'W': 24.12,
#   'H': 3.61,
#   'WWR': 0.26,
#   'AR': 1.2,
#   'EUI': 169.2,
#   'FA': 698.0},
#  293: {'L': 36.66,
#   'W': 24.44,
#   'H': 3.5,
#   'WWR': 0.31,
#   'AR': 1.5,
#   'EUI': 167.3,
#   'FA': 896.0},
#  294: {'L': 31.71,
#   'W': 16.18,
#   'H': 2.65,
#   'WWR': 0.27,
#   'AR': 1.96,
#   'EUI': 166.2,
#   'FA': 513.1},
#  295: {'L': 12.42,
#   'W': 9.34,
#   'H': 2.75,
#   'WWR': 0.33,
#   'AR': 1.33,
#   'EUI': 208.4,
#   'FA': 116.0},
#  296: {'L': 33.15,
#   'W': 26.1,
#   'H': 3.16,
#   'WWR': 0.31,
#   'AR': 1.27,
#   'EUI': 164.6,
#   'FA': 865.2},
#  297: {'L': 30.65,
#   'W': 20.43,
#   'H': 2.58,
#   'WWR': 0.18,
#   'AR': 1.5,
#   'EUI': 157.9,
#   'FA': 626.2},
#  298: {'L': 34.28,
#   'W': 29.05,
#   'H': 2.93,
#   'WWR': 0.29,
#   'AR': 1.18,
#   'EUI': 159.9,
#   'FA': 995.8},
#  299: {'L': 31.1,
#   'W': 24.49,
#   'H': 3.2,
#   'WWR': 0.16,
#   'AR': 1.27,
#   'EUI': 159.4,
#   'FA': 761.6},
#  300: {'L': 28.49,
#   'W': 28.21,
#   'H': 3.72,
#   'WWR': 0.27,
#   'AR': 1.01,
#   'EUI': 168.4,
#   'FA': 803.7},
#  301: {'L': 28.89,
#   'W': 18.76,
#   'H': 2.68,
#   'WWR': 0.18,
#   'AR': 1.54,
#   'EUI': 160.4,
#   'FA': 542.0},
#  302: {'L': 32.58,
#   'W': 16.54,
#   'H': 3.73,
#   'WWR': 0.18,
#   'AR': 1.97,
#   'EUI': 171.1,
#   'FA': 538.9},
#  303: {'L': 34.99,
#   'W': 24.47,
#   'H': 2.68,
#   'WWR': 0.31,
#   'AR': 1.43,
#   'EUI': 160.6,
#   'FA': 856.2},
#  304: {'L': 38.61,
#   'W': 19.5,
#   'H': 3.5,
#   'WWR': 0.32,
#   'AR': 1.98,
#   'EUI': 171.8,
#   'FA': 752.9},
#  305: {'L': 44.11,
#   'W': 22.28,
#   'H': 3.56,
#   'WWR': 0.32,
#   'AR': 1.98,
#   'EUI': 167.8,
#   'FA': 982.8},
#  306: {'L': 29.27,
#   'W': 16.82,
#   'H': 2.92,
#   'WWR': 0.34,
#   'AR': 1.74,
#   'EUI': 173.7,
#   'FA': 492.3},
#  307: {'L': 35.02,
#   'W': 23.82,
#   'H': 2.93,
#   'WWR': 0.35,
#   'AR': 1.47,
#   'EUI': 165.0,
#   'FA': 834.2},
#  308: {'L': 37.76,
#   'W': 24.52,
#   'H': 3.05,
#   'WWR': 0.16,
#   'AR': 1.54,
#   'EUI': 156.5,
#   'FA': 925.9},
#  309: {'L': 21.54,
#   'W': 20.71,
#   'H': 3.42,
#   'WWR': 0.16,
#   'AR': 1.04,
#   'EUI': 168.6,
#   'FA': 446.1},
#  310: {'L': 30.02,
#   'W': 20.56,
#   'H': 3.24,
#   'WWR': 0.17,
#   'AR': 1.46,
#   'EUI': 163.0,
#   'FA': 617.2},
#  311: {'L': 16.72,
#   'W': 16.39,
#   'H': 2.81,
#   'WWR': 0.34,
#   'AR': 1.02,
#   'EUI': 183.8,
#   'FA': 274.0},
#  312: {'L': 27.19,
#   'W': 26.66,
#   'H': 2.91,
#   'WWR': 0.31,
#   'AR': 1.02,
#   'EUI': 164.7,
#   'FA': 724.9},
#  313: {'L': 40.31,
#   'W': 20.78,
#   'H': 3.39,
#   'WWR': 0.17,
#   'AR': 1.94,
#   'EUI': 161.0,
#   'FA': 837.6},
#  314: {'L': 13.55,
#   'W': 12.32,
#   'H': 2.64,
#   'WWR': 0.18,
#   'AR': 1.1,
#   'EUI': 179.0,
#   'FA': 166.9},
#  315: {'L': 13.2,
#   'W': 7.95,
#   'H': 3.43,
#   'WWR': 0.15,
#   'AR': 1.66,
#   'EUI': 204.5,
#   'FA': 104.9},
#  316: {'L': 11.78,
#   'W': 11.55,
#   'H': 3.68,
#   'WWR': 0.33,
#   'AR': 1.02,
#   'EUI': 225.4,
#   'FA': 136.1},
#  317: {'L': 27.7,
#   'W': 19.93,
#   'H': 2.72,
#   'WWR': 0.22,
#   'AR': 1.39,
#   'EUI': 162.4,
#   'FA': 552.1},
#  318: {'L': 31.67,
#   'W': 20.43,
#   'H': 3.03,
#   'WWR': 0.34,
#   'AR': 1.55,
#   'EUI': 169.6,
#   'FA': 647.0},
#  319: {'L': 28.09,
#   'W': 22.47,
#   'H': 2.82,
#   'WWR': 0.29,
#   'AR': 1.25,
#   'EUI': 164.9,
#   'FA': 631.2},
#  320: {'L': 16.05,
#   'W': 12.84,
#   'H': 2.94,
#   'WWR': 0.21,
#   'AR': 1.25,
#   'EUI': 181.8,
#   'FA': 206.1},
#  321: {'L': 16.32,
#   'W': 9.38,
#   'H': 2.55,
#   'WWR': 0.29,
#   'AR': 1.74,
#   'EUI': 191.1,
#   'FA': 153.1},
#  322: {'L': 25.26,
#   'W': 22.96,
#   'H': 3.93,
#   'WWR': 0.28,
#   'AR': 1.1,
#   'EUI': 177.1,
#   'FA': 580.0},
#  323: {'L': 35.78,
#   'W': 25.93,
#   'H': 3.98,
#   'WWR': 0.33,
#   'AR': 1.38,
#   'EUI': 171.8,
#   'FA': 927.8},
#  324: {'L': 34.09,
#   'W': 21.44,
#   'H': 3.49,
#   'WWR': 0.33,
#   'AR': 1.59,
#   'EUI': 171.9,
#   'FA': 730.9},
#  325: {'L': 38.91,
#   'W': 20.81,
#   'H': 2.82,
#   'WWR': 0.21,
#   'AR': 1.87,
#   'EUI': 158.8,
#   'FA': 809.7},
#  326: {'L': 33.2,
#   'W': 29.91,
#   'H': 2.8,
#   'WWR': 0.24,
#   'AR': 1.11,
#   'EUI': 157.0,
#   'FA': 993.0},
#  327: {'L': 31.5,
#   'W': 27.39,
#   'H': 3.17,
#   'WWR': 0.21,
#   'AR': 1.15,
#   'EUI': 160.0,
#   'FA': 862.8},
#  328: {'L': 38.74,
#   'W': 23.48,
#   'H': 3.5,
#   'WWR': 0.24,
#   'AR': 1.65,
#   'EUI': 163.7,
#   'FA': 909.6},
#  329: {'L': 13.99,
#   'W': 11.86,
#   'H': 3.79,
#   'WWR': 0.29,
#   'AR': 1.18,
#   'EUI': 213.3,
#   'FA': 165.9},
#  330: {'L': 27.95,
#   'W': 16.84,
#   'H': 3.32,
#   'WWR': 0.3,
#   'AR': 1.66,
#   'EUI': 176.8,
#   'FA': 470.7},
#  331: {'L': 31.72,
#   'W': 22.66,
#   'H': 3.32,
#   'WWR': 0.28,
#   'AR': 1.4,
#   'EUI': 167.4,
#   'FA': 718.8},
#  332: {'L': 29.42,
#   'W': 14.86,
#   'H': 2.8,
#   'WWR': 0.31,
#   'AR': 1.98,
#   'EUI': 173.1,
#   'FA': 437.2},
#  333: {'L': 39.81,
#   'W': 23.01,
#   'H': 2.7,
#   'WWR': 0.27,
#   'AR': 1.73,
#   'EUI': 158.8,
#   'FA': 916.0},
#  334: {'L': 35.91,
#   'W': 18.8,
#   'H': 2.72,
#   'WWR': 0.24,
#   'AR': 1.91,
#   'EUI': 161.5,
#   'FA': 675.1},
#  335: {'L': 22.07,
#   'W': 12.33,
#   'H': 3.44,
#   'WWR': 0.33,
#   'AR': 1.79,
#   'EUI': 195.6,
#   'FA': 272.1},
#  336: {'L': 12.61,
#   'W': 7.93,
#   'H': 3.0,
#   'WWR': 0.22,
#   'AR': 1.59,
#   'EUI': 206.4,
#   'FA': 100.0},
#  337: {'L': 22.28,
#   'W': 12.11,
#   'H': 3.73,
#   'WWR': 0.3,
#   'AR': 1.84,
#   'EUI': 197.9,
#   'FA': 269.8},
#  338: {'L': 22.25,
#   'W': 20.41,
#   'H': 3.52,
#   'WWR': 0.3,
#   'AR': 1.09,
#   'EUI': 179.2,
#   'FA': 454.1},
#  339: {'L': 28.87,
#   'W': 22.21,
#   'H': 2.57,
#   'WWR': 0.33,
#   'AR': 1.3,
#   'EUI': 164.0,
#   'FA': 641.2},
#  340: {'L': 20.76,
#   'W': 12.14,
#   'H': 3.98,
#   'WWR': 0.31,
#   'AR': 1.71,
#   'EUI': 205.2,
#   'FA': 252.0},
#  341: {'L': 24.91,
#   'W': 13.04,
#   'H': 3.61,
#   'WWR': 0.21,
#   'AR': 1.91,
#   'EUI': 182.3,
#   'FA': 324.8},
#  342: {'L': 30.7,
#   'W': 25.16,
#   'H': 3.11,
#   'WWR': 0.23,
#   'AR': 1.22,
#   'EUI': 161.8,
#   'FA': 772.4},
#  343: {'L': 31.94,
#   'W': 15.97,
#   'H': 3.89,
#   'WWR': 0.17,
#   'AR': 2.0,
#   'EUI': 172.9,
#   'FA': 510.1},
#  344: {'L': 30.13,
#   'W': 16.2,
#   'H': 3.14,
#   'WWR': 0.18,
#   'AR': 1.86,
#   'EUI': 166.8,
#   'FA': 488.1},
#  345: {'L': 39.71,
#   'W': 21.35,
#   'H': 3.71,
#   'WWR': 0.23,
#   'AR': 1.86,
#   'EUI': 166.3,
#   'FA': 847.8},
#  346: {'L': 22.69,
#   'W': 19.56,
#   'H': 3.84,
#   'WWR': 0.31,
#   'AR': 1.16,
#   'EUI': 184.5,
#   'FA': 443.8},
#  347: {'L': 23.74,
#   'W': 23.5,
#   'H': 3.43,
#   'WWR': 0.32,
#   'AR': 1.01,
#   'EUI': 175.2,
#   'FA': 557.9},
#  348: {'L': 39.33,
#   'W': 23.98,
#   'H': 2.95,
#   'WWR': 0.22,
#   'AR': 1.64,
#   'EUI': 158.2,
#   'FA': 943.1},
#  349: {'L': 32.02,
#   'W': 21.49,
#   'H': 3.42,
#   'WWR': 0.18,
#   'AR': 1.49,
#   'EUI': 163.6,
#   'FA': 688.1},
#  350: {'L': 14.83,
#   'W': 10.59,
#   'H': 3.21,
#   'WWR': 0.33,
#   'AR': 1.4,
#   'EUI': 208.4,
#   'FA': 157.1},
#  351: {'L': 35.96,
#   'W': 23.05,
#   'H': 3.41,
#   'WWR': 0.24,
#   'AR': 1.56,
#   'EUI': 164.2,
#   'FA': 828.9},
#  352: {'L': 31.78,
#   'W': 19.03,
#   'H': 3.08,
#   'WWR': 0.26,
#   'AR': 1.67,
#   'EUI': 167.2,
#   'FA': 604.8},
#  353: {'L': 22.11,
#   'W': 18.58,
#   'H': 2.71,
#   'WWR': 0.2,
#   'AR': 1.19,
#   'EUI': 165.1,
#   'FA': 410.8},
#  354: {'L': 33.77,
#   'W': 20.59,
#   'H': 3.11,
#   'WWR': 0.3,
#   'AR': 1.64,
#   'EUI': 167.4,
#   'FA': 695.3},
#  355: {'L': 40.76,
#   'W': 21.12,
#   'H': 2.9,
#   'WWR': 0.24,
#   'AR': 1.93,
#   'EUI': 160.2,
#   'FA': 860.9},
#  356: {'L': 23.53,
#   'W': 19.77,
#   'H': 2.74,
#   'WWR': 0.18,
#   'AR': 1.19,
#   'EUI': 162.6,
#   'FA': 465.2},
#  357: {'L': 30.17,
#   'W': 21.4,
#   'H': 2.96,
#   'WWR': 0.32,
#   'AR': 1.41,
#   'EUI': 167.6,
#   'FA': 645.6},
#  358: {'L': 18.96,
#   'W': 11.56,
#   'H': 2.63,
#   'WWR': 0.2,
#   'AR': 1.64,
#   'EUI': 175.5,
#   'FA': 219.2},
#  359: {'L': 31.82,
#   'W': 19.64,
#   'H': 3.84,
#   'WWR': 0.19,
#   'AR': 1.62,
#   'EUI': 169.3,
#   'FA': 624.9},
#  360: {'L': 22.1,
#   'W': 19.22,
#   'H': 3.83,
#   'WWR': 0.15,
#   'AR': 1.15,
#   'EUI': 172.7,
#   'FA': 424.8},
#  361: {'L': 27.26,
#   'W': 17.25,
#   'H': 2.93,
#   'WWR': 0.24,
#   'AR': 1.58,
#   'EUI': 168.2,
#   'FA': 470.2},
#  362: {'L': 36.43,
#   'W': 23.5,
#   'H': 2.69,
#   'WWR': 0.3,
#   'AR': 1.55,
#   'EUI': 160.4,
#   'FA': 856.1},
#  363: {'L': 41.49,
#   'W': 21.61,
#   'H': 3.12,
#   'WWR': 0.24,
#   'AR': 1.92,
#   'EUI': 161.4,
#   'FA': 896.6},
#  364: {'L': 36.23,
#   'W': 19.69,
#   'H': 2.58,
#   'WWR': 0.17,
#   'AR': 1.84,
#   'EUI': 156.5,
#   'FA': 713.4},
#  365: {'L': 40.41,
#   'W': 23.63,
#   'H': 3.22,
#   'WWR': 0.2,
#   'AR': 1.71,
#   'EUI': 159.3,
#   'FA': 954.9},
#  366: {'L': 24.09,
#   'W': 16.06,
#   'H': 2.64,
#   'WWR': 0.22,
#   'AR': 1.5,
#   'EUI': 166.7,
#   'FA': 386.9},
#  367: {'L': 19.04,
#   'W': 10.88,
#   'H': 2.91,
#   'WWR': 0.24,
#   'AR': 1.75,
#   'EUI': 185.1,
#   'FA': 207.2},
#  368: {'L': 21.47,
#   'W': 17.6,
#   'H': 3.42,
#   'WWR': 0.33,
#   'AR': 1.22,
#   'EUI': 184.6,
#   'FA': 377.9},
#  369: {'L': 14.77,
#   'W': 14.62,
#   'H': 2.79,
#   'WWR': 0.28,
#   'AR': 1.01,
#   'EUI': 184.4,
#   'FA': 215.9},
#  370: {'L': 16.93,
#   'W': 14.11,
#   'H': 2.66,
#   'WWR': 0.29,
#   'AR': 1.2,
#   'EUI': 180.5,
#   'FA': 238.9},
#  371: {'L': 27.59,
#   'W': 24.42,
#   'H': 3.9,
#   'WWR': 0.32,
#   'AR': 1.13,
#   'EUI': 176.4,
#   'FA': 673.8},
#  372: {'L': 25.45,
#   'W': 20.36,
#   'H': 3.79,
#   'WWR': 0.29,
#   'AR': 1.25,
#   'EUI': 178.8,
#   'FA': 518.2},
#  373: {'L': 15.41,
#   'W': 13.17,
#   'H': 3.52,
#   'WWR': 0.34,
#   'AR': 1.17,
#   'EUI': 206.3,
#   'FA': 203.0},
#  374: {'L': 16.18,
#   'W': 8.84,
#   'H': 3.17,
#   'WWR': 0.18,
#   'AR': 1.83,
#   'EUI': 193.9,
#   'FA': 143.0},
#  375: {'L': 26.16,
#   'W': 21.44,
#   'H': 2.81,
#   'WWR': 0.26,
#   'AR': 1.22,
#   'EUI': 164.9,
#   'FA': 560.9},
#  376: {'L': 30.93,
#   'W': 26.9,
#   'H': 3.73,
#   'WWR': 0.29,
#   'AR': 1.15,
#   'EUI': 169.0,
#   'FA': 832.0},
#  377: {'L': 37.31,
#   'W': 25.73,
#   'H': 3.6,
#   'WWR': 0.29,
#   'AR': 1.45,
#   'EUI': 166.0,
#   'FA': 960.0},
#  378: {'L': 35.13,
#   'W': 28.1,
#   'H': 3.7,
#   'WWR': 0.35,
#   'AR': 1.25,
#   'EUI': 169.2,
#   'FA': 987.2},
#  379: {'L': 41.28,
#   'W': 23.19,
#   'H': 3.18,
#   'WWR': 0.26,
#   'AR': 1.78,
#   'EUI': 161.8,
#   'FA': 957.3},
#  380: {'L': 25.78,
#   'W': 19.83,
#   'H': 3.03,
#   'WWR': 0.18,
#   'AR': 1.3,
#   'EUI': 164.1,
#   'FA': 511.2},
#  381: {'L': 22.27,
#   'W': 13.92,
#   'H': 3.38,
#   'WWR': 0.26,
#   'AR': 1.6,
#   'EUI': 183.8,
#   'FA': 310.0},
#  382: {'L': 25.09,
#   'W': 13.71,
#   'H': 3.37,
#   'WWR': 0.15,
#   'AR': 1.83,
#   'EUI': 173.0,
#   'FA': 344.0},
#  383: {'L': 21.08,
#   'W': 18.02,
#   'H': 2.64,
#   'WWR': 0.29,
#   'AR': 1.17,
#   'EUI': 170.9,
#   'FA': 379.9},
#  384: {'L': 34.93,
#   'W': 23.6,
#   'H': 3.4,
#   'WWR': 0.18,
#   'AR': 1.48,
#   'EUI': 161.0,
#   'FA': 824.4},
#  385: {'L': 21.64,
#   'W': 12.58,
#   'H': 3.88,
#   'WWR': 0.19,
#   'AR': 1.72,
#   'EUI': 187.8,
#   'FA': 272.2},
#  386: {'L': 33.31,
#   'W': 26.44,
#   'H': 3.01,
#   'WWR': 0.34,
#   'AR': 1.26,
#   'EUI': 164.3,
#   'FA': 880.7},
#  387: {'L': 34.32,
#   'W': 18.16,
#   'H': 3.69,
#   'WWR': 0.17,
#   'AR': 1.89,
#   'EUI': 167.4,
#   'FA': 623.3},
#  388: {'L': 19.65,
#   'W': 16.94,
#   'H': 4.0,
#   'WWR': 0.33,
#   'AR': 1.16,
#   'EUI': 196.8,
#   'FA': 332.9},
#  389: {'L': 22.8,
#   'W': 12.81,
#   'H': 3.46,
#   'WWR': 0.16,
#   'AR': 1.78,
#   'EUI': 178.0,
#   'FA': 292.1},
#  390: {'L': 32.8,
#   'W': 24.12,
#   'H': 3.6,
#   'WWR': 0.29,
#   'AR': 1.36,
#   'EUI': 168.9,
#   'FA': 791.1},
#  391: {'L': 33.3,
#   'W': 20.81,
#   'H': 3.64,
#   'WWR': 0.32,
#   'AR': 1.6,
#   'EUI': 173.9,
#   'FA': 693.0},
#  392: {'L': 39.49,
#   'W': 21.58,
#   'H': 3.03,
#   'WWR': 0.27,
#   'AR': 1.83,
#   'EUI': 162.6,
#   'FA': 852.2},
#  393: {'L': 13.7,
#   'W': 11.61,
#   'H': 3.47,
#   'WWR': 0.26,
#   'AR': 1.18,
#   'EUI': 204.3,
#   'FA': 159.1},
#  394: {'L': 35.77,
#   'W': 19.13,
#   'H': 2.6,
#   'WWR': 0.35,
#   'AR': 1.87,
#   'EUI': 165.2,
#   'FA': 684.3},
#  395: {'L': 25.18,
#   'W': 21.16,
#   'H': 3.36,
#   'WWR': 0.2,
#   'AR': 1.19,
#   'EUI': 167.7,
#   'FA': 532.8},
#  396: {'L': 15.57,
#   'W': 14.83,
#   'H': 2.67,
#   'WWR': 0.24,
#   'AR': 1.05,
#   'EUI': 177.5,
#   'FA': 230.9},
#  397: {'L': 31.07,
#   'W': 18.83,
#   'H': 3.82,
#   'WWR': 0.31,
#   'AR': 1.65,
#   'EUI': 178.7,
#   'FA': 585.1},
#  398: {'L': 32.08,
#   'W': 18.98,
#   'H': 3.62,
#   'WWR': 0.28,
#   'AR': 1.69,
#   'EUI': 173.8,
#   'FA': 608.9},
#  399: {'L': 36.69,
#   'W': 24.3,
#   'H': 3.71,
#   'WWR': 0.34,
#   'AR': 1.51,
#   'EUI': 170.9,
#   'FA': 891.6},
#  400: {'L': 29.83,
#   'W': 29.83,
#   'H': 3.42,
#   'WWR': 0.24,
#   'AR': 1.0,
#   'EUI': 162.9,
#   'FA': 889.8},
#  401: {'L': 15.37,
#   'W': 7.88,
#   'H': 3.79,
#   'WWR': 0.17,
#   'AR': 1.95,
#   'EUI': 210.9,
#   'FA': 121.1},
#  402: {'L': 18.39,
#   'W': 9.24,
#   'H': 2.58,
#   'WWR': 0.28,
#   'AR': 1.99,
#   'EUI': 188.8,
#   'FA': 169.9},
#  403: {'L': 38.95,
#   'W': 20.18,
#   'H': 3.73,
#   'WWR': 0.22,
#   'AR': 1.93,
#   'EUI': 167.2,
#   'FA': 786.0},
#  404: {'L': 30.11,
#   'W': 21.82,
#   'H': 3.52,
#   'WWR': 0.32,
#   'AR': 1.38,
#   'EUI': 173.2,
#   'FA': 657.0},
#  405: {'L': 36.54,
#   'W': 21.62,
#   'H': 3.09,
#   'WWR': 0.27,
#   'AR': 1.69,
#   'EUI': 163.8,
#   'FA': 790.0},
#  406: {'L': 34.74,
#   'W': 21.99,
#   'H': 3.63,
#   'WWR': 0.27,
#   'AR': 1.58,
#   'EUI': 169.0,
#   'FA': 763.9},
#  407: {'L': 24.17,
#   'W': 21.02,
#   'H': 3.98,
#   'WWR': 0.25,
#   'AR': 1.15,
#   'EUI': 178.2,
#   'FA': 508.1},
#  408: {'L': 21.2,
#   'W': 11.04,
#   'H': 3.63,
#   'WWR': 0.25,
#   'AR': 1.92,
#   'EUI': 195.6,
#   'FA': 234.1},
#  409: {'L': 25.45,
#   'W': 22.13,
#   'H': 3.34,
#   'WWR': 0.29,
#   'AR': 1.15,
#   'EUI': 172.1,
#   'FA': 563.2},
#  410: {'L': 30.14,
#   'W': 18.05,
#   'H': 2.62,
#   'WWR': 0.32,
#   'AR': 1.67,
#   'EUI': 167.0,
#   'FA': 544.0},
#  411: {'L': 32.14,
#   'W': 23.12,
#   'H': 3.59,
#   'WWR': 0.22,
#   'AR': 1.39,
#   'EUI': 165.9,
#   'FA': 743.1},
#  412: {'L': 15.09,
#   'W': 7.82,
#   'H': 3.84,
#   'WWR': 0.21,
#   'AR': 1.93,
#   'EUI': 219.4,
#   'FA': 118.0},
#  413: {'L': 27.02,
#   'W': 17.21,
#   'H': 3.04,
#   'WWR': 0.3,
#   'AR': 1.57,
#   'EUI': 173.4,
#   'FA': 465.0},
#  414: {'L': 37.76,
#   'W': 25.86,
#   'H': 3.43,
#   'WWR': 0.33,
#   'AR': 1.46,
#   'EUI': 166.3,
#   'FA': 976.5},
#  415: {'L': 38.5,
#   'W': 21.04,
#   'H': 3.28,
#   'WWR': 0.18,
#   'AR': 1.83,
#   'EUI': 160.9,
#   'FA': 810.0},
#  416: {'L': 21.95,
#   'W': 19.09,
#   'H': 3.39,
#   'WWR': 0.18,
#   'AR': 1.15,
#   'EUI': 170.7,
#   'FA': 419.0},
#  417: {'L': 19.17,
#   'W': 10.59,
#   'H': 3.36,
#   'WWR': 0.28,
#   'AR': 1.81,
#   'EUI': 198.2,
#   'FA': 203.0},
#  418: {'L': 14.55,
#   'W': 11.28,
#   'H': 3.53,
#   'WWR': 0.22,
#   'AR': 1.29,
#   'EUI': 199.4,
#   'FA': 164.1},
#  419: {'L': 18.62,
#   'W': 13.49,
#   'H': 3.37,
#   'WWR': 0.19,
#   'AR': 1.38,
#   'EUI': 181.9,
#   'FA': 251.2},
#  420: {'L': 28.51,
#   'W': 15.75,
#   'H': 2.57,
#   'WWR': 0.27,
#   'AR': 1.81,
#   'EUI': 167.0,
#   'FA': 449.0},
#  421: {'L': 38.35,
#   'W': 23.1,
#   'H': 2.71,
#   'WWR': 0.33,
#   'AR': 1.66,
#   'EUI': 161.5,
#   'FA': 885.9},
#  422: {'L': 27.51,
#   'W': 18.22,
#   'H': 3.99,
#   'WWR': 0.21,
#   'AR': 1.51,
#   'EUI': 176.0,
#   'FA': 501.2},
#  423: {'L': 38.84,
#   'W': 20.44,
#   'H': 3.31,
#   'WWR': 0.23,
#   'AR': 1.9,
#   'EUI': 164.1,
#   'FA': 793.9},
#  424: {'L': 17.14,
#   'W': 9.63,
#   'H': 2.53,
#   'WWR': 0.31,
#   'AR': 1.78,
#   'EUI': 190.7,
#   'FA': 165.1},
#  425: {'L': 17.04,
#   'W': 10.39,
#   'H': 3.62,
#   'WWR': 0.34,
#   'AR': 1.64,
#   'EUI': 215.2,
#   'FA': 177.1},
#  426: {'L': 11.78,
#   'W': 10.61,
#   'H': 2.7,
#   'WWR': 0.29,
#   'AR': 1.11,
#   'EUI': 199.3,
#   'FA': 125.0},
#  427: {'L': 18.32,
#   'W': 12.13,
#   'H': 2.9,
#   'WWR': 0.28,
#   'AR': 1.51,
#   'EUI': 186.1,
#   'FA': 222.2},
#  428: {'L': 13.04,
#   'W': 10.43,
#   'H': 3.25,
#   'WWR': 0.3,
#   'AR': 1.25,
#   'EUI': 210.6,
#   'FA': 136.0},
#  429: {'L': 22.67,
#   'W': 22.45,
#   'H': 3.98,
#   'WWR': 0.21,
#   'AR': 1.01,
#   'EUI': 175.2,
#   'FA': 508.9},
#  430: {'L': 34.06,
#   'W': 23.49,
#   'H': 2.85,
#   'WWR': 0.28,
#   'AR': 1.45,
#   'EUI': 161.7,
#   'FA': 800.1},
#  431: {'L': 19.08,
#   'W': 15.26,
#   'H': 3.11,
#   'WWR': 0.33,
#   'AR': 1.25,
#   'EUI': 186.5,
#   'FA': 291.2},
#  432: {'L': 29.39,
#   'W': 18.84,
#   'H': 3.66,
#   'WWR': 0.32,
#   'AR': 1.56,
#   'EUI': 178.6,
#   'FA': 553.7},
#  433: {'L': 22.45,
#   'W': 14.87,
#   'H': 3.51,
#   'WWR': 0.32,
#   'AR': 1.51,
#   'EUI': 188.9,
#   'FA': 333.8},
#  434: {'L': 36.46,
#   'W': 18.89,
#   'H': 2.94,
#   'WWR': 0.34,
#   'AR': 1.93,
#   'EUI': 168.4,
#   'FA': 688.7},
#  435: {'L': 23.08,
#   'W': 15.81,
#   'H': 2.97,
#   'WWR': 0.23,
#   'AR': 1.46,
#   'EUI': 172.2,
#   'FA': 364.9},
#  436: {'L': 36.9,
#   'W': 18.73,
#   'H': 2.79,
#   'WWR': 0.34,
#   'AR': 1.97,
#   'EUI': 166.8,
#   'FA': 691.1},
#  437: {'L': 22.73,
#   'W': 15.05,
#   'H': 3.25,
#   'WWR': 0.17,
#   'AR': 1.51,
#   'EUI': 172.5,
#   'FA': 342.1},
#  438: {'L': 30.48,
#   'W': 27.46,
#   'H': 2.87,
#   'WWR': 0.24,
#   'AR': 1.11,
#   'EUI': 159.4,
#   'FA': 837.0},
#  439: {'L': 22.51,
#   'W': 15.11,
#   'H': 3.53,
#   'WWR': 0.32,
#   'AR': 1.49,
#   'EUI': 188.6,
#   'FA': 340.1},
#  440: {'L': 28.2,
#   'W': 14.61,
#   'H': 2.52,
#   'WWR': 0.31,
#   'AR': 1.93,
#   'EUI': 170.3,
#   'FA': 412.0},
#  441: {'L': 30.69,
#   'W': 15.74,
#   'H': 3.14,
#   'WWR': 0.24,
#   'AR': 1.95,
#   'EUI': 170.9,
#   'FA': 483.1},
#  442: {'L': 21.14,
#   'W': 10.73,
#   'H': 2.52,
#   'WWR': 0.34,
#   'AR': 1.97,
#   'EUI': 185.3,
#   'FA': 226.8},
#  443: {'L': 41.03,
#   'W': 21.26,
#   'H': 3.38,
#   'WWR': 0.23,
#   'AR': 1.93,
#   'EUI': 163.4,
#   'FA': 872.3},
#  444: {'L': 31.24,
#   'W': 23.85,
#   'H': 3.14,
#   'WWR': 0.21,
#   'AR': 1.31,
#   'EUI': 161.6,
#   'FA': 745.1},
#  445: {'L': 35.14,
#   'W': 23.27,
#   'H': 2.61,
#   'WWR': 0.27,
#   'AR': 1.51,
#   'EUI': 159.0,
#   'FA': 817.7},
#  446: {'L': 39.27,
#   'W': 21.34,
#   'H': 2.86,
#   'WWR': 0.34,
#   'AR': 1.84,
#   'EUI': 164.4,
#   'FA': 838.0},
#  447: {'L': 21.66,
#   'W': 16.66,
#   'H': 3.53,
#   'WWR': 0.3,
#   'AR': 1.3,
#   'EUI': 184.9,
#   'FA': 360.9},
#  448: {'L': 23.74,
#   'W': 12.43,
#   'H': 3.18,
#   'WWR': 0.22,
#   'AR': 1.91,
#   'EUI': 179.6,
#   'FA': 295.1},
#  449: {'L': 34.84,
#   'W': 23.07,
#   'H': 3.54,
#   'WWR': 0.17,
#   'AR': 1.51,
#   'EUI': 161.9,
#   'FA': 803.8},
#  450: {'L': 38.75,
#   'W': 22.53,
#   'H': 3.61,
#   'WWR': 0.26,
#   'AR': 1.72,
#   'EUI': 166.4,
#   'FA': 873.0},
#  451: {'L': 29.65,
#   'W': 20.88,
#   'H': 3.2,
#   'WWR': 0.19,
#   'AR': 1.42,
#   'EUI': 163.7,
#   'FA': 619.1},
#  452: {'L': 23.44,
#   'W': 12.88,
#   'H': 2.5,
#   'WWR': 0.19,
#   'AR': 1.82,
#   'EUI': 167.7,
# ...
#   'EUI': 177.5,
#   'FA': 256.0},
#  851: {'L': 36.61,
#   'W': 23.62,
#   'H': 3.29,
#   'WWR': 0.21,
#   'AR': 1.55,
#   'EUI': 161.2,
#   'FA': 864.7},
#  852: {'L': 41.83,
#   'W': 21.9,
#   'H': 3.1,
#   'WWR': 0.17,
#   'AR': 1.91,
#   'EUI': 157.9,
#   'FA': 916.1},
#  853: {'L': 29.29,
#   'W': 18.19,
#   'H': 3.94,
#   'WWR': 0.3,
#   'AR': 1.61,
#   'EUI': 181.4,
#   'FA': 532.8},
#  854: {'L': 22.88,
#   'W': 15.25,
#   'H': 3.67,
#   'WWR': 0.16,
#   'AR': 1.5,
#   'EUI': 176.0,
#   'FA': 348.9},
#  855: {'L': 33.84,
#   'W': 17.09,
#   'H': 2.55,
#   'WWR': 0.2,
#   'AR': 1.98,
#   'EUI': 160.1,
#   'FA': 578.3},
#  856: {'L': 36.27,
#   'W': 19.19,
#   'H': 2.86,
#   'WWR': 0.17,
#   'AR': 1.89,
#   'EUI': 159.1,
#   'FA': 696.0},
#  857: {'L': 20.36,
#   'W': 14.44,
#   'H': 3.02,
#   'WWR': 0.21,
#   'AR': 1.41,
#   'EUI': 175.4,
#   'FA': 294.0},
#  858: {'L': 25.75,
#   'W': 21.82,
#   'H': 2.75,
#   'WWR': 0.16,
#   'AR': 1.18,
#   'EUI': 159.3,
#   'FA': 561.9},
#  859: {'L': 22.37,
#   'W': 18.64,
#   'H': 2.7,
#   'WWR': 0.27,
#   'AR': 1.2,
#   'EUI': 168.8,
#   'FA': 417.0},
#  860: {'L': 15.95,
#   'W': 10.85,
#   'H': 2.98,
#   'WWR': 0.19,
#   'AR': 1.47,
#   'EUI': 185.2,
#   'FA': 173.1},
#  861: {'L': 40.97,
#   'W': 22.51,
#   'H': 3.46,
#   'WWR': 0.34,
#   'AR': 1.82,
#   'EUI': 168.6,
#   'FA': 922.2},
#  862: {'L': 20.98,
#   'W': 12.2,
#   'H': 2.55,
#   'WWR': 0.17,
#   'AR': 1.72,
#   'EUI': 169.5,
#   'FA': 256.0},
#  863: {'L': 29.22,
#   'W': 22.48,
#   'H': 3.11,
#   'WWR': 0.25,
#   'AR': 1.3,
#   'EUI': 165.1,
#   'FA': 656.9},
#  864: {'L': 39.33,
#   'W': 23.55,
#   'H': 2.68,
#   'WWR': 0.22,
#   'AR': 1.67,
#   'EUI': 156.5,
#   'FA': 926.2},
#  865: {'L': 26.0,
#   'W': 19.12,
#   'H': 3.2,
#   'WWR': 0.17,
#   'AR': 1.36,
#   'EUI': 165.6,
#   'FA': 497.1},
#  866: {'L': 23.35,
#   'W': 16.1,
#   'H': 2.55,
#   'WWR': 0.27,
#   'AR': 1.45,
#   'EUI': 169.0,
#   'FA': 375.9},
#  867: {'L': 23.89,
#   'W': 13.27,
#   'H': 3.39,
#   'WWR': 0.16,
#   'AR': 1.8,
#   'EUI': 175.5,
#   'FA': 317.0},
#  868: {'L': 33.87,
#   'W': 26.46,
#   'H': 3.47,
#   'WWR': 0.33,
#   'AR': 1.28,
#   'EUI': 167.8,
#   'FA': 896.2},
#  869: {'L': 24.81,
#   'W': 17.85,
#   'H': 3.08,
#   'WWR': 0.25,
#   'AR': 1.39,
#   'EUI': 171.2,
#   'FA': 442.9},
#  870: {'L': 31.87,
#   'W': 17.61,
#   'H': 3.23,
#   'WWR': 0.34,
#   'AR': 1.81,
#   'EUI': 175.2,
#   'FA': 561.2},
#  871: {'L': 35.48,
#   'W': 23.97,
#   'H': 3.29,
#   'WWR': 0.26,
#   'AR': 1.48,
#   'EUI': 163.8,
#   'FA': 850.5},
#  872: {'L': 18.53,
#   'W': 13.43,
#   'H': 3.18,
#   'WWR': 0.22,
#   'AR': 1.38,
#   'EUI': 182.1,
#   'FA': 248.9},
#  873: {'L': 35.57,
#   'W': 23.1,
#   'H': 3.45,
#   'WWR': 0.34,
#   'AR': 1.54,
#   'EUI': 169.9,
#   'FA': 821.7},
#  874: {'L': 24.5,
#   'W': 19.6,
#   'H': 2.76,
#   'WWR': 0.15,
#   'AR': 1.25,
#   'EUI': 160.8,
#   'FA': 480.2},
#  875: {'L': 28.17,
#   'W': 19.84,
#   'H': 2.92,
#   'WWR': 0.17,
#   'AR': 1.42,
#   'EUI': 161.5,
#   'FA': 558.9},
#  876: {'L': 30.15,
#   'W': 27.66,
#   'H': 3.93,
#   'WWR': 0.2,
#   'AR': 1.09,
#   'EUI': 165.6,
#   'FA': 834.0},
#  877: {'L': 29.24,
#   'W': 25.21,
#   'H': 3.28,
#   'WWR': 0.25,
#   'AR': 1.16,
#   'EUI': 164.9,
#   'FA': 737.1},
#  878: {'L': 15.36,
#   'W': 14.91,
#   'H': 3.68,
#   'WWR': 0.29,
#   'AR': 1.03,
#   'EUI': 199.4,
#   'FA': 229.0},
#  879: {'L': 16.89,
#   'W': 9.88,
#   'H': 2.96,
#   'WWR': 0.21,
#   'AR': 1.71,
#   'EUI': 188.5,
#   'FA': 166.9},
#  880: {'L': 27.9,
#   'W': 13.95,
#   'H': 3.17,
#   'WWR': 0.32,
#   'AR': 2.0,
#   'EUI': 181.5,
#   'FA': 389.2},
#  881: {'L': 20.93,
#   'W': 14.95,
#   'H': 3.21,
#   'WWR': 0.2,
#   'AR': 1.4,
#   'EUI': 175.9,
#   'FA': 312.9},
#  882: {'L': 35.19,
#   'W': 27.49,
#   'H': 3.8,
#   'WWR': 0.21,
#   'AR': 1.28,
#   'EUI': 163.1,
#   'FA': 967.4},
#  883: {'L': 17.29,
#   'W': 14.29,
#   'H': 3.83,
#   'WWR': 0.32,
#   'AR': 1.21,
#   'EUI': 202.9,
#   'FA': 247.1},
#  884: {'L': 12.48,
#   'W': 8.16,
#   'H': 3.55,
#   'WWR': 0.17,
#   'AR': 1.53,
#   'EUI': 210.7,
#   'FA': 101.8},
#  885: {'L': 33.35,
#   'W': 18.53,
#   'H': 3.3,
#   'WWR': 0.33,
#   'AR': 1.8,
#   'EUI': 173.5,
#   'FA': 618.0},
#  886: {'L': 28.16,
#   'W': 18.17,
#   'H': 3.38,
#   'WWR': 0.29,
#   'AR': 1.55,
#   'EUI': 174.9,
#   'FA': 511.7},
#  887: {'L': 33.83,
#   'W': 21.41,
#   'H': 3.97,
#   'WWR': 0.17,
#   'AR': 1.58,
#   'EUI': 166.7,
#   'FA': 724.3},
#  888: {'L': 36.61,
#   'W': 21.41,
#   'H': 2.91,
#   'WWR': 0.26,
#   'AR': 1.71,
#   'EUI': 161.9,
#   'FA': 783.8},
#  889: {'L': 31.51,
#   'W': 31.2,
#   'H': 3.35,
#   'WWR': 0.31,
#   'AR': 1.01,
#   'EUI': 164.3,
#   'FA': 983.1},
#  890: {'L': 26.8,
#   'W': 26.27,
#   'H': 2.84,
#   'WWR': 0.17,
#   'AR': 1.02,
#   'EUI': 158.0,
#   'FA': 704.0},
#  891: {'L': 28.38,
#   'W': 17.41,
#   'H': 3.96,
#   'WWR': 0.18,
#   'AR': 1.63,
#   'EUI': 174.0,
#   'FA': 494.1},
#  892: {'L': 32.67,
#   'W': 28.41,
#   'H': 3.2,
#   'WWR': 0.35,
#   'AR': 1.15,
#   'EUI': 165.7,
#   'FA': 928.2},
#  893: {'L': 31.61,
#   'W': 29.27,
#   'H': 2.67,
#   'WWR': 0.22,
#   'AR': 1.08,
#   'EUI': 156.0,
#   'FA': 925.2},
#  894: {'L': 27.99,
#   'W': 16.86,
#   'H': 3.55,
#   'WWR': 0.22,
#   'AR': 1.66,
#   'EUI': 173.7,
#   'FA': 471.9},
#  895: {'L': 43.6,
#   'W': 22.71,
#   'H': 3.6,
#   'WWR': 0.28,
#   'AR': 1.92,
#   'EUI': 165.8,
#   'FA': 990.2},
#  896: {'L': 20.44,
#   'W': 14.92,
#   'H': 2.59,
#   'WWR': 0.28,
#   'AR': 1.37,
#   'EUI': 173.8,
#   'FA': 305.0},
#  897: {'L': 34.75,
#   'W': 26.94,
#   'H': 2.6,
#   'WWR': 0.18,
#   'AR': 1.29,
#   'EUI': 154.0,
#   'FA': 936.2},
#  898: {'L': 28.95,
#   'W': 21.93,
#   'H': 2.58,
#   'WWR': 0.21,
#   'AR': 1.32,
#   'EUI': 158.9,
#   'FA': 634.9},
#  899: {'L': 32.53,
#   'W': 22.75,
#   'H': 3.37,
#   'WWR': 0.24,
#   'AR': 1.43,
#   'EUI': 165.3,
#   'FA': 740.1},
#  900: {'L': 35.88,
#   'W': 23.45,
#   'H': 4.0,
#   'WWR': 0.19,
#   'AR': 1.53,
#   'EUI': 165.7,
#   'FA': 841.4},
#  901: {'L': 27.92,
#   'W': 20.38,
#   'H': 3.35,
#   'WWR': 0.21,
#   'AR': 1.37,
#   'EUI': 167.3,
#   'FA': 569.0},
#  902: {'L': 18.29,
#   'W': 10.45,
#   'H': 2.94,
#   'WWR': 0.2,
#   'AR': 1.75,
#   'EUI': 183.8,
#   'FA': 191.1},
#  903: {'L': 38.91,
#   'W': 24.02,
#   'H': 3.88,
#   'WWR': 0.29,
#   'AR': 1.62,
#   'EUI': 168.9,
#   'FA': 934.6},
#  904: {'L': 27.75,
#   'W': 14.23,
#   'H': 2.79,
#   'WWR': 0.28,
#   'AR': 1.95,
#   'EUI': 172.9,
#   'FA': 394.9},
#  905: {'L': 29.47,
#   'W': 27.8,
#   'H': 3.23,
#   'WWR': 0.23,
#   'AR': 1.06,
#   'EUI': 162.1,
#   'FA': 819.3},
#  906: {'L': 24.36,
#   'W': 21.18,
#   'H': 3.76,
#   'WWR': 0.29,
#   'AR': 1.15,
#   'EUI': 178.5,
#   'FA': 515.9},
#  907: {'L': 24.54,
#   'W': 15.24,
#   'H': 3.3,
#   'WWR': 0.18,
#   'AR': 1.61,
#   'EUI': 172.4,
#   'FA': 374.0},
#  908: {'L': 31.77,
#   'W': 23.36,
#   'H': 3.2,
#   'WWR': 0.34,
#   'AR': 1.36,
#   'EUI': 168.8,
#   'FA': 742.2},
#  909: {'L': 37.01,
#   'W': 20.56,
#   'H': 2.8,
#   'WWR': 0.18,
#   'AR': 1.8,
#   'EUI': 157.9,
#   'FA': 760.9},
#  910: {'L': 30.02,
#   'W': 21.29,
#   'H': 3.77,
#   'WWR': 0.34,
#   'AR': 1.41,
#   'EUI': 177.8,
#   'FA': 639.1},
#  911: {'L': 22.55,
#   'W': 12.46,
#   'H': 3.8,
#   'WWR': 0.23,
#   'AR': 1.81,
#   'EUI': 190.2,
#   'FA': 281.0},
#  912: {'L': 17.29,
#   'W': 14.17,
#   'H': 3.99,
#   'WWR': 0.26,
#   'AR': 1.22,
#   'EUI': 198.9,
#   'FA': 245.0},
#  913: {'L': 31.42,
#   'W': 18.93,
#   'H': 3.95,
#   'WWR': 0.21,
#   'AR': 1.66,
#   'EUI': 172.6,
#   'FA': 594.8},
#  914: {'L': 18.92,
#   'W': 18.19,
#   'H': 3.37,
#   'WWR': 0.28,
#   'AR': 1.04,
#   'EUI': 182.1,
#   'FA': 344.2},
#  915: {'L': 26.52,
#   'W': 15.24,
#   'H': 3.0,
#   'WWR': 0.21,
#   'AR': 1.74,
#   'EUI': 170.0,
#   'FA': 404.2},
#  916: {'L': 28.46,
#   'W': 17.04,
#   'H': 2.93,
#   'WWR': 0.26,
#   'AR': 1.67,
#   'EUI': 169.1,
#   'FA': 485.0},
#  917: {'L': 37.53,
#   'W': 19.75,
#   'H': 2.55,
#   'WWR': 0.33,
#   'AR': 1.9,
#   'EUI': 162.7,
#   'FA': 741.2},
#  918: {'L': 34.7,
#   'W': 18.96,
#   'H': 2.94,
#   'WWR': 0.31,
#   'AR': 1.83,
#   'EUI': 167.4,
#   'FA': 657.9},
#  919: {'L': 39.96,
#   'W': 22.45,
#   'H': 3.41,
#   'WWR': 0.23,
#   'AR': 1.78,
#   'EUI': 163.0,
#   'FA': 897.1},
#  920: {'L': 13.81,
#   'W': 8.47,
#   'H': 2.52,
#   'WWR': 0.33,
#   'AR': 1.63,
#   'EUI': 202.9,
#   'FA': 117.0},
#  921: {'L': 14.73,
#   'W': 8.82,
#   'H': 3.5,
#   'WWR': 0.2,
#   'AR': 1.67,
#   'EUI': 205.4,
#   'FA': 129.9},
#  922: {'L': 21.85,
#   'W': 12.63,
#   'H': 3.86,
#   'WWR': 0.28,
#   'AR': 1.73,
#   'EUI': 196.7,
#   'FA': 276.0},
#  923: {'L': 17.67,
#   'W': 12.62,
#   'H': 2.83,
#   'WWR': 0.33,
#   'AR': 1.4,
#   'EUI': 189.0,
#   'FA': 223.0},
#  924: {'L': 23.24,
#   'W': 20.39,
#   'H': 3.21,
#   'WWR': 0.24,
#   'AR': 1.14,
#   'EUI': 170.7,
#   'FA': 473.9},
#  925: {'L': 29.29,
#   'W': 19.02,
#   'H': 3.2,
#   'WWR': 0.16,
#   'AR': 1.54,
#   'EUI': 163.6,
#   'FA': 557.1},
#  926: {'L': 18.52,
#   'W': 12.86,
#   'H': 3.99,
#   'WWR': 0.33,
#   'AR': 1.44,
#   'EUI': 208.9,
#   'FA': 238.2},
#  927: {'L': 30.38,
#   'W': 30.08,
#   'H': 2.68,
#   'WWR': 0.19,
#   'AR': 1.01,
#   'EUI': 155.1,
#   'FA': 913.8},
#  928: {'L': 12.69,
#   'W': 8.19,
#   'H': 3.2,
#   'WWR': 0.21,
#   'AR': 1.55,
#   'EUI': 208.1,
#   'FA': 103.9},
#  929: {'L': 13.64,
#   'W': 10.18,
#   'H': 2.76,
#   'WWR': 0.23,
#   'AR': 1.34,
#   'EUI': 190.9,
#   'FA': 138.9},
#  930: {'L': 42.01,
#   'W': 22.11,
#   'H': 3.39,
#   'WWR': 0.17,
#   'AR': 1.9,
#   'EUI': 159.7,
#   'FA': 928.8},
#  931: {'L': 27.43,
#   'W': 24.94,
#   'H': 2.73,
#   'WWR': 0.16,
#   'AR': 1.1,
#   'EUI': 157.0,
#   'FA': 684.1},
#  932: {'L': 44.32,
#   'W': 22.16,
#   'H': 3.97,
#   'WWR': 0.26,
#   'AR': 2.0,
#   'EUI': 168.0,
#   'FA': 982.1},
#  933: {'L': 27.71,
#   'W': 14.21,
#   'H': 2.99,
#   'WWR': 0.25,
#   'AR': 1.95,
#   'EUI': 173.5,
#   'FA': 393.8},
#  934: {'L': 35.68,
#   'W': 25.13,
#   'H': 3.49,
#   'WWR': 0.19,
#   'AR': 1.42,
#   'EUI': 161.0,
#   'FA': 896.6},
#  935: {'L': 24.31,
#   'W': 21.14,
#   'H': 3.0,
#   'WWR': 0.21,
#   'AR': 1.15,
#   'EUI': 165.4,
#   'FA': 513.9},
#  936: {'L': 30.44,
#   'W': 29.84,
#   'H': 3.81,
#   'WWR': 0.22,
#   'AR': 1.02,
#   'EUI': 164.5,
#   'FA': 908.3},
#  937: {'L': 38.89,
#   'W': 23.57,
#   'H': 3.86,
#   'WWR': 0.15,
#   'AR': 1.65,
#   'EUI': 161.5,
#   'FA': 916.6},
#  938: {'L': 20.3,
#   'W': 14.0,
#   'H': 3.82,
#   'WWR': 0.31,
#   'AR': 1.45,
#   'EUI': 197.4,
#   'FA': 284.2},
#  939: {'L': 27.28,
#   'W': 23.72,
#   'H': 3.86,
#   'WWR': 0.18,
#   'AR': 1.15,
#   'EUI': 167.7,
#   'FA': 647.1},
#  940: {'L': 40.23,
#   'W': 22.86,
#   'H': 2.85,
#   'WWR': 0.17,
#   'AR': 1.76,
#   'EUI': 155.9,
#   'FA': 919.7},
#  941: {'L': 37.31,
#   'W': 24.23,
#   'H': 3.34,
#   'WWR': 0.15,
#   'AR': 1.54,
#   'EUI': 158.2,
#   'FA': 904.0},
#  942: {'L': 17.28,
#   'W': 10.47,
#   'H': 2.71,
#   'WWR': 0.22,
#   'AR': 1.65,
#   'EUI': 182.8,
#   'FA': 180.9},
#  943: {'L': 15.54,
#   'W': 8.05,
#   'H': 3.85,
#   'WWR': 0.31,
#   'AR': 1.93,
#   'EUI': 234.0,
#   'FA': 125.1},
#  944: {'L': 25.5,
#   'W': 13.21,
#   'H': 3.78,
#   'WWR': 0.29,
#   'AR': 1.93,
#   'EUI': 191.3,
#   'FA': 336.9},
#  945: {'L': 33.4,
#   'W': 29.3,
#   'H': 2.62,
#   'WWR': 0.2,
#   'AR': 1.14,
#   'EUI': 154.4,
#   'FA': 978.6},
#  946: {'L': 15.57,
#   'W': 9.05,
#   'H': 3.23,
#   'WWR': 0.35,
#   'AR': 1.72,
#   'EUI': 217.2,
#   'FA': 140.9},
#  947: {'L': 30.25,
#   'W': 27.01,
#   'H': 3.51,
#   'WWR': 0.33,
#   'AR': 1.12,
#   'EUI': 169.6,
#   'FA': 817.1},
#  948: {'L': 15.34,
#   'W': 11.2,
#   'H': 2.98,
#   'WWR': 0.32,
#   'AR': 1.37,
#   'EUI': 198.8,
#   'FA': 171.8},
#  949: {'L': 31.32,
#   'W': 18.64,
#   'H': 2.52,
#   'WWR': 0.33,
#   'AR': 1.68,
#   'EUI': 165.3,
#   'FA': 583.8},
#  950: {'L': 21.55,
#   'W': 17.96,
#   'H': 2.5,
#   'WWR': 0.23,
#   'AR': 1.2,
#   'EUI': 165.4,
#   'FA': 387.0},
#  951: {'L': 18.03,
#   'W': 9.59,
#   'H': 2.68,
#   'WWR': 0.35,
#   'AR': 1.88,
#   'EUI': 197.0,
#   'FA': 172.9},
#  952: {'L': 37.36,
#   'W': 20.53,
#   'H': 3.12,
#   'WWR': 0.24,
#   'AR': 1.82,
#   'EUI': 163.3,
#   'FA': 767.0},
#  953: {'L': 13.79,
#   'W': 11.89,
#   'H': 2.96,
#   'WWR': 0.31,
#   'AR': 1.16,
#   'EUI': 198.5,
#   'FA': 164.0},
#  954: {'L': 13.64,
#   'W': 10.18,
#   'H': 2.65,
#   'WWR': 0.29,
#   'AR': 1.34,
#   'EUI': 195.1,
#   'FA': 138.9},
#  955: {'L': 13.18,
#   'W': 9.48,
#   'H': 3.64,
#   'WWR': 0.34,
#   'AR': 1.39,
#   'EUI': 230.4,
#   'FA': 125.0},
#  956: {'L': 28.52,
#   'W': 17.94,
#   'H': 3.71,
#   'WWR': 0.32,
#   'AR': 1.59,
#   'EUI': 181.0,
#   'FA': 511.7},
#  957: {'L': 32.24,
#   'W': 27.79,
#   'H': 3.75,
#   'WWR': 0.21,
#   'AR': 1.16,
#   'EUI': 163.7,
#   'FA': 896.0},
#  958: {'L': 13.69,
#   'W': 13.16,
#   'H': 3.44,
#   'WWR': 0.24,
#   'AR': 1.04,
#   'EUI': 197.1,
#   'FA': 180.2},
#  959: {'L': 37.65,
#   'W': 25.79,
#   'H': 3.48,
#   'WWR': 0.22,
#   'AR': 1.46,
#   'EUI': 161.5,
#   'FA': 971.0},
#  960: {'L': 22.68,
#   'W': 15.97,
#   'H': 3.35,
#   'WWR': 0.2,
#   'AR': 1.42,
#   'EUI': 174.7,
#   'FA': 362.2},
#  961: {'L': 20.76,
#   'W': 14.12,
#   'H': 3.86,
#   'WWR': 0.21,
#   'AR': 1.47,
#   'EUI': 186.9,
#   'FA': 293.1},
#  962: {'L': 34.66,
#   'W': 21.53,
#   'H': 3.45,
#   'WWR': 0.35,
#   'AR': 1.61,
#   'EUI': 172.3,
#   'FA': 746.2},
#  963: {'L': 31.43,
#   'W': 18.71,
#   'H': 3.95,
#   'WWR': 0.18,
#   'AR': 1.68,
#   'EUI': 170.8,
#   'FA': 588.1},
#  964: {'L': 35.91,
#   'W': 22.03,
#   'H': 3.8,
#   'WWR': 0.24,
#   'AR': 1.63,
#   'EUI': 168.2,
#   'FA': 791.1},
#  965: {'L': 31.49,
#   'W': 21.87,
#   'H': 3.1,
#   'WWR': 0.28,
#   'AR': 1.44,
#   'EUI': 166.0,
#   'FA': 688.7},
#  966: {'L': 32.97,
#   'W': 17.35,
#   'H': 3.35,
#   'WWR': 0.21,
#   'AR': 1.9,
#   'EUI': 168.2,
#   'FA': 572.0},
#  967: {'L': 36.97,
#   'W': 23.4,
#   'H': 3.94,
#   'WWR': 0.31,
#   'AR': 1.58,
#   'EUI': 171.9,
#   'FA': 865.1},
#  968: {'L': 22.06,
#   'W': 11.61,
#   'H': 3.6,
#   'WWR': 0.32,
#   'AR': 1.9,
#   'EUI': 199.8,
#   'FA': 256.1},
#  969: {'L': 36.67,
#   'W': 26.77,
#   'H': 2.66,
#   'WWR': 0.3,
#   'AR': 1.37,
#   'EUI': 158.4,
#   'FA': 981.7},
#  970: {'L': 27.69,
#   'W': 19.5,
#   'H': 3.02,
#   'WWR': 0.22,
#   'AR': 1.42,
#   'EUI': 165.6,
#   'FA': 540.0},
#  971: {'L': 21.29,
#   'W': 14.1,
#   'H': 3.97,
#   'WWR': 0.24,
#   'AR': 1.51,
#   'EUI': 190.9,
#   'FA': 300.2},
#  972: {'L': 35.24,
#   'W': 27.75,
#   'H': 3.17,
#   'WWR': 0.17,
#   'AR': 1.27,
#   'EUI': 156.9,
#   'FA': 977.9},
#  973: {'L': 15.4,
#   'W': 13.05,
#   'H': 3.74,
#   'WWR': 0.16,
#   'AR': 1.18,
#   'EUI': 189.5,
#   'FA': 201.0},
#  974: {'L': 22.08,
#   'W': 16.48,
#   'H': 3.02,
#   'WWR': 0.23,
#   'AR': 1.34,
#   'EUI': 172.7,
#   'FA': 363.9},
#  975: {'L': 32.51,
#   'W': 16.76,
#   'H': 2.69,
#   'WWR': 0.27,
#   'AR': 1.94,
#   'EUI': 165.7,
#   'FA': 544.9},
#  976: {'L': 15.0,
#   'W': 10.0,
#   'H': 3.51,
#   'WWR': 0.18,
#   'AR': 1.5,
#   'EUI': 197.5,
#   'FA': 150.0},
#  977: {'L': 16.79,
#   'W': 15.84,
#   'H': 3.37,
#   'WWR': 0.29,
#   'AR': 1.06,
#   'EUI': 189.6,
#   'FA': 266.0},
#  978: {'L': 13.72,
#   'W': 7.58,
#   'H': 3.24,
#   'WWR': 0.2,
#   'AR': 1.81,
#   'EUI': 208.7,
#   'FA': 104.0},
#  979: {'L': 27.68,
#   'W': 20.81,
#   'H': 3.97,
#   'WWR': 0.18,
#   'AR': 1.33,
#   'EUI': 170.7,
#   'FA': 576.0},
#  980: {'L': 33.04,
#   'W': 19.21,
#   'H': 3.02,
#   'WWR': 0.19,
#   'AR': 1.72,
#   'EUI': 162.2,
#   'FA': 634.7},
#  981: {'L': 26.36,
#   'W': 18.18,
#   'H': 2.64,
#   'WWR': 0.19,
#   'AR': 1.45,
#   'EUI': 162.0,
#   'FA': 479.2},
#  982: {'L': 31.6,
#   'W': 17.46,
#   'H': 3.73,
#   'WWR': 0.35,
#   'AR': 1.81,
#   'EUI': 182.4,
#   'FA': 551.7},
#  983: {'L': 15.46,
#   'W': 11.12,
#   'H': 3.57,
#   'WWR': 0.19,
#   'AR': 1.39,
#   'EUI': 195.2,
#   'FA': 171.9},
#  984: {'L': 31.7,
#   'W': 18.87,
#   'H': 2.57,
#   'WWR': 0.19,
#   'AR': 1.68,
#   'EUI': 159.0,
#   'FA': 598.2},
#  985: {'L': 31.8,
#   'W': 20.92,
#   'H': 2.95,
#   'WWR': 0.26,
#   'AR': 1.52,
#   'EUI': 164.2,
#   'FA': 665.3},
#  986: {'L': 29.19,
#   'W': 23.54,
#   'H': 3.64,
#   'WWR': 0.26,
#   'AR': 1.24,
#   'EUI': 169.8,
#   'FA': 687.1},
#  987: {'L': 32.51,
#   'W': 17.02,
#   'H': 2.57,
#   'WWR': 0.3,
#   'AR': 1.91,
#   'EUI': 165.6,
#   'FA': 553.3},
#  988: {'L': 12.67,
#   'W': 11.84,
#   'H': 2.68,
#   'WWR': 0.18,
#   'AR': 1.07,
#   'EUI': 182.2,
#   'FA': 150.0},
#  989: {'L': 29.78,
#   'W': 17.52,
#   'H': 3.72,
#   'WWR': 0.33,
#   'AR': 1.7,
#   'EUI': 181.7,
#   'FA': 521.8},
#  990: {'L': 18.7,
#   'W': 13.85,
#   'H': 3.24,
#   'WWR': 0.23,
#   'AR': 1.35,
#   'EUI': 182.9,
#   'FA': 259.0},
#  991: {'L': 28.94,
#   'W': 24.95,
#   'H': 2.65,
#   'WWR': 0.33,
#   'AR': 1.16,
#   'EUI': 163.1,
#   'FA': 722.1},
#  992: {'L': 34.03,
#   'W': 17.54,
#   'H': 3.96,
#   'WWR': 0.26,
#   'AR': 1.94,
#   'EUI': 176.9,
#   'FA': 596.9},
#  993: {'L': 42.09,
#   'W': 22.27,
#   'H': 3.93,
#   'WWR': 0.16,
#   'AR': 1.89,
#   'EUI': 162.6,
#   'FA': 937.3},
#  994: {'L': 33.14,
#   'W': 20.21,
#   'H': 2.56,
#   'WWR': 0.32,
#   'AR': 1.64,
#   'EUI': 163.3,
#   'FA': 669.8},
#  995: {'L': 24.26,
#   'W': 23.33,
#   'H': 2.58,
#   'WWR': 0.24,
#   'AR': 1.04,
#   'EUI': 161.5,
#   'FA': 566.0},
#  996: {'L': 25.15,
#   'W': 24.42,
#   'H': 3.76,
#   'WWR': 0.21,
#   'AR': 1.03,
#   'EUI': 169.7,
#   'FA': 614.2},
#  997: {'L': 39.49,
#   'W': 20.15,
#   'H': 2.51,
#   'WWR': 0.29,
#   'AR': 1.96,
#   'EUI': 159.9,
#   'FA': 795.7},
#  998: {'L': 23.93,
#   'W': 15.34,
#   'H': 3.45,
#   'WWR': 0.3,
#   'AR': 1.56,
#   'EUI': 183.9,
#   'FA': 367.1},
#  999: {'L': 37.14,
#   'W': 21.72,
#   'H': 3.57,
#   'WWR': 0.28,
#   'AR': 1.71,
#   'EUI': 168.4,
#   'FA': 806.7},
#  1000: {'L': 14.44,
#   'W': 8.3,
#   'H': 3.16,
#   'WWR': 0.25,
#   'AR': 1.74,
#   'EUI': 208.3,
#   'FA': 119.9},
#  ...}

# %% [markdown]
# ### Creating the dataset with Query and Answer

# %% [markdown]
# ###

# %%
import random

# Set the random seed
random.seed(123)

# Initialize JSON pairs list
json_pairs = []

# Process each IDF file
for idf_file in os.listdir(idf_folder_path):
    if idf_file.endswith('.idf') and idf_file.startswith("in"):
        idf_file_path = os.path.join(idf_folder_path, idf_file)

        try:
            building_id = int(idf_file.replace("in", "").replace(".idf", ""))
            description = building_data.get(building_id)
            if not description:
                print(f"Warning: No description found for {idf_file}")
                continue
        except ValueError:
            print(f"Skipping {idf_file} - Invalid filename format.")
            continue

        # Extract EnergyPlus objects
        zones, spaces, space_lists, building_surfaces, fenestration_surfaces = extract_objects(idf_file_path)

        # Debugging: Print number of extracted components
        print(f"Processing {idf_file}: Zones({len(zones)}), Spaces({len(spaces)}), "
              f"SpaceLists({len(space_lists)}), Surfaces({len(building_surfaces)}), Windows({len(fenestration_surfaces)})")

        # Ensure at least some components exist
        if any([zones, spaces, space_lists, building_surfaces, fenestration_surfaces]):
            json_pairs.append({
                "user": generate_combined_query(description),
                "assistant": "".join(zones + spaces + space_lists + building_surfaces + fenestration_surfaces)
            })
        else:
            print(f"Skipping {idf_file} - No relevant objects found.")
# Out:
# Processing in1.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in10.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in100.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1000.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1001.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1002.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1003.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1004.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1005.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1006.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1007.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1008.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1009.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in101.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1010.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1011.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1012.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1013.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1014.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1015.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1016.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1017.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1018.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1019.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in102.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1020.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1021.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1022.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1023.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1024.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1025.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1026.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1027.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1028.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1029.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in103.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1030.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1031.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1032.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1033.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1034.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1035.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1036.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1037.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1038.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1039.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in104.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1040.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1041.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1042.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1043.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1044.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1045.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1046.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1047.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1048.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1049.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in105.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1050.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1051.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1052.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1053.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1054.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1055.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1056.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1057.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1058.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1059.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in106.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1060.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1061.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1062.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1063.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1064.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1065.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1066.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1067.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1068.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1069.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in107.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1070.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1071.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1072.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1073.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1074.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1075.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1076.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1077.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1078.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1079.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in108.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1080.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1081.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1082.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1083.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1084.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1085.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1086.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1087.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1088.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1089.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in109.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1090.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1091.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1092.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1093.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1094.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1095.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1096.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1097.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1098.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1099.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in11.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in110.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1100.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1101.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1102.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1103.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1104.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1105.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1106.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1107.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1108.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1109.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in111.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1110.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1111.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1112.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1113.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1114.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1115.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1116.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1117.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1118.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1119.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in112.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1120.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1121.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1122.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1123.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1124.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1125.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1126.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1127.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1128.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1129.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in113.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1130.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1131.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1132.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1133.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1134.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1135.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1136.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1137.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1138.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1139.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in114.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1140.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1141.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1142.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1143.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1144.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1145.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1146.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1147.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1148.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1149.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in115.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1150.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1151.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1152.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1153.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1154.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1155.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1156.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1157.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1158.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1159.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in116.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1160.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1161.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1162.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1163.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1164.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1165.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1166.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1167.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1168.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1169.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in117.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1170.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1171.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1172.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1173.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1174.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1175.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1176.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1177.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1178.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1179.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in118.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1180.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1181.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1182.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1183.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1184.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1185.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1186.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1187.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1188.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1189.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in119.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1190.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1191.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1192.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1193.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1194.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1195.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1196.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1197.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1198.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1199.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in12.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in120.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1200.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1201.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1202.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1203.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1204.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1205.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1206.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1207.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1208.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1209.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in121.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1210.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1211.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1212.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1213.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1214.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1215.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1216.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1217.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1218.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1219.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in122.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1220.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1221.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1222.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1223.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1224.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1225.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1226.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1227.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1228.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1229.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in123.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1230.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1231.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1232.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1233.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1234.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1235.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1236.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1237.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1238.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1239.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in124.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1240.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1241.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1242.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1243.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1244.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1245.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1246.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1247.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1248.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1249.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in125.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1250.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1251.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1252.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1253.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1254.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1255.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1256.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1257.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1258.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1259.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in126.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1260.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1261.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1262.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1263.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1264.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1265.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1266.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1267.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1268.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1269.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in127.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1270.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1271.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1272.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1273.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1274.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1275.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1276.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1277.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1278.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1279.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in128.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1280.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1281.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1282.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1283.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1284.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1285.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1286.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1287.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1288.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1289.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in129.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1290.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1291.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1292.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1293.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1294.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1295.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1296.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1297.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1298.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1299.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in13.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in130.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1300.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1301.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1302.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1303.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1304.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1305.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1306.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1307.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1308.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1309.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in131.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1310.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1311.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1312.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1313.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1314.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1315.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1316.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1317.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1318.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1319.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in132.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1320.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1321.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1322.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1323.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1324.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1325.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1326.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1327.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1328.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1329.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in133.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1330.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1331.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1332.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1333.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1334.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1335.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1336.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1337.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1338.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1339.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in134.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1340.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1341.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1342.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1343.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1344.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1345.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1346.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1347.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1348.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1349.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in135.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1350.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1351.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1352.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1353.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1354.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1355.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1356.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1357.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1358.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1359.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in136.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1360.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1361.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1362.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1363.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1364.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1365.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1366.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1367.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1368.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1369.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in137.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1370.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1371.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1372.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1373.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1374.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1375.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1376.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1377.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1378.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1379.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in138.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1380.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1381.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1382.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1383.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1384.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1385.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1386.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1387.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1388.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1389.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in139.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1390.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1391.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1392.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1393.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1394.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1395.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1396.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1397.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1398.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1399.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in14.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in140.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1400.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1401.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1402.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1403.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1404.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1405.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1406.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1407.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1408.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1409.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in141.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1410.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1411.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1412.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1413.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1414.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1415.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1416.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1417.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1418.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1419.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in142.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1420.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1421.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1422.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1423.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1424.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1425.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1426.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1427.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1428.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1429.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in143.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1430.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1431.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1432.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1433.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1434.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1435.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1436.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1437.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1438.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1439.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in144.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1440.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1441.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1442.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1443.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1444.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1445.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1446.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1447.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1448.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1449.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in145.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1450.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1451.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1452.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1453.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1454.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1455.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1456.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1457.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1458.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1459.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in146.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1460.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1461.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1462.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1463.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1464.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1465.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1466.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1467.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1468.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1469.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in147.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1470.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1471.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1472.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1473.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1474.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1475.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1476.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1477.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1478.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1479.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in148.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1480.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1481.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1482.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1483.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1484.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1485.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1486.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1487.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1488.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1489.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in149.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1490.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1491.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1492.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1493.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1494.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1495.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1496.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1497.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1498.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1499.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in15.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in150.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1500.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1501.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1502.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1503.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1504.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1505.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1506.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1507.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1508.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1509.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in151.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1510.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1511.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1512.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1513.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1514.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1515.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1516.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1517.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1518.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in1519.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# ...
# Processing in823.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in824.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in825.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in826.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in827.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in828.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in829.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in83.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in830.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in831.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in832.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in833.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in834.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in835.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in836.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in837.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in838.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in839.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in84.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in840.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in841.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in842.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in843.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in844.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in845.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in846.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in847.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in848.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in849.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in85.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in850.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in851.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in852.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in853.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in854.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in855.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in856.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in857.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in858.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in859.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in86.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in860.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in861.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in862.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in863.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in864.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in865.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in866.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in867.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in868.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in869.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in87.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in870.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in871.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in872.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in873.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in874.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in875.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in876.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in877.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in878.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in879.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in88.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in880.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in881.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in882.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in883.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in884.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in885.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in886.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in887.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in888.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in889.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in89.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in890.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in891.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in892.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in893.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in894.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in895.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in896.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in897.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in898.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in899.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in9.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in90.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in900.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in901.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in902.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in903.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in904.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in905.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in906.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in907.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in908.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in909.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in91.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in910.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in911.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in912.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in913.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in914.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in915.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in916.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in917.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in918.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in919.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in92.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in920.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in921.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in922.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in923.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in924.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in925.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in926.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in927.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in928.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in929.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in93.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in930.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in931.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in932.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in933.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in934.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in935.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in936.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in937.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in938.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in939.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in94.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in940.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in941.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in942.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in943.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in944.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in945.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in946.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in947.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in948.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in949.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in95.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in950.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in951.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in952.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in953.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in954.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in955.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in956.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in957.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in958.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in959.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in96.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in960.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in961.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in962.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in963.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in964.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in965.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in966.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in967.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in968.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in969.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in97.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in970.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in971.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in972.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in973.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in974.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in975.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in976.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in977.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in978.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in979.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in98.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in980.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in981.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in982.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in983.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in984.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in985.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in986.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in987.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in988.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in989.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in99.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in990.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in991.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in992.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in993.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in994.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in995.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in996.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in997.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in998.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)
# Processing in999.idf: Zones(1), Spaces(1), SpaceLists(1), Surfaces(6), Windows(4)

# %%
# Save dataset to JSON
with open(output_json_path, 'w', encoding='utf-8') as json_file:
    json.dump(json_pairs, json_file, indent=2)

print(f"Fine-tuning dataset saved to {output_json_path}")
# Out:
# Fine-tuning dataset saved to BuildingGeometricDataset2.json

# %% [markdown]
# ### Cleaning the json file

# %%
## Making 0.2 or two significant digitsimport json
import re
file_path = r"C:\Users\Jayedi Aman\OneDrive - University of Missouri\Desktop\LLM\BuildingGeometricDataset2.json"

def round_numbers_in_text(text, precision=2):
    # Match only floating point numbers (with decimals), including negatives
    number_pattern = re.compile(r'-?\d+\.\d+')

    def round_match(match):
        num = float(match.group())
        return f"{num:.{precision}f}"

    return number_pattern.sub(round_match, text)

def round_json_numbers(json_data, precision=2):
    for item in json_data:
        for key in item:
            if isinstance(item[key], str):
                item[key] = round_numbers_in_text(item[key], precision)
    return json_data

# %%
# === Usage ===
# Load your JSON file
with open(file_path, "r") as f:
    data = json.load(f)

# Round numbers in the JSON
rounded_data = round_json_numbers(data, precision=2)

# %%
# Save the modified JSON
with open(file_path, "w") as f:
    json.dump(rounded_data, f, indent=2)

# %% [markdown]
# templates = [
#         f"Create an EnergyPlus IDF component including a Zone, Space, and SpaceList along with a building surface and its fenestration."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Building details: FA={description['FA']:.4f} m2, L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Generate an IDF snippet defining a Zone, Space, SpaceList, a building surface, and an associated window/aperture."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Building: {description['FA']:.4f} m2, {description['L']:.4f}m x {description['W']:.4f}m x {description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Provide an EnergyPlus IDF file that includes a Zone, Space, SpaceList, a building surface, and a window/aperture."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Details: L={description['L']:.4f}m, W={description['W']:.4f}m, H={description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Give me EnergyPlus IDF file that includes a Zone, Space, SpaceList, a building surface, and a window/aperture."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Details: L={description['L']:.4f}m, W={description['W']:.4f}m, H={description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Make IDF defining a Zone, Space, SpaceList, a building surface, and an associated fenestration."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Building: {description['FA']:.4f} m2, {description['L']:.4f}m x {description['W']:.4f}m x {description['H']:.4f}m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Construct an EnergyPlus IDF file featuring a Zone, Space, SpaceList, a building surface, and its fenestration.\n"
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Specifications: Floor Area={description['FA']:.4f} sq.m, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, Aspect Ratio={description['AR']:.4f}, Window-to-Wall Ratio={description['WWR']:.2f}.",
#
#         f"Dram an IDF file that includes a Zone, Space, SpaceList, a building surface, and a window or other fenestration element."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Building properties: {description['FA']:.4f} sq.m total, {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Generate an EnergyPlus IDF section containing a Zone, Space, SpaceList, a building surface with fenestration, and necessary geometric details."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Dimensions: {description['L']:.4f} m (L) x {description['W']:.4f} m (W) x {description['H']:.4f} m (H), Total Area={description['FA']:.4f} sq.m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Create a valid IDF file for EnergyPlus that defines a Zone, Space, SpaceList, a building envelope surface, and an opening such as a window."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Given parameters: FA={description['FA']:.4f} square m, L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Write an IDF script containing a Zone, Space, SpaceList, an building surface, and its corresponding fenestration."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Input specifications: Floor Area={description['FA']:.4f} square m, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Design an IDF file that incorporates a Zone, Space, SpaceList, a key building surface, and its fenestration for EnergyPlus simulation."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Parameters: Floor Area={description['FA']:.4f} square feet, L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Prepare an EnergyPlus IDF definition that includes a Zone, Space, SpaceList, an building surface, and an associated window or aperture."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Building configuration: {description['FA']:.4f} square feet, {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Write an IDF file for a building with a Zone, Space, SpaceList, a building surface, and an opening fenestration for EnergyPlus analysis."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Specifications: L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, FA={description['FA']:.4f} sq. feet, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Develop an EnergyPlus IDF file that defines a Zone, Space, SpaceList, building surface and fenestration element, and other necessary details."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Inputs: Floor Area={description['FA']:.4f} sq m, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Formulate an IDF snippet that includes a Zone, Space, SpaceList, building surface, and a window or glazing element."
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Building parameters: {description['FA']:.4f} sq m total, Dimensions: {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"How can I generate an EnergyPlus IDF file that includes a Zone, Space, SpaceList, a building surface, and a window?"
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"My building details are: Floor Area={description['FA']:.4f} SF, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, Aspect Ratio={description['AR']:.4f}, and Window-to-Wall Ratio={description['WWR']:.2f}.",
#
#         f"Can you provide an IDF file containing a Zone, Space, SpaceList, building surface, and its fenestration?"
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"The building parameters are: {description['FA']:.4f} SF total, {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"What would an EnergyPlus IDF look like for a building with a Zone, Space, SpaceList, a building surface, and fenestration?"
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"Here are my specifications: L={description['L']:.4f} m, W={description['W']:.4f} m, H={description['H']:.4f} m, FA={description['FA']:.4f} m2, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"Can you help me create an IDF snippet for EnergyPlus that includes a Zone, Space, SpaceList, a building surface, and a glazing element?"
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"The building details are: {description['FA']:.4f} sq m , Dimensions: {description['L']:.4f} m x {description['W']:.4f} m x {description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#
#         f"What is the correct IDF structure for defining a Zone, Space, SpaceList, an building surface, and a fenestration in EnergyPlus?"
#         f"Assume the surface vertices begin at (0,0,0) and follow clockwise order. Include window placement on one wall."
#         f"My building specifications are: Floor Area={description['FA']:.4f} m2, Length={description['L']:.4f} m, Width={description['W']:.4f} m, Height={description['H']:.4f} m, AR={description['AR']:.4f}, WWR={description['WWR']:.2f}.",
#     ]
